# %%
import pandas as pd
import numpy as np
import os
from datetime import datetime

# %%
#os.getcwd( )
os.chdir('Documents\Bootcamp_HW\Project_Work\ETL') 
os.getcwd( )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-10b81f9b4f9b> in <module>
#       1 #os.getcwd( )
# ----> 2 os.chdir('Documents\Bootcamp_HW\Project_Work\ETL')
#       3 os.getcwd( )
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'Documents\\Bootcamp_HW\\Project_Work\\ETL'

# %%
#upload the first CSV file with index as 'Date' and drop the index column 'Unnamed: 0'
upload_df = pd.read_csv('3Y_BTC_5-15-19.csv', index_col="Date")
main_df=upload_df.drop(upload_df.columns[0], axis=1) #dropped the index column as 'Date' is the index
main_df
# Out:
#              Open     High      Low    Close       Volume     MarketCap  \
# Date
# 20160516   457.59   458.20   452.95   454.16     59171500    7063120268
# 20160517   454.01   455.07   453.61   453.78     64100300    7058821457
# 20160518   453.69   456.00   453.30   454.62     86850096    7073564772
# 20160519   454.52   454.63   438.71   438.71     96027400    6827425412
# 20160520   437.79   444.05   437.39   442.68     81987904    6890716750
# 20160521   442.97   443.78   441.71   443.19     42762300    6900237725
# 20160522   443.22   443.43   439.04   439.32     39657600    6842082300
# 20160523   439.35   444.35   438.82   444.15     50582500    6919346395
# 20160524   444.29   447.10   443.93   445.98     65783100    6949432035
# 20160525   446.06   450.30   446.06   449.60     65231000    7007360094
# 20160526   449.67   453.64   447.90   453.38     65203800    7067871184
# 20160527   453.52   478.15   453.52   473.46    164780992    7382558440
# ...

# %%
#upload the next CSV file 
upload_df = pd.read_csv('bitfinex_l-s-v.csv', index_col='Date')
upload_df.columns=['finex_BTC_short','finex_BTC_long','finex_BTC_vol']
upload_df
# Out:
#           finex_BTC_short  finex_BTC_long  finex_BTC_vol
# Date
# 20190515       27477.2881      25001.5399          19036
# 20190514       27134.3879      24789.3294          29341
# 20190513       25684.6636      26226.9500          36467
# 20190512       25682.8605      22249.4830          31959
# 20190511       26631.4663      22629.3385          37945
# 20190510       30142.8601      18008.4966          14493
# 20190509       32385.4480      19127.9740           9682
# 20190508       32446.0476      18306.7113           8222
# 20190507       32045.2756      18334.0558          11990
# 20190506       31871.8415      18418.6867           6477
# 20190505       30837.3928      18626.6610           5816
# 20190504       30547.9276      18424.1297           9437
# 20190503       29954.2449      18031.8041          19480
# 20190502       31189.5831      18608.4080          11076
# 20190501       30618.9926      18012.1074           5537
# ...

# %%
crypto_df=pd.merge(main_df, upload_df, on='Date', how='outer') 
crypto_df
# Out:
#              Open     High      Low    Close       Volume     MarketCap  \
# Date
# 20160516   457.59   458.20   452.95   454.16     59171500    7063120268
# 20160517   454.01   455.07   453.61   453.78     64100300    7058821457
# 20160518   453.69   456.00   453.30   454.62     86850096    7073564772
# 20160519   454.52   454.63   438.71   438.71     96027400    6827425412
# 20160520   437.79   444.05   437.39   442.68     81987904    6890716750
# 20160521   442.97   443.78   441.71   443.19     42762300    6900237725
# 20160522   443.22   443.43   439.04   439.32     39657600    6842082300
# 20160523   439.35   444.35   438.82   444.15     50582500    6919346395
# 20160524   444.29   447.10   443.93   445.98     65783100    6949432035
# 20160525   446.06   450.30   446.06   449.60     65231000    7007360094
# 20160526   449.67   453.64   447.90   453.38     65203800    7067871184
# 20160527   453.52   478.15   453.52   473.46    164780992    7382558440
# ...

# %%
#upload the next CSV file 
upload_df = pd.read_csv('crypto_total_cap.csv', index_col='Date')
upload_df.columns=['temp','CryptoCap']
del upload_df['temp']
upload_df
# Out:
#              CryptoCap
# Date
# 20180101  6.168760e+11
# 20180102  6.751490e+11
# 20180103  7.371720e+11
# 20180104  7.535050e+11
# 20180105  7.822990e+11
# 20180106  8.162930e+11
# 20180107  8.305950e+11
# 20180108  7.438420e+11
# 20180109  7.326670e+11
# 20180110  7.351310e+11
# 20180111  6.653320e+11
# 20180112  7.177620e+11
# 20180113  7.459290e+11
# 20180114  7.066060e+11
# 20180115  6.821820e+11
# 20180116  5.374670e+11
# 20180117  5.402390e+11
# 20180118  5.673530e+11
# 20180119  5.714740e+11
# 20180120  6.304010e+11
# 20180121  5.597790e+11
# 20180122  5.312950e+11
# 20180123  5.264940e+11
# 20180124  5.540840e+11
# 20180125  5.514620e+11
# 20180126  5.448170e+11
# 20180127  5.598150e+11
# 20180128  5.959110e+11
# 20180129  5.697930e+11
# 20180130  5.032190e+11
# ...                ...
# 20190416  1.772240e+11
# 20190417  1.777050e+11
# 20190418  1.803870e+11
# 20190419  1.805110e+11
# 20190420  1.808370e+11
# 20190421  1.781080e+11
# 20190422  1.805410e+11
# ...

# %%
#merge crypto_df with total_cap df on left outer join 
crypto_df=pd.merge(crypto_df, upload_df, on='Date', how='left') 
crypto_df
# Out:
#              Open     High      Low    Close       Volume     MarketCap  \
# Date
# 20160516   457.59   458.20   452.95   454.16     59171500    7063120268
# 20160517   454.01   455.07   453.61   453.78     64100300    7058821457
# 20160518   453.69   456.00   453.30   454.62     86850096    7073564772
# 20160519   454.52   454.63   438.71   438.71     96027400    6827425412
# 20160520   437.79   444.05   437.39   442.68     81987904    6890716750
# 20160521   442.97   443.78   441.71   443.19     42762300    6900237725
# 20160522   443.22   443.43   439.04   439.32     39657600    6842082300
# 20160523   439.35   444.35   438.82   444.15     50582500    6919346395
# 20160524   444.29   447.10   443.93   445.98     65783100    6949432035
# 20160525   446.06   450.30   446.06   449.60     65231000    7007360094
# 20160526   449.67   453.64   447.90   453.38     65203800    7067871184
# 20160527   453.52   478.15   453.52   473.46    164780992    7382558440
# ...

# %%
#upload the next CSV file containgin total Bitcoins in circulation  
upload_df = pd.read_csv('total-bitcoins_2yrs5-15-19.csv', index_col='Date')
upload_df
# Out:
#            BTC_Float
# Date
# 20170515  16332562.5
# 20170516  16334212.5
# 20170517  16336150.0
# 20170518  16337925.0
# 20170519  16339975.0
# 20170520  16342037.5
# 20170521  16343875.0
# 20170522  16345700.0
# 20170523  16347800.0
# 20170524  16349725.0
# 20170525  16351762.5
# 20170526  16353675.0
# 20170527  16355775.0
# 20170528  16357837.5
# 20170529  16359725.0
# 20170530  16361962.5
# 20170531  16364012.5
# 20170601  16366137.5
# 20170602  16367962.5
# 20170603  16370362.5
# 20170604  16372375.0
# 20170605  16374425.0
# 20170606  16376312.5
# 20170607  16378375.0
# 20170608  16380437.5
# 20170609  16382325.0
# 20170610  16384087.5
# 20170611  16385912.5
# 20170612  16387750.0
# 20170613  16389512.5
# ...              ...
# 20190416  17649437.5
# 20190417  17651162.5
# 20190418  17653025.0
# 20190419  17654925.0
# 20190420  17656562.5
# 20190421  17658587.5
# 20190422  17660262.5
# 20190423  17661712.5
# 20190424  17663750.0
# 20190425  17665537.5
# 20190426  17667425.0
# ...

# %%
#merge crypto_df with total_cap df on left outer join 
#crypto_df=pd.merge(crypto_df, upload_df, on='Date', how='left') 
crypto_df.dtypes #for creating my SQL table
# Out:
# Open               float64
# High               float64
# Low                float64
# Close              float64
# Volume               int64
# MarketCap            int64
# UnitVolume         float64
# Rolling20D         float64
# finex_BTC_short    float64
# finex_BTC_long     float64
# finex_BTC_vol      float64
# CryptoCap          float64
# BTC_Float          float64
# dtype: object

# %%
#import the databse modules 
from sqlalchemy import create_engine
# Create Engine and Pass in MySQL Connection
# <database_language>://<username>:<password>@<url>:<port>/<dbname>

#engine = create_engine("mysql://k5xunpkmojyzse51:ifagg1gp7e2xyapi@ffn96u87j5ogvehy.cbetxkdyhwsb.us-east-1.rds.amazonaws.com:3306/tq6h098h0ym00zp6")
engine = create_engine("mysql://root:limited@127.0.0.1:3306/crypto_dashboard")
# PyMySQL
import pymysql
pymysql.install_as_MySQLdb()

# %%
'''
# Query all Records in the the Database
#below is how executed 


CREATE TABLE BTC (
  Date INT NOT NULL,
  Open float DEFAULT NULL,
  High float DEFAULT NULL,
  Low float DEFAULT NULL,
  Close float DEFAULT NULL,
  Volume bigint DEFAULT NULL,
  MarketCap bigint DEFAULT NULL,
  UnitVolume float DEFAULT NULL,
  Rolling20D float DEFAULT NULL,
  finex_BTC_short float DEFAULT NULL,
  finex_BTC_long float DEFAULT NULL, 
  finex_BTC_vol float DEFAULT NULL, 
  CryptoCap float DEFAULT NULL, 
  BTC_Float float DEFAULT NULL,
  Primary KEY (Date));
  
#below line uploads my dataframe to SQL where I created the above columns
#crypto_df.to_sql(name='btc', con=engine, if_exists='append', index=True) 

'''
# Out:
# '\n# Query all Records in the the Database\n#below is how executed \n#data = engine.execute("SELECT * FROM Census_Data")\n\n\nCREATE TABLE BTC (\n  Date INT NOT NULL,\n  Open float DEFAULT NULL,\n  High float DEFAULT NULL,\n  Low float DEFAULT NULL,\n  Close float DEFAULT NULL,\n  Volume bigint DEFAULT NULL,\n  MarketCap bigint DEFAULT NULL,\n  UnitVolume float DEFAULT NULL,\n  Rolling20D float DEFAULT NULL,\n  finex_BTC_short float DEFAULT NULL,\n  finex_BTC_long float DEFAULT NULL, \n  finex_BTC_vol float DEFAULT NULL, \n  CryptoCap float DEFAULT NULL, \n  BTC_Float float DEFAULT NULL,\n  Primary KEY (Date));\n\n'

# %%
crypto_df.to_sql(name='btc', con=engine, if_exists='append', index=True)

# %%
data = engine.execute("show tables")
engine.table_names()
# Out:
# ['btc']
