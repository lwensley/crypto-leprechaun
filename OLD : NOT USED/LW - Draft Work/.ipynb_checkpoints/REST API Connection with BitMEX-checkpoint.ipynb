# %% [markdown]
# ## Capturing Data from BitMEX through API

# %% [markdown]
# ### Getting started

# %% [markdown]
# Instructions: https://www.bitmex.com/api/explorer/ <br>
# ReadMe Instructions: https://github.com/BitMEX/api-connectors/blob/master/official-http/python-swaggerpy/README.md

# %% [markdown]
# login to BitMEX, request an API Key <br>
# login to BitMEX Test site, request an API Key <br>
# store API Keys and API Secrets

# %% [markdown]
# ##### Install bitmex in terminal:
# $ pip install bitmex

# %% [markdown]
# ### Import dependencies, connect to BitMEX

# %%
# Dependencies
import bitmex
import requests
import json
import datetime
# import dateutil.parser
# from dateutil.tz import tzutc
import time
import pandas as pd
from sqlalchemy import create_engine
import numpy as np

# # Set-up & connect to live BitMEX environment
# from BitMEX_API_Keys import API_KEY
# from BitMEX_API_Keys import API_SECRET

# client = bitmex.bitmex(test=False, api_key=API_KEY, api_secret=API_SECRET)

# Set-up & connect to test BitMEX environment
from BitMEX_API_Keys_test import API_KEY_TEST
from BitMEX_API_Keys_test import API_SECRET_TEST

test_client = bitmex.bitmex(test=True, api_key=API_KEY_TEST, api_secret=API_SECRET_TEST)

# %% [markdown]
# ### Research available responses for the bitmex API
# Every function of the BitMEX.com platform is exposed here:

# %%
Explorer_url = "https://www.bitmex.com/api/explorer/swagger.json"

# run a request using our params dictionary
Explorer_response = requests.get(Explorer_url)

# convert response to json
Explorer_data = Explorer_response.json()

# Print the json (pretty printed)
print(json.dumps(Explorer_data, indent=4, sort_keys=True))
# Out:
# {
#     "basePath": "/api/v1",
#     "consumes": [
#         "application/json",
#         "application/x-www-form-urlencoded"
#     ],
#     "definitions": {
#         "APIKey": {
#             "description": "Persistent API Keys for Developers",
#             "properties": {
#                 "cidr": {
#                     "maxLength": 18,
#                     "type": "string"
#                 },
#                 "created": {
#                     "format": "date-time",
#                     "type": "string"
#                 },
#                 "enabled": {
#                     "default": false,
#                     "type": "boolean"
#                 },
#                 "id": {
#                     "maxLength": 24,
#                     "type": "string"
#                 },
#                 "name": {
#                     "maxLength": 64,
#                     "type": "string"
#                 },
#                 "nonce": {
#                     "default": 0,
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "permissions": {
#                     "default": [],
#                     "items": {
#                         "$ref": "#/definitions/x-any"
#                     },
#                     "type": "array"
#                 },
#                 "secret": {
#                     "maxLength": 48,
#                     "type": "string"
#                 },
#                 "userId": {
#                     "format": "int32",
#                     "type": "number"
#                 }
#             },
#             "required": [
#                 "id",
#                 "secret",
#                 "name",
#                 "nonce",
#                 "userId"
#             ],
#             "type": "object"
#         },
#         "AccessToken": {
#             "properties": {
#                 "created": {
#                     "format": "date-time",
#                     "type": "string"
#                 },
#                 "id": {
#                     "type": "string"
#                 },
#                 "ttl": {
#                     "default": 1209600,
#                     "description": "time to live in seconds (2 weeks by default)",
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "userId": {
#                     "format": "double",
#                     "type": "number"
#                 }
#             },
#             "required": [
#                 "id"
#             ],
#             "type": "object"
#         },
#         "Affiliate": {
#             "properties": {
#                 "account": {
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "affiliatePayout": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "currency": {
#                     "type": "string"
#                 },
#                 "execComm": {
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "execTurnover": {
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "payoutPcnt": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "pendingPayout": {
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "prevComm": {
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "prevPayout": {
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "prevTimestamp": {
#                     "format": "date-time",
#                     "type": "string"
#                 },
#                 "prevTurnover": {
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "referralDiscount": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "referrerAccount": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "timestamp": {
#                     "format": "date-time",
#                     "type": "string"
#                 },
#                 "totalComm": {
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "totalReferrals": {
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "totalTurnover": {
#                     "format": "int64",
#                     "type": "number"
#                 }
#             },
#             "required": [
#                 "account",
#                 "currency"
#             ],
#             "type": "object"
#         },
#         "Announcement": {
#             "description": "Public Announcements",
#             "properties": {
#                 "content": {
#                     "type": "string"
#                 },
#                 "date": {
#                     "format": "date-time",
#                     "type": "string"
#                 },
#                 "id": {
#                     "format": "int32",
#                     "type": "number"
#                 },
#                 "link": {
#                     "type": "string"
#                 },
#                 "title": {
#                     "type": "string"
#                 }
#             },
#             "required": [
#                 "id"
#             ],
#             "type": "object"
#         },
#         "Chat": {
#             "description": "Trollbox Data",
#             "properties": {
#                 "channelID": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "date": {
#                     "format": "date-time",
#                     "type": "string"
#                 },
#                 "fromBot": {
#                     "default": false,
#                     "type": "boolean"
#                 },
#                 "html": {
#                     "type": "string"
#                 },
#                 "id": {
#                     "format": "int32",
#                     "type": "number"
#                 },
#                 "message": {
#                     "type": "string"
#                 },
#                 "user": {
#                     "type": "string"
#                 }
#             },
#             "required": [
#                 "date",
#                 "user",
#                 "message",
#                 "html"
#             ],
#             "type": "object"
#         },
#         "ChatChannel": {
#             "properties": {
#                 "id": {
#                     "format": "int32",
#                     "type": "number"
#                 },
#                 "name": {
#                     "type": "string"
#                 }
#             },
#             "required": [
#                 "name"
#             ],
#             "type": "object"
#         },
#         "CommunicationToken": {
#             "description": "User communication SNS token",
#             "properties": {
#                 "channel": {
#                     "type": "string"
#                 },
#                 "deviceToken": {
#                     "type": "string"
#                 },
#                 "id": {
#                     "type": "string"
#                 },
#                 "userId": {
#                     "format": "int32",
#                     "type": "number"
#                 }
#             },
#             "required": [
#                 "id",
#                 "userId",
#                 "deviceToken",
#                 "channel"
#             ],
#             "type": "object"
#         },
#         "ConnectedUsers": {
#             "properties": {
#                 "bots": {
#                     "format": "int32",
#                     "type": "number"
#                 },
#                 "users": {
#                     "format": "int32",
#                     "type": "number"
#                 }
#             },
#             "type": "object"
#         },
#         "Error": {
#             "properties": {
#                 "error": {
#                     "properties": {
#                         "message": {
#                             "type": "string"
#                         },
#                         "name": {
#                             "type": "string"
#                         }
#                     },
#                     "type": "object"
#                 }
#             },
#             "required": [
#                 "error"
#             ],
#             "type": "object"
#         },
#         "Execution": {
#             "description": "Raw Order and Balance Data",
#             "properties": {
#                 "account": {
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "avgPx": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "clOrdID": {
#                     "type": "string"
#                 },
#                 "clOrdLinkID": {
#                     "type": "string"
#                 },
#                 "commission": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "contingencyType": {
#                     "type": "string"
#                 },
#                 "cumQty": {
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "currency": {
#                     "type": "string"
#                 },
#                 "displayQty": {
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "exDestination": {
#                     "type": "string"
#                 },
#                 "execComm": {
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "execCost": {
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "execID": {
#                     "format": "guid",
#                     "type": "string"
#                 },
#                 "execInst": {
#                     "type": "string"
#                 },
#                 "execType": {
#                     "type": "string"
#                 },
#                 "foreignNotional": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "homeNotional": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "lastLiquidityInd": {
#                     "type": "string"
#                 },
#                 "lastMkt": {
#                     "type": "string"
#                 },
#                 "lastPx": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "lastQty": {
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "leavesQty": {
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "multiLegReportingType": {
#                     "type": "string"
#                 },
#                 "ordRejReason": {
#                     "type": "string"
#                 },
#                 "ordStatus": {
#                     "type": "string"
#                 },
#                 "ordType": {
#                     "type": "string"
#                 },
#                 "orderID": {
#                     "format": "guid",
#                     "type": "string"
#                 },
#                 "orderQty": {
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "pegOffsetValue": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "pegPriceType": {
#                     "type": "string"
#                 },
#                 "price": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "settlCurrency": {
#                     "type": "string"
#                 },
#                 "side": {
#                     "type": "string"
#                 },
#                 "simpleCumQty": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "simpleLeavesQty": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "simpleOrderQty": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "stopPx": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "symbol": {
#                     "type": "string"
#                 },
#                 "text": {
#                     "type": "string"
#                 },
#                 "timeInForce": {
#                     "type": "string"
#                 },
#                 "timestamp": {
#                     "format": "date-time",
#                     "type": "string"
#                 },
#                 "tradePublishIndicator": {
#                     "type": "string"
#                 },
#                 "transactTime": {
#                     "format": "date-time",
#                     "type": "string"
#                 },
#                 "trdMatchID": {
#                     "format": "guid",
#                     "type": "string"
#                 },
#                 "triggered": {
#                     "type": "string"
#                 },
#                 "underlyingLastPx": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "workingIndicator": {
#                     "type": "boolean"
#                 }
#             },
#             "required": [
#                 "execID"
#             ],
#             "type": "object"
#         },
#         "Funding": {
#             "description": "Swap Funding History",
#             "properties": {
#                 "fundingInterval": {
#                     "format": "date-time",
#                     "type": "string"
#                 },
#                 "fundingRate": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "fundingRateDaily": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "symbol": {
#                     "type": "string"
#                 },
#                 "timestamp": {
#                     "format": "date-time",
#                     "type": "string"
#                 }
#             },
#             "required": [
#                 "timestamp",
#                 "symbol"
#             ],
#             "type": "object"
#         },
#         "GlobalNotification": {
#             "description": "Account Notifications",
#             "properties": {
#                 "body": {
#                     "type": "string"
#                 },
#                 "closable": {
#                     "default": true,
#                     "type": "boolean"
#                 },
#                 "date": {
#                     "format": "date-time",
#                     "type": "string"
#                 },
#                 "id": {
#                     "format": "int32",
#                     "type": "number"
#                 },
#                 "persist": {
#                     "default": true,
#                     "type": "boolean"
#                 },
#                 "sound": {
#                     "type": "string"
#                 },
#                 "title": {
#                     "type": "string"
#                 },
#                 "ttl": {
#                     "format": "int32",
#                     "type": "number"
#                 },
#                 "type": {
#                     "enum": [
#                         "success",
#                         "error",
#                         "info"
#                     ],
#                     "type": "string"
#                 },
#                 "waitForVisibility": {
#                     "default": true,
#                     "type": "boolean"
#                 }
#             },
#             "required": [
#                 "date",
#                 "title",
#                 "body",
#                 "ttl"
#             ],
#             "type": "object"
#         },
#         "IndexComposite": {
#             "properties": {
#                 "indexSymbol": {
#                     "type": "string"
#                 },
#                 "lastPrice": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "logged": {
#                     "format": "date-time",
#                     "type": "string"
#                 },
#                 "reference": {
#                     "type": "string"
#                 },
#                 "symbol": {
#                     "type": "string"
#                 },
#                 "timestamp": {
#                     "format": "date-time",
#                     "type": "string"
#                 },
#                 "weight": {
#                     "format": "double",
#                     "type": "number"
#                 }
#             },
#             "required": [
#                 "timestamp"
#             ],
#             "type": "object"
#         },
#         "Instrument": {
#             "description": "Tradeable Contracts, Indices, and History",
#             "properties": {
#                 "askPrice": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "bankruptLimitDownPrice": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "bankruptLimitUpPrice": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "bidPrice": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "buyLeg": {
#                     "type": "string"
#                 },
#                 "calcInterval": {
#                     "format": "date-time",
#                     "type": "string"
#                 },
#                 "capped": {
#                     "type": "boolean"
#                 },
#                 "closingTimestamp": {
#                     "format": "date-time",
#                     "type": "string"
#                 },
#                 "deleverage": {
#                     "type": "boolean"
#                 },
#                 "expiry": {
#                     "format": "date-time",
#                     "type": "string"
#                 },
#                 "fairBasis": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "fairBasisRate": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "fairMethod": {
#                     "type": "string"
#                 },
#                 "fairPrice": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "foreignNotional24h": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "front": {
#                     "format": "date-time",
#                     "type": "string"
#                 },
#                 "fundingBaseSymbol": {
#                     "type": "string"
#                 },
#                 "fundingInterval": {
#                     "format": "date-time",
#                     "type": "string"
#                 },
#                 "fundingPremiumSymbol": {
#                     "type": "string"
#                 },
#                 "fundingQuoteSymbol": {
#                     "type": "string"
#                 },
#                 "fundingRate": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "fundingTimestamp": {
#                     "format": "date-time",
#                     "type": "string"
#                 },
#                 "hasLiquidity": {
#                     "type": "boolean"
#                 },
#                 "highPrice": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "homeNotional24h": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "impactAskPrice": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "impactBidPrice": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "impactMidPrice": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "indicativeFundingRate": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "indicativeSettlePrice": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "indicativeTaxRate": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "initMargin": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "insuranceFee": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "inverseLeg": {
#                     "type": "string"
#                 },
#                 "isInverse": {
#                     "type": "boolean"
#                 },
#                 "isQuanto": {
#                     "type": "boolean"
#                 },
#                 "lastChangePcnt": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "lastPrice": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "lastPriceProtected": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "lastTickDirection": {
#                     "type": "string"
#                 },
#                 "limit": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "limitDownPrice": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "limitUpPrice": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "listing": {
#                     "format": "date-time",
#                     "type": "string"
#                 },
#                 "lotSize": {
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "lowPrice": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "maintMargin": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "makerFee": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "markMethod": {
#                     "type": "string"
#                 },
#                 "markPrice": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "maxOrderQty": {
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "maxPrice": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "midPrice": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "multiplier": {
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "openInterest": {
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "openValue": {
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "openingTimestamp": {
#                     "format": "date-time",
#                     "type": "string"
#                 },
#                 "optionMultiplier": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "optionStrikePcnt": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "optionStrikePrice": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "optionStrikeRound": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "optionUnderlyingPrice": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "positionCurrency": {
#                     "type": "string"
#                 },
#                 "prevClosePrice": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "prevPrice24h": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "prevTotalTurnover": {
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "prevTotalVolume": {
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "publishInterval": {
#                     "format": "date-time",
#                     "type": "string"
#                 },
#                 "publishTime": {
#                     "format": "date-time",
#                     "type": "string"
#                 },
#                 "quoteCurrency": {
#                     "type": "string"
#                 },
#                 "quoteToSettleMultiplier": {
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "rebalanceInterval": {
#                     "format": "date-time",
#                     "type": "string"
#                 },
#                 "rebalanceTimestamp": {
#                     "format": "date-time",
#                     "type": "string"
#                 },
#                 "reference": {
#                     "type": "string"
#                 },
#                 "referenceSymbol": {
#                     "type": "string"
#                 },
#                 "relistInterval": {
#                     "format": "date-time",
#                     "type": "string"
#                 },
#                 "riskLimit": {
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "riskStep": {
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "rootSymbol": {
#                     "type": "string"
#                 },
#                 "sellLeg": {
#                     "type": "string"
#                 },
#                 "sessionInterval": {
#                     "format": "date-time",
#                     "type": "string"
#                 },
#                 "settlCurrency": {
#                     "type": "string"
#                 },
#                 "settle": {
#                     "format": "date-time",
#                     "type": "string"
#                 },
#                 "settledPrice": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "settlementFee": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "state": {
#                     "type": "string"
#                 },
#                 "symbol": {
#                     "type": "string"
#                 },
#                 "takerFee": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "taxed": {
#                     "type": "boolean"
#                 },
#                 "tickSize": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "timestamp": {
#                     "format": "date-time",
#                     "type": "string"
#                 },
#                 "totalTurnover": {
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "totalVolume": {
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "turnover": {
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "turnover24h": {
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "typ": {
#                     "type": "string"
#                 },
#                 "underlying": {
#                     "type": "string"
#                 },
#                 "underlyingSymbol": {
#                     "type": "string"
#                 },
#                 "underlyingToPositionMultiplier": {
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "underlyingToSettleMultiplier": {
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "volume": {
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "volume24h": {
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "vwap": {
#                     "format": "double",
#                     "type": "number"
#                 }
#             },
#             "required": [
#                 "symbol"
#             ],
#             "type": "object"
#         },
#         "InstrumentInterval": {
#             "properties": {
#                 "intervals": {
#                     "items": {
#                         "type": "string"
#                     },
#                     "type": "array"
#                 },
#                 "symbols": {
#                     "items": {
#                         "type": "string"
#                     },
#                     "type": "array"
#                 }
#             },
#             "required": [
#                 "intervals",
#                 "symbols"
#             ],
#             "type": "object"
#         },
#         "Insurance": {
#             "description": "Insurance Fund Data",
#             "properties": {
#                 "currency": {
#                     "type": "string"
#                 },
#                 "timestamp": {
#                     "format": "date-time",
#                     "type": "string"
#                 },
#                 "walletBalance": {
#                     "format": "int64",
#                     "type": "number"
#                 }
#             },
#             "required": [
#                 "currency",
#                 "timestamp"
#             ],
#             "type": "object"
#         },
#         "Leaderboard": {
#             "description": "Information on Top Users",
#             "properties": {
#                 "isRealName": {
#                     "type": "boolean"
#                 },
#                 "name": {
#                     "type": "string"
#                 },
#                 "profit": {
#                     "format": "double",
#                     "type": "number"
#                 }
#             },
#             "required": [
#                 "name"
#             ],
#             "type": "object"
#         },
#         "Liquidation": {
#             "description": "Active Liquidations",
#             "properties": {
#                 "leavesQty": {
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "orderID": {
#                     "format": "guid",
#                     "type": "string"
#                 },
#                 "price": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "side": {
#                     "type": "string"
#                 },
#                 "symbol": {
#                     "type": "string"
#                 }
#             },
#             "required": [
#                 "orderID"
#             ],
#             "type": "object"
#         },
#         "Margin": {
#             "properties": {
#                 "account": {
#                     "default": 0,
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "action": {
#                     "type": "string"
#                 },
#                 "amount": {
#                     "default": 0,
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "availableMargin": {
#                     "default": 0,
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "commission": {
#                     "default": 0,
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "confirmedDebit": {
#                     "default": 0,
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "currency": {
#                     "type": "string"
#                 },
#                 "excessMargin": {
#                     "default": 0,
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "excessMarginPcnt": {
#                     "default": 0,
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "grossComm": {
#                     "default": 0,
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "grossExecCost": {
#                     "default": 0,
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "grossLastValue": {
#                     "default": 0,
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "grossMarkValue": {
#                     "default": 0,
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "grossOpenCost": {
#                     "default": 0,
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "grossOpenPremium": {
#                     "default": 0,
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "indicativeTax": {
#                     "default": 0,
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "initMargin": {
#                     "default": 0,
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "maintMargin": {
#                     "default": 0,
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "marginBalance": {
#                     "default": 0,
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "marginBalancePcnt": {
#                     "default": 0,
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "marginLeverage": {
#                     "default": 0,
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "marginUsedPcnt": {
#                     "default": 0,
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "pendingCredit": {
#                     "default": 0,
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "pendingDebit": {
#                     "default": 0,
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "prevRealisedPnl": {
#                     "default": 0,
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "prevState": {
#                     "type": "string"
#                 },
#                 "prevUnrealisedPnl": {
#                     "default": 0,
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "realisedPnl": {
#                     "default": 0,
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "riskLimit": {
#                     "default": 0,
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "riskValue": {
#                     "default": 0,
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "sessionMargin": {
#                     "default": 0,
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "state": {
#                     "type": "string"
#                 },
#                 "syntheticMargin": {
#                     "default": 0,
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "targetExcessMargin": {
#                     "default": 0,
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "taxableMargin": {
#                     "default": 0,
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "timestamp": {
#                     "format": "date-time",
#                     "type": "string"
#                 },
#                 "unrealisedPnl": {
#                     "default": 0,
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "unrealisedProfit": {
#                     "default": 0,
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "varMargin": {
#                     "default": 0,
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "walletBalance": {
#                     "default": 0,
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "withdrawableMargin": {
#                     "default": 0,
#                     "format": "int64",
#                     "type": "number"
#                 }
#             },
#             "required": [
#                 "account",
#                 "currency"
#             ],
#             "type": "object"
#         },
#         "Order": {
#             "description": "Placement, Cancellation, Amending, and History",
#             "properties": {
#                 "account": {
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "avgPx": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "clOrdID": {
#                     "type": "string"
#                 },
#                 "clOrdLinkID": {
#                     "type": "string"
#                 },
#                 "contingencyType": {
#                     "type": "string"
#                 },
#                 "cumQty": {
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "currency": {
#                     "type": "string"
#                 },
#                 "displayQty": {
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "exDestination": {
#                     "type": "string"
#                 },
#                 "execInst": {
#                     "type": "string"
#                 },
#                 "leavesQty": {
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "multiLegReportingType": {
#                     "type": "string"
#                 },
#                 "ordRejReason": {
#                     "type": "string"
#                 },
#                 "ordStatus": {
#                     "type": "string"
#                 },
#                 "ordType": {
#                     "type": "string"
#                 },
#                 "orderID": {
#                     "format": "guid",
#                     "type": "string"
#                 },
#                 "orderQty": {
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "pegOffsetValue": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "pegPriceType": {
#                     "type": "string"
#                 },
#                 "price": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "settlCurrency": {
#                     "type": "string"
#                 },
#                 "side": {
#                     "type": "string"
#                 },
#                 "simpleCumQty": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "simpleLeavesQty": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "simpleOrderQty": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "stopPx": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "symbol": {
#                     "type": "string"
#                 },
#                 "text": {
#                     "type": "string"
#                 },
#                 "timeInForce": {
#                     "type": "string"
#                 },
#                 "timestamp": {
#                     "format": "date-time",
#                     "type": "string"
#                 },
#                 "transactTime": {
#                     "format": "date-time",
#                     "type": "string"
#                 },
#                 "triggered": {
#                     "type": "string"
#                 },
#                 "workingIndicator": {
#                     "type": "boolean"
#                 }
#             },
#             "required": [
#                 "orderID"
#             ],
#             "type": "object"
#         },
#         "OrderBookL2": {
#             "properties": {
#                 "id": {
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "price": {
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "side": {
#                     "type": "string"
#                 },
#                 "size": {
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "symbol": {
#                     "type": "string"
#                 }
#             },
#             "required": [
#                 "symbol",
#                 "id",
#                 "side"
#             ],
#             "type": "object"
#         },
#         "Position": {
#             "description": "Summary of Open and Closed Positions",
#             "properties": {
#                 "account": {
#                     "default": 0,
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "avgCostPrice": {
#                     "default": 0,
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "avgEntryPrice": {
#                     "default": 0,
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "bankruptPrice": {
#                     "default": 0,
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "breakEvenPrice": {
#                     "default": 0,
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "commission": {
#                     "default": 0,
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "crossMargin": {
#                     "type": "boolean"
#                 },
#                 "currency": {
#                     "type": "string"
#                 },
#                 "currentComm": {
#                     "default": 0,
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "currentCost": {
#                     "default": 0,
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "currentQty": {
#                     "default": 0,
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "currentTimestamp": {
#                     "format": "date-time",
#                     "type": "string"
#                 },
#                 "deleveragePercentile": {
#                     "default": 0,
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "execBuyCost": {
#                     "default": 0,
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "execBuyQty": {
#                     "default": 0,
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "execComm": {
#                     "default": 0,
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "execCost": {
#                     "default": 0,
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "execQty": {
#                     "default": 0,
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "execSellCost": {
#                     "default": 0,
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "execSellQty": {
#                     "default": 0,
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "foreignNotional": {
#                     "default": 0,
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "grossExecCost": {
#                     "default": 0,
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "grossOpenCost": {
#                     "default": 0,
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "grossOpenPremium": {
#                     "default": 0,
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "homeNotional": {
#                     "default": 0,
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "indicativeTax": {
#                     "default": 0,
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "indicativeTaxRate": {
#                     "default": 0,
#                     "format": "double",
#                     "type": "number"
#                 },
#                 "initMargin": {
#                     "default": 0,
#                     "format": "int64",
#                     "type": "number"
#                 },
#                 "initMarginReq": {
#                     "default": 0,
#                     "format": "double",
# ...
#                         }
#                     }
#                 },
#                 "summary": "Get the execution history by day.",
#                 "tags": [
#                     "User"
#                 ]
#             }
#         },
#         "/user/logout": {
#             "post": {
#                 "deprecated": false,
#                 "operationId": "User.logout",
#                 "parameters": [],
#                 "responses": {
#                     "200": {
#                         "description": "Request was successful",
#                         "schema": {
#                             "type": "null"
#                         }
#                     }
#                 },
#                 "security": [],
#                 "summary": "Log out of BitMEX.",
#                 "tags": [
#                     "User"
#                 ]
#             }
#         },
#         "/user/margin": {
#             "get": {
#                 "deprecated": false,
#                 "operationId": "User.getMargin",
#                 "parameters": [
#                     {
#                         "default": "XBt",
#                         "in": "query",
#                         "name": "currency",
#                         "required": false,
#                         "type": "string"
#                     }
#                 ],
#                 "responses": {
#                     "200": {
#                         "description": "Request was successful",
#                         "schema": {
#                             "$ref": "#/definitions/Margin"
#                         }
#                     }
#                 },
#                 "summary": "Get your account's margin status. Send a currency of \"all\" to receive an array of all supported currencies.",
#                 "tags": [
#                     "User"
#                 ]
#             }
#         },
#         "/user/minWithdrawalFee": {
#             "get": {
#                 "deprecated": false,
#                 "description": "This is changed based on network conditions to ensure timely withdrawals. During network congestion, this may be high. The fee is returned in the same currency.",
#                 "operationId": "User.minWithdrawalFee",
#                 "parameters": [
#                     {
#                         "default": "XBt",
#                         "in": "query",
#                         "name": "currency",
#                         "required": false,
#                         "type": "string"
#                     }
#                 ],
#                 "responses": {
#                     "200": {
#                         "description": "Request was successful",
#                         "schema": {
#                             "type": "object"
#                         }
#                     }
#                 },
#                 "security": [],
#                 "summary": "Get the minimum withdrawal fee for a currency.",
#                 "tags": [
#                     "User"
#                 ]
#             }
#         },
#         "/user/preferences": {
#             "post": {
#                 "deprecated": false,
#                 "operationId": "User.savePreferences",
#                 "parameters": [
#                     {
#                         "format": "JSON",
#                         "in": "formData",
#                         "name": "prefs",
#                         "required": true,
#                         "type": "string"
#                     },
#                     {
#                         "default": false,
#                         "description": "If true, will overwrite all existing preferences.",
#                         "in": "formData",
#                         "name": "overwrite",
#                         "required": false,
#                         "type": "boolean"
#                     }
#                 ],
#                 "responses": {
#                     "200": {
#                         "description": "Request was successful",
#                         "schema": {
#                             "$ref": "#/definitions/User"
#                         }
#                     }
#                 },
#                 "summary": "Save user preferences.",
#                 "tags": [
#                     "User"
#                 ]
#             }
#         },
#         "/user/requestWithdrawal": {
#             "post": {
#                 "deprecated": false,
#                 "description": "This will send a confirmation email to the email address on record.",
#                 "operationId": "User.requestWithdrawal",
#                 "parameters": [
#                     {
#                         "description": "2FA token. Required if 2FA is enabled on your account.",
#                         "in": "formData",
#                         "name": "otpToken",
#                         "required": false,
#                         "type": "string"
#                     },
#                     {
#                         "default": "XBt",
#                         "description": "Currency you're withdrawing. Options: `XBt`",
#                         "in": "formData",
#                         "name": "currency",
#                         "required": true,
#                         "type": "string"
#                     },
#                     {
#                         "description": "Amount of withdrawal currency.",
#                         "format": "int64",
#                         "in": "formData",
#                         "name": "amount",
#                         "required": true,
#                         "type": "number"
#                     },
#                     {
#                         "description": "Destination Address.",
#                         "in": "formData",
#                         "name": "address",
#                         "required": true,
#                         "type": "string"
#                     },
#                     {
#                         "description": "Network fee for Bitcoin withdrawals. If not specified, a default value will be calculated based on Bitcoin network conditions. You will have a chance to confirm this via email.",
#                         "format": "double",
#                         "in": "formData",
#                         "name": "fee",
#                         "required": false,
#                         "type": "number"
#                     },
#                     {
#                         "description": "Optional annotation, e.g. 'Transfer to home wallet'.",
#                         "in": "formData",
#                         "name": "text",
#                         "required": false,
#                         "type": "string"
#                     }
#                 ],
#                 "responses": {
#                     "200": {
#                         "description": "Request was successful",
#                         "schema": {
#                             "$ref": "#/definitions/Transaction"
#                         }
#                     }
#                 },
#                 "summary": "Request a withdrawal to an external wallet.",
#                 "tags": [
#                     "User"
#                 ]
#             }
#         },
#         "/user/wallet": {
#             "get": {
#                 "deprecated": false,
#                 "operationId": "User.getWallet",
#                 "parameters": [
#                     {
#                         "default": "XBt",
#                         "in": "query",
#                         "name": "currency",
#                         "required": false,
#                         "type": "string"
#                     }
#                 ],
#                 "responses": {
#                     "200": {
#                         "description": "Request was successful",
#                         "schema": {
#                             "$ref": "#/definitions/Wallet"
#                         }
#                     }
#                 },
#                 "summary": "Get your current wallet information.",
#                 "tags": [
#                     "User"
#                 ]
#             }
#         },
#         "/user/walletHistory": {
#             "get": {
#                 "deprecated": false,
#                 "operationId": "User.getWalletHistory",
#                 "parameters": [
#                     {
#                         "default": "XBt",
#                         "in": "query",
#                         "name": "currency",
#                         "required": false,
#                         "type": "string"
#                     },
#                     {
#                         "default": 100,
#                         "description": "Number of results to fetch.",
#                         "format": "double",
#                         "in": "query",
#                         "name": "count",
#                         "required": false,
#                         "type": "number"
#                     },
#                     {
#                         "default": 0,
#                         "description": "Starting point for results.",
#                         "format": "double",
#                         "in": "query",
#                         "name": "start",
#                         "required": false,
#                         "type": "number"
#                     }
#                 ],
#                 "responses": {
#                     "200": {
#                         "description": "Request was successful",
#                         "schema": {
#                             "items": {
#                                 "$ref": "#/definitions/Transaction"
#                             },
#                             "type": "array"
#                         }
#                     }
#                 },
#                 "summary": "Get a history of all of your wallet transactions (deposits, withdrawals, PNL).",
#                 "tags": [
#                     "User"
#                 ]
#             }
#         },
#         "/user/walletSummary": {
#             "get": {
#                 "deprecated": false,
#                 "operationId": "User.getWalletSummary",
#                 "parameters": [
#                     {
#                         "default": "XBt",
#                         "in": "query",
#                         "name": "currency",
#                         "required": false,
#                         "type": "string"
#                     }
#                 ],
#                 "responses": {
#                     "200": {
#                         "description": "Request was successful",
#                         "schema": {
#                             "items": {
#                                 "$ref": "#/definitions/Transaction"
#                             },
#                             "type": "array"
#                         }
#                     }
#                 },
#                 "summary": "Get a summary of all of your wallet transactions (deposits, withdrawals, PNL).",
#                 "tags": [
#                     "User"
#                 ]
#             }
#         },
#         "/userEvent": {
#             "get": {
#                 "deprecated": false,
#                 "operationId": "UserEvent.get",
#                 "parameters": [
#                     {
#                         "default": 150,
#                         "description": "Number of results to fetch.",
#                         "format": "double",
#                         "in": "query",
#                         "name": "count",
#                         "required": false,
#                         "type": "number"
#                     },
#                     {
#                         "description": "Cursor for pagination.",
#                         "format": "double",
#                         "in": "query",
#                         "name": "startId",
#                         "required": false,
#                         "type": "number"
#                     }
#                 ],
#                 "responses": {
#                     "200": {
#                         "description": "Request was successful",
#                         "schema": {
#                             "items": {
#                                 "$ref": "#/definitions/UserEvent"
#                             },
#                             "type": "array"
#                         }
#                     },
#                     "400": {
#                         "description": "Parameter Error",
#                         "schema": {
#                             "$ref": "#/definitions/Error"
#                         }
#                     },
#                     "401": {
#                         "description": "Unauthorized",
#                         "schema": {
#                             "$ref": "#/definitions/Error"
#                         }
#                     },
#                     "403": {
#                         "description": "Access Denied",
#                         "schema": {
#                             "$ref": "#/definitions/Error"
#                         }
#                     },
#                     "404": {
#                         "description": "Not Found",
#                         "schema": {
#                             "$ref": "#/definitions/Error"
#                         }
#                     }
#                 },
#                 "summary": "Get your user events",
#                 "tags": [
#                     "UserEvent"
#                 ]
#             }
#         }
#     },
#     "produces": [
#         "application/json",
#         "application/xml",
#         "text/xml",
#         "application/javascript",
#         "text/javascript"
#     ],
#     "security": [
#         {
#             "apiExpires": [],
#             "apiKey": [],
#             "apiSignature": []
#         }
#     ],
#     "securityDefinitions": {
#         "apiExpires": {
#             "in": "header",
#             "name": "api-expires",
#             "type": "apiKey"
#         },
#         "apiKey": {
#             "in": "header",
#             "name": "api-key",
#             "type": "apiKey"
#         },
#         "apiSignature": {
#             "in": "header",
#             "name": "api-signature",
#             "type": "apiKey"
#         }
#     },
#     "swagger": "2.0",
#     "tags": [
#         {
#             "description": "Public Announcements",
#             "name": "Announcement"
#         },
#         {
#             "description": "Persistent API Keys for Developers",
#             "name": "APIKey"
#         },
#         {
#             "description": "Trollbox Data",
#             "name": "Chat"
#         },
#         {
#             "description": "Raw Order and Balance Data",
#             "name": "Execution"
#         },
#         {
#             "description": "Swap Funding History",
#             "name": "Funding"
#         },
#         {
#             "description": "Tradeable Contracts, Indices, and History",
#             "name": "Instrument"
#         },
#         {
#             "description": "Insurance Fund Data",
#             "name": "Insurance"
#         },
#         {
#             "description": "Information on Top Users",
#             "name": "Leaderboard"
#         },
#         {
#             "description": "Active Liquidations",
#             "name": "Liquidation"
#         },
#         {
#             "description": "Account Notifications",
#             "name": "GlobalNotification"
#         },
#         {
#             "description": "Placement, Cancellation, Amending, and History",
#             "name": "Order"
#         },
#         {
#             "description": "Level 2 Book Data",
#             "name": "OrderBook"
#         },
#         {
#             "description": "Summary of Open and Closed Positions",
#             "name": "Position"
#         },
#         {
#             "description": "Best Bid/Offer Snapshots & Historical Bins",
#             "name": "Quote"
#         },
#         {
#             "description": "Dynamic Schemata for Developers",
#             "name": "Schema"
#         },
#         {
#             "description": "Historical Settlement Data",
#             "name": "Settlement"
#         },
#         {
#             "description": "Exchange Statistics",
#             "name": "Stats"
#         },
#         {
#             "description": "Individual & Bucketed Trades",
#             "name": "Trade"
#         },
#         {
#             "description": "Account Operations",
#             "name": "User"
#         },
#         {
#             "description": "User Events for auditing",
#             "name": "UserEvent"
#         }
#     ]
# }

# %% [markdown]
# ## Pull Data from BitMEX API

# %% [markdown]
# - The API supports fetching full data for one or multiple instruments. <br>
# - "reverse=True" returns the newest results, remove to return the oldest results <br>
# - BitMEX API returns a maximum of 500 results per request. The default number of results is 100. (use "count = 500")
# - To get more than 500 requests, use "start=500"

# %% [markdown]
# ### Get funding data:

# %%
# filters
target_symbol = "XBTUSD"


# set up a parameters dictionary
params = {
    "symbol": target_symbol,
    "key": API_KEY,
    "count": 500,
    "reverse": True
}

# base url
base_url = "https://www.bitmex.com/api/v1/funding"

# run a request using our params dictionary
response = requests.get(base_url, params=params)

# %%
# convert response to json
Funding_data = response.json()

# %%
# create data frame
Funding_data_df = pd.DataFrame(Funding_data)

# view data frame
Funding_data_df
# Out:
#               fundingInterval  fundingRate  fundingRateDaily  symbol  \
# 0    2000-01-01T08:00:00.000Z     0.000499          0.001497  XBTUSD
# 1    2000-01-01T08:00:00.000Z     0.000810          0.002430  XBTUSD
# 2    2000-01-01T08:00:00.000Z     0.000526          0.001578  XBTUSD
# 3    2000-01-01T08:00:00.000Z     0.000387          0.001161  XBTUSD
# 4    2000-01-01T08:00:00.000Z     0.000111          0.000333  XBTUSD
# 5    2000-01-01T08:00:00.000Z     0.001083          0.003249  XBTUSD
# 6    2000-01-01T08:00:00.000Z     0.001809          0.005427  XBTUSD
# 7    2000-01-01T08:00:00.000Z     0.000635          0.001905  XBTUSD
# 8    2000-01-01T08:00:00.000Z     0.000591          0.001773  XBTUSD
# 9    2000-01-01T08:00:00.000Z     0.000211          0.000633  XBTUSD
# 10   2000-01-01T08:00:00.000Z     0.000100          0.000300  XBTUSD
# 11   2000-01-01T08:00:00.000Z    -0.000116         -0.000348  XBTUSD
# 12   2000-01-01T08:00:00.000Z     0.000100          0.000300  XBTUSD
# 13   2000-01-01T08:00:00.000Z     0.000100          0.000300  XBTUSD
# 14   2000-01-01T08:00:00.000Z     0.000100          0.000300  XBTUSD
# 15   2000-01-01T08:00:00.000Z     0.000100          0.000300  XBTUSD
# 16   2000-01-01T08:00:00.000Z     0.000100          0.000300  XBTUSD
# 17   2000-01-01T08:00:00.000Z     0.000100          0.000300  XBTUSD
# 18   2000-01-01T08:00:00.000Z     0.000100          0.000300  XBTUSD
# 19   2000-01-01T08:00:00.000Z     0.000100          0.000300  XBTUSD
# 20   2000-01-01T08:00:00.000Z     0.000001          0.000003  XBTUSD
# 21   2000-01-01T08:00:00.000Z     0.000100          0.000300  XBTUSD
# 22   2000-01-01T08:00:00.000Z     0.000100          0.000300  XBTUSD
# 23   2000-01-01T08:00:00.000Z     0.000100          0.000300  XBTUSD
# 24   2000-01-01T08:00:00.000Z    -0.000070         -0.000210  XBTUSD
# 25   2000-01-01T08:00:00.000Z    -0.000455         -0.001365  XBTUSD
# 26   2000-01-01T08:00:00.000Z    -0.000536         -0.001608  XBTUSD
# 27   2000-01-01T08:00:00.000Z    -0.000088         -0.000264  XBTUSD
# 28   2000-01-01T08:00:00.000Z     0.000010          0.000030  XBTUSD
# 29   2000-01-01T08:00:00.000Z     0.000100          0.000300  XBTUSD
# ..                        ...          ...               ...     ...
# 470  2000-01-01T08:00:00.000Z    -0.000249         -0.000747  XBTUSD
# 471  2000-01-01T08:00:00.000Z    -0.000234         -0.000702  XBTUSD
# 472  2000-01-01T08:00:00.000Z    -0.000997         -0.002991  XBTUSD
# 473  2000-01-01T08:00:00.000Z    -0.001256         -0.003768  XBTUSD
# 474  2000-01-01T08:00:00.000Z    -0.000778         -0.002334  XBTUSD
# 475  2000-01-01T08:00:00.000Z    -0.001344         -0.004032  XBTUSD
# 476  2000-01-01T08:00:00.000Z    -0.001079         -0.003237  XBTUSD
# 477  2000-01-01T08:00:00.000Z    -0.000434         -0.001302  XBTUSD
# 478  2000-01-01T08:00:00.000Z    -0.000069         -0.000207  XBTUSD
# 479  2000-01-01T08:00:00.000Z     0.000100          0.000300  XBTUSD
# 480  2000-01-01T08:00:00.000Z     0.000100          0.000300  XBTUSD
# 481  2000-01-01T08:00:00.000Z    -0.000053         -0.000159  XBTUSD
# 482  2000-01-01T08:00:00.000Z    -0.000406         -0.001218  XBTUSD
# 483  2000-01-01T08:00:00.000Z     0.000100          0.000300  XBTUSD
# 484  2000-01-01T08:00:00.000Z     0.000025          0.000075  XBTUSD
# 485  2000-01-01T08:00:00.000Z    -0.000013         -0.000039  XBTUSD
# 486  2000-01-01T08:00:00.000Z     0.000100          0.000300  XBTUSD
# 487  2000-01-01T08:00:00.000Z     0.000100          0.000300  XBTUSD
# 488  2000-01-01T08:00:00.000Z     0.000044          0.000132  XBTUSD
# 489  2000-01-01T08:00:00.000Z    -0.000341         -0.001023  XBTUSD
# 490  2000-01-01T08:00:00.000Z    -0.000450         -0.001350  XBTUSD
# 491  2000-01-01T08:00:00.000Z    -0.000165         -0.000495  XBTUSD
# 492  2000-01-01T08:00:00.000Z     0.000061          0.000183  XBTUSD
# 493  2000-01-01T08:00:00.000Z    -0.000259         -0.000777  XBTUSD
# 494  2000-01-01T08:00:00.000Z    -0.000078         -0.000234  XBTUSD
# 495  2000-01-01T08:00:00.000Z     0.000036          0.000108  XBTUSD
# 496  2000-01-01T08:00:00.000Z    -0.000001         -0.000003  XBTUSD
# 497  2000-01-01T08:00:00.000Z    -0.000012         -0.000036  XBTUSD
# 498  2000-01-01T08:00:00.000Z    -0.000246         -0.000738  XBTUSD
# 499  2000-01-01T08:00:00.000Z    -0.000467         -0.001401  XBTUSD
#
#                     timestamp
# 0    2019-06-18T20:00:00.000Z
# 1    2019-06-18T12:00:00.000Z
# 2    2019-06-18T04:00:00.000Z
# 3    2019-06-17T20:00:00.000Z
# 4    2019-06-17T12:00:00.000Z
# 5    2019-06-17T04:00:00.000Z
# 6    2019-06-16T20:00:00.000Z
# 7    2019-06-16T12:00:00.000Z
# 8    2019-06-16T04:00:00.000Z
# 9    2019-06-15T20:00:00.000Z
# 10   2019-06-15T12:00:00.000Z
# 11   2019-06-15T04:00:00.000Z
# 12   2019-06-14T20:00:00.000Z
# 13   2019-06-14T12:00:00.000Z
# 14   2019-06-14T04:00:00.000Z
# 15   2019-06-13T20:00:00.000Z
# 16   2019-06-13T12:00:00.000Z
# 17   2019-06-13T04:00:00.000Z
# 18   2019-06-12T20:00:00.000Z
# 19   2019-06-12T12:00:00.000Z
# 20   2019-06-12T04:00:00.000Z
# 21   2019-06-11T20:00:00.000Z
# 22   2019-06-11T12:00:00.000Z
# 23   2019-06-11T04:00:00.000Z
# 24   2019-06-10T20:00:00.000Z
# 25   2019-06-10T12:00:00.000Z
# 26   2019-06-10T04:00:00.000Z
# 27   2019-06-09T20:00:00.000Z
# 28   2019-06-09T12:00:00.000Z
# 29   2019-06-09T04:00:00.000Z
# ..                        ...
# 470  2019-01-13T04:00:00.000Z
# 471  2019-01-12T20:00:00.000Z
# 472  2019-01-12T12:00:00.000Z
# 473  2019-01-12T04:00:00.000Z
# 474  2019-01-11T20:00:00.000Z
# 475  2019-01-11T12:00:00.000Z
# 476  2019-01-11T04:00:00.000Z
# 477  2019-01-10T20:00:00.000Z
# 478  2019-01-10T12:00:00.000Z
# 479  2019-01-10T04:00:00.000Z
# 480  2019-01-09T20:00:00.000Z
# 481  2019-01-09T12:00:00.000Z
# 482  2019-01-09T04:00:00.000Z
# 483  2019-01-08T20:00:00.000Z
# 484  2019-01-08T12:00:00.000Z
# 485  2019-01-08T04:00:00.000Z
# 486  2019-01-07T20:00:00.000Z
# 487  2019-01-07T12:00:00.000Z
# 488  2019-01-07T04:00:00.000Z
# 489  2019-01-06T20:00:00.000Z
# 490  2019-01-06T12:00:00.000Z
# 491  2019-01-06T04:00:00.000Z
# 492  2019-01-05T20:00:00.000Z
# 493  2019-01-05T12:00:00.000Z
# 494  2019-01-05T04:00:00.000Z
# 495  2019-01-04T20:00:00.000Z
# 496  2019-01-04T12:00:00.000Z
# 497  2019-01-04T04:00:00.000Z
# 498  2019-01-03T20:00:00.000Z
# 499  2019-01-03T12:00:00.000Z
#
# [500 rows x 5 columns]

# %%
# Print the json (pretty printed)
print(json.dumps(Funding_data, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.000499,
#         "fundingRateDaily": 0.001497,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-18T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.00081,
#         "fundingRateDaily": 0.00243,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-18T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.000526,
#         "fundingRateDaily": 0.001578,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-18T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.000387,
#         "fundingRateDaily": 0.001161,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-17T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.000111,
#         "fundingRateDaily": 0.000333,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-17T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.001083,
#         "fundingRateDaily": 0.003249,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-17T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.001809,
#         "fundingRateDaily": 0.005427,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-16T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.000635,
#         "fundingRateDaily": 0.001905,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-16T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.000591,
#         "fundingRateDaily": 0.0017730000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-16T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.000211,
#         "fundingRateDaily": 0.000633,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-15T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-15T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000116,
#         "fundingRateDaily": -0.000348,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-15T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-14T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-14T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-14T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-13T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-13T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-13T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-12T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-12T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 1e-06,
#         "fundingRateDaily": 3e-06,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-12T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-11T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-11T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-11T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -7e-05,
#         "fundingRateDaily": -0.00020999999999999998,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-10T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000455,
#         "fundingRateDaily": -0.001365,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-10T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000536,
#         "fundingRateDaily": -0.001608,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-10T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -8.8e-05,
#         "fundingRateDaily": -0.000264,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-09T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 1e-05,
#         "fundingRateDaily": 3.0000000000000004e-05,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-09T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-09T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -5.7e-05,
#         "fundingRateDaily": -0.000171,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-08T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000237,
#         "fundingRateDaily": -0.0007109999999999999,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-08T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 5.2e-05,
#         "fundingRateDaily": 0.000156,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-08T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-07T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-07T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000125,
#         "fundingRateDaily": -0.000375,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-07T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -5.7e-05,
#         "fundingRateDaily": -0.000171,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-06T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000162,
#         "fundingRateDaily": -0.000486,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-06T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -5.9e-05,
#         "fundingRateDaily": -0.000177,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-06T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-05T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 5.4e-05,
#         "fundingRateDaily": 0.00016199999999999998,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-05T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -2.8e-05,
#         "fundingRateDaily": -8.4e-05,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-05T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -1.8e-05,
#         "fundingRateDaily": -5.4e-05,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-04T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-04T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-04T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-03T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.000176,
#         "fundingRateDaily": 0.000528,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-03T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.000438,
#         "fundingRateDaily": 0.001314,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-03T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.000601,
#         "fundingRateDaily": 0.001803,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-02T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-02T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.000372,
#         "fundingRateDaily": 0.001116,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-02T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-01T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.000141,
#         "fundingRateDaily": 0.00042300000000000004,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-01T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.000116,
#         "fundingRateDaily": 0.000348,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-06-01T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-31T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-31T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.000339,
#         "fundingRateDaily": 0.0010170000000000001,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-31T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.001131,
#         "fundingRateDaily": 0.003393,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-30T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.000515,
#         "fundingRateDaily": 0.0015450000000000001,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-30T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.00082,
#         "fundingRateDaily": 0.00246,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-30T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.000753,
#         "fundingRateDaily": 0.0022589999999999997,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-29T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.000726,
#         "fundingRateDaily": 0.002178,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-29T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.001224,
#         "fundingRateDaily": 0.003672,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-29T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.001543,
#         "fundingRateDaily": 0.004629,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-28T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.001425,
#         "fundingRateDaily": 0.004275,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-28T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.001267,
#         "fundingRateDaily": 0.0038009999999999997,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-28T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.001734,
#         "fundingRateDaily": 0.005202,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-27T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.00298,
#         "fundingRateDaily": 0.00894,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-27T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.000608,
#         "fundingRateDaily": 0.001824,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-27T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.000416,
#         "fundingRateDaily": 0.001248,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-26T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.000684,
#         "fundingRateDaily": 0.002052,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-26T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.00041,
#         "fundingRateDaily": 0.00123,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-26T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.00071,
#         "fundingRateDaily": 0.00213,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-25T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.000488,
#         "fundingRateDaily": 0.001464,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-25T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.00059,
#         "fundingRateDaily": 0.00177,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-25T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.000159,
#         "fundingRateDaily": 0.000477,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-24T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-24T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-24T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-23T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-23T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-23T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.000375,
#         "fundingRateDaily": 0.0011250000000000001,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-22T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.000407,
#         "fundingRateDaily": 0.001221,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-22T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-22T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.000302,
#         "fundingRateDaily": 0.0009060000000000001,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-21T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.000177,
#         "fundingRateDaily": 0.000531,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-21T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-21T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.000329,
#         "fundingRateDaily": 0.000987,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-20T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.000265,
#         "fundingRateDaily": 0.0007949999999999999,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-20T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.000187,
#         "fundingRateDaily": 0.000561,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-20T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.000386,
#         "fundingRateDaily": 0.001158,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-19T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -8.9e-05,
#         "fundingRateDaily": -0.000267,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-19T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000271,
#         "fundingRateDaily": -0.0008129999999999999,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-19T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000118,
#         "fundingRateDaily": -0.000354,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-18T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.00014,
#         "fundingRateDaily": -0.00041999999999999996,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-18T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-18T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-17T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.000658,
#         "fundingRateDaily": 0.001974,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-17T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.000312,
#         "fundingRateDaily": 0.000936,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-17T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.000701,
#         "fundingRateDaily": 0.002103,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-16T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.000198,
#         "fundingRateDaily": 0.0005939999999999999,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-16T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-16T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.000347,
#         "fundingRateDaily": 0.0010409999999999998,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-15T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-15T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-15T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.000276,
#         "fundingRateDaily": 0.000828,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-14T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.000234,
#         "fundingRateDaily": 0.0007019999999999999,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-14T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-14T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-13T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-13T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-13T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-12T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-12T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-12T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -8.8e-05,
#         "fundingRateDaily": -0.000264,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-11T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000692,
#         "fundingRateDaily": -0.002076,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-11T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000942,
#         "fundingRateDaily": -0.002826,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-11T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.001058,
#         "fundingRateDaily": -0.0031739999999999997,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-10T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.001462,
#         "fundingRateDaily": -0.004386,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-10T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.001063,
#         "fundingRateDaily": -0.003189,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-10T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000496,
#         "fundingRateDaily": -0.0014880000000000002,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-09T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000709,
#         "fundingRateDaily": -0.002127,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-09T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.001053,
#         "fundingRateDaily": -0.0031589999999999995,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-09T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000821,
#         "fundingRateDaily": -0.002463,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-08T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000758,
#         "fundingRateDaily": -0.002274,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-08T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000151,
#         "fundingRateDaily": -0.00045300000000000006,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-08T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-07T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 1e-06,
#         "fundingRateDaily": 3e-06,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-07T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000649,
#         "fundingRateDaily": -0.001947,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-07T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000174,
#         "fundingRateDaily": -0.000522,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-06T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.00036,
#         "fundingRateDaily": -0.00108,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-06T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000295,
#         "fundingRateDaily": -0.000885,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-06T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-05T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -3.5e-05,
#         "fundingRateDaily": -0.00010499999999999999,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-05T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.001147,
#         "fundingRateDaily": -0.003441,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-05T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000164,
#         "fundingRateDaily": -0.000492,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-04T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000144,
#         "fundingRateDaily": -0.000432,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-04T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-04T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 9.2e-05,
#         "fundingRateDaily": 0.000276,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-03T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.00053,
#         "fundingRateDaily": -0.0015899999999999998,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-03T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.001068,
#         "fundingRateDaily": -0.003204,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-03T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000232,
#         "fundingRateDaily": -0.000696,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-02T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000372,
#         "fundingRateDaily": -0.001116,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-02T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000669,
#         "fundingRateDaily": -0.002007,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-02T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000317,
#         "fundingRateDaily": -0.000951,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-01T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000688,
#         "fundingRateDaily": -0.002064,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-01T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000679,
#         "fundingRateDaily": -0.002037,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-05-01T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000377,
#         "fundingRateDaily": -0.001131,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-30T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000648,
#         "fundingRateDaily": -0.001944,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-30T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000589,
#         "fundingRateDaily": -0.001767,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-30T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000788,
#         "fundingRateDaily": -0.0023639999999999998,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-29T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000297,
#         "fundingRateDaily": -0.0008910000000000001,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-29T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000617,
#         "fundingRateDaily": -0.0018510000000000002,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-29T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000627,
#         "fundingRateDaily": -0.0018809999999999999,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-28T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000859,
#         "fundingRateDaily": -0.002577,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-28T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000232,
#         "fundingRateDaily": -0.000696,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-28T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000415,
#         "fundingRateDaily": -0.001245,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-27T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000721,
#         "fundingRateDaily": -0.002163,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-27T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000365,
#         "fundingRateDaily": -0.001095,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-27T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000233,
#         "fundingRateDaily": -0.000699,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-26T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000974,
#         "fundingRateDaily": -0.002922,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-26T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -8.1e-05,
#         "fundingRateDaily": -0.000243,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-26T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000301,
#         "fundingRateDaily": -0.0009029999999999999,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-25T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000249,
#         "fundingRateDaily": -0.0007469999999999999,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-25T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000129,
#         "fundingRateDaily": -0.000387,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-25T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -8.1e-05,
#         "fundingRateDaily": -0.000243,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-24T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000488,
#         "fundingRateDaily": -0.001464,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-24T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000617,
#         "fundingRateDaily": -0.0018510000000000002,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-24T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000506,
#         "fundingRateDaily": -0.0015180000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-23T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000177,
#         "fundingRateDaily": -0.000531,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-23T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-23T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-22T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 4.4e-05,
#         "fundingRateDaily": 0.000132,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-22T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-22T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-21T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-21T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -7.6e-05,
#         "fundingRateDaily": -0.000228,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-21T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-20T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-20T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -6.7e-05,
#         "fundingRateDaily": -0.000201,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-20T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -7.4e-05,
#         "fundingRateDaily": -0.00022199999999999998,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-19T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 7.2e-05,
#         "fundingRateDaily": 0.000216,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-19T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-19T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-18T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-18T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-18T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-17T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-17T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-17T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -4.5e-05,
#         "fundingRateDaily": -0.000135,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-16T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000286,
#         "fundingRateDaily": -0.000858,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-16T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-16T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-15T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-15T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 7.3e-05,
#         "fundingRateDaily": 0.000219,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-15T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-14T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 2.9e-05,
#         "fundingRateDaily": 8.7e-05,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-14T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -5.4e-05,
#         "fundingRateDaily": -0.00016199999999999998,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-14T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000207,
#         "fundingRateDaily": -0.000621,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-13T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -5.8e-05,
#         "fundingRateDaily": -0.000174,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-13T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 8.4e-05,
#         "fundingRateDaily": 0.000252,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-13T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-12T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-12T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-12T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-11T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000263,
#         "fundingRateDaily": -0.000789,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-11T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-11T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-10T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-10T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-10T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-09T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-09T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000136,
#         "fundingRateDaily": -0.000408,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-09T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-08T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-08T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-04-08T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
# ...
#         "timestamp": "2019-01-27T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000218,
#         "fundingRateDaily": -0.0006540000000000001,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-27T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-26T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000255,
#         "fundingRateDaily": -0.0007650000000000001,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-26T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000593,
#         "fundingRateDaily": -0.001779,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-26T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -5e-05,
#         "fundingRateDaily": -0.00015000000000000001,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-25T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -5.1e-05,
#         "fundingRateDaily": -0.000153,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-25T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000147,
#         "fundingRateDaily": -0.000441,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-25T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 8e-05,
#         "fundingRateDaily": 0.00024000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-24T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000169,
#         "fundingRateDaily": -0.000507,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-24T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000501,
#         "fundingRateDaily": -0.001503,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-24T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 7.5e-05,
#         "fundingRateDaily": 0.000225,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-23T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -4.3e-05,
#         "fundingRateDaily": -0.000129,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-23T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000691,
#         "fundingRateDaily": -0.002073,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-23T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 1e-06,
#         "fundingRateDaily": 3e-06,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-22T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000398,
#         "fundingRateDaily": -0.0011940000000000002,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-22T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000298,
#         "fundingRateDaily": -0.0008939999999999999,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-22T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -5.9e-05,
#         "fundingRateDaily": -0.000177,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-21T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000597,
#         "fundingRateDaily": -0.001791,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-21T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.001171,
#         "fundingRateDaily": -0.0035129999999999996,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-21T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-20T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-20T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-20T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-19T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000131,
#         "fundingRateDaily": -0.000393,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-19T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000321,
#         "fundingRateDaily": -0.000963,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-19T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-18T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000174,
#         "fundingRateDaily": -0.000522,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-18T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000413,
#         "fundingRateDaily": -0.001239,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-18T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000277,
#         "fundingRateDaily": -0.000831,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-17T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000136,
#         "fundingRateDaily": -0.000408,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-17T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 8e-05,
#         "fundingRateDaily": 0.00024000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-17T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000252,
#         "fundingRateDaily": -0.0007559999999999999,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-16T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000231,
#         "fundingRateDaily": -0.000693,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-16T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -2.8e-05,
#         "fundingRateDaily": -8.4e-05,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-16T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 5.5e-05,
#         "fundingRateDaily": 0.000165,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-15T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000306,
#         "fundingRateDaily": -0.000918,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-15T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000156,
#         "fundingRateDaily": -0.000468,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-15T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000252,
#         "fundingRateDaily": -0.0007559999999999999,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-14T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-14T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-14T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.00023,
#         "fundingRateDaily": -0.0006900000000000001,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-13T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000397,
#         "fundingRateDaily": -0.001191,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-13T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000249,
#         "fundingRateDaily": -0.0007469999999999999,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-13T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000234,
#         "fundingRateDaily": -0.0007019999999999999,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-12T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000997,
#         "fundingRateDaily": -0.002991,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-12T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.001256,
#         "fundingRateDaily": -0.0037679999999999996,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-12T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000778,
#         "fundingRateDaily": -0.002334,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-11T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.001344,
#         "fundingRateDaily": -0.004032,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-11T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.001079,
#         "fundingRateDaily": -0.0032370000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-11T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000434,
#         "fundingRateDaily": -0.001302,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-10T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -6.9e-05,
#         "fundingRateDaily": -0.000207,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-10T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-10T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-09T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -5.3e-05,
#         "fundingRateDaily": -0.00015900000000000002,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-09T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000406,
#         "fundingRateDaily": -0.001218,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-09T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-08T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 2.5e-05,
#         "fundingRateDaily": 7.500000000000001e-05,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-08T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -1.3e-05,
#         "fundingRateDaily": -3.9e-05,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-08T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-07T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 0.0001,
#         "fundingRateDaily": 0.00030000000000000003,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-07T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 4.4e-05,
#         "fundingRateDaily": 0.000132,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-07T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000341,
#         "fundingRateDaily": -0.001023,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-06T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.00045,
#         "fundingRateDaily": -0.00135,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-06T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000165,
#         "fundingRateDaily": -0.000495,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-06T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 6.1e-05,
#         "fundingRateDaily": 0.000183,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-05T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000259,
#         "fundingRateDaily": -0.000777,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-05T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -7.8e-05,
#         "fundingRateDaily": -0.000234,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-05T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": 3.6e-05,
#         "fundingRateDaily": 0.000108,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-04T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -1e-06,
#         "fundingRateDaily": -3e-06,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-04T12:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -1.2e-05,
#         "fundingRateDaily": -3.6e-05,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-04T04:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000246,
#         "fundingRateDaily": -0.000738,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-03T20:00:00.000Z"
#     },
#     {
#         "fundingInterval": "2000-01-01T08:00:00.000Z",
#         "fundingRate": -0.000467,
#         "fundingRateDaily": -0.0014010000000000001,
#         "symbol": "XBTUSD",
#         "timestamp": "2019-01-03T12:00:00.000Z"
#     }
# ]

# %% [markdown]
# ### Get instrament data:

# %%
# set symbol and number of results to pull
root_symbol = 'XBT'

# %%
# set symbol and number of results to pull
start_count = range(0, 501, 500)

# for i in start_count:
#     print(i)

# %%
# Create a python dictionary
XBT_data = []

# Create a python dictionary
for i in start_count:
    try:
        XBT_data_i = test_client.Instrument.Instrument_get(count=500, start=start_count[i], reverse=True, filter=json.dumps({'rootSymbol': root_symbol})).result()
        XBT_data.append(XBT_data_i)
    except(ValueError, KeyError, IndexError):
        print("Missing field/result... skipping.")
     
    time.sleep(1)
    print("------------")

len(XBT_data)
# Out:
# ------------
# Missing field/result... skipping.
# ------------
# 1

# %%
# view data
XBT_data
# Out:
# [([{'symbol': 'XBTZ19',
#     'rootSymbol': 'XBT',
#     'state': 'Open',
#     'typ': 'FFCCSX',
#     'listing': datetime.datetime(2019, 6, 13, 6, 0, tzinfo=tzutc()),
#     'front': datetime.datetime(2019, 10, 25, 12, 0, tzinfo=tzutc()),
#     'expiry': datetime.datetime(2019, 12, 27, 12, 0, tzinfo=tzutc()),
#     'settle': datetime.datetime(2019, 12, 27, 12, 0, tzinfo=tzutc()),
#     'relistInterval': None,
#     'inverseLeg': '',
#     'sellLeg': '',
#     'buyLeg': '',
#     'optionStrikePcnt': None,
#     'optionStrikeRound': None,
#     'optionStrikePrice': None,
#     'optionMultiplier': None,
#     'positionCurrency': 'USD',
#     'underlying': 'XBT',
#     'quoteCurrency': 'USD',
#     'underlyingSymbol': 'XBT=',
#     'reference': 'BMEX',
#     'referenceSymbol': '.BXBT30M',
#     'calcInterval': None,
#     'publishInterval': None,
#     'publishTime': None,
#     'maxOrderQty': 10000000,
#     'maxPrice': 1000000.0,
#     'lotSize': 1,
#     'tickSize': 0.5,
#     'multiplier': -100000000,
#     'settlCurrency': 'XBt',
#     'underlyingToPositionMultiplier': None,
#     'underlyingToSettleMultiplier': -100000000,
#     'quoteToSettleMultiplier': None,
#     'isQuanto': False,
#     'isInverse': True,
#     'initMargin': 0.01,
#     'maintMargin': 0.005,
#     'riskLimit': 5000000000,
#     'riskStep': 5000000000,
#     'limit': None,
#     'capped': False,
#     'taxed': True,
#     'deleverage': True,
#     'makerFee': -0.00025,
#     'takerFee': 0.00075,
#     'settlementFee': 0.0005,
#     'insuranceFee': 0.0,
#     'fundingBaseSymbol': '',
#     'fundingQuoteSymbol': '',
#     'fundingPremiumSymbol': '',
#     'fundingTimestamp': None,
#     'fundingInterval': None,
#     'fundingRate': None,
#     'indicativeFundingRate': None,
#     'rebalanceTimestamp': None,
#     'rebalanceInterval': None,
#     'openingTimestamp': datetime.datetime(2019, 6, 19, 2, 0, tzinfo=tzutc()),
#     'closingTimestamp': datetime.datetime(2019, 6, 19, 3, 0, tzinfo=tzutc()),
#     'sessionInterval': datetime.datetime(2000, 1, 1, 1, 0, tzinfo=tzutc()),
#     'prevClosePrice': 9997.73,
#     'limitDownPrice': None,
#     'limitUpPrice': None,
#     'bankruptLimitDownPrice': None,
#     'bankruptLimitUpPrice': None,
#     'prevTotalVolume': 4910574,
#     'totalVolume': 4910578,
#     'volume': 4,
#     'volume24h': 74700,
#     'prevTotalTurnover': 53922129743,
#     'totalTurnover': 53922173223,
#     'turnover': 43480,
#     'turnover24h': 812256886,
#     'homeNotional24h': 8.122568860000001,
#     'foreignNotional24h': 74700.0,
#     'prevPrice24h': 9200.0,
#     'vwap': 9197.0937,
#     'highPrice': 9200.0,
#     'lowPrice': 8580.0,
#     'lastPrice': 9200.0,
#     'lastPriceProtected': 9711.17,
#     'lastTickDirection': 'ZeroPlusTick',
#     'lastChangePcnt': 0.0,
#     'bidPrice': 9199.5,
#     'midPrice': 9199.75,
#     'askPrice': 9200.0,
#     'impactBidPrice': 8547.7391,
#     'impactMidPrice': 8926.0,
#     'impactAskPrice': 9304.0566,
#     'hasLiquidity': False,
#     'openInterest': 4566412,
#     'openValue': 45828510832,
#     'fairMethod': 'ImpactMidPrice',
#     'fairBasisRate': 0.17,
#     'fairBasis': 815.57,
#     'fairPrice': 9964.0,
#     'markMethod': 'FairPrice',
#     'markPrice': 9964.0,
#     'indicativeTaxRate': 0.0,
#     'indicativeSettlePrice': 9148.43,
#     'optionUnderlyingPrice': None,
#     'settledPrice': None,
#     'timestamp': datetime.datetime(2019, 6, 19, 2, 12, 50, tzinfo=tzutc())},
#    {'symbol': 'XBTU19',
#     'rootSymbol': 'XBT',
#     'state': 'Open',
#     'typ': 'FFCCSX',
#     'listing': datetime.datetime(2019, 3, 13, 9, 0, tzinfo=tzutc()),
#     'front': datetime.datetime(2019, 7, 26, 12, 0, tzinfo=tzutc()),
#     'expiry': datetime.datetime(2019, 9, 27, 12, 0, tzinfo=tzutc()),
#     'settle': datetime.datetime(2019, 9, 27, 12, 0, tzinfo=tzutc()),
#     'relistInterval': None,
#     'inverseLeg': '',
#     'sellLeg': '',
#     'buyLeg': '',
#     'optionStrikePcnt': None,
#     'optionStrikeRound': None,
#     'optionStrikePrice': None,
#     'optionMultiplier': None,
#     'positionCurrency': 'USD',
#     'underlying': 'XBT',
#     'quoteCurrency': 'USD',
#     'underlyingSymbol': 'XBT=',
#     'reference': 'BMEX',
#     'referenceSymbol': '.BXBT30M',
#     'calcInterval': None,
#     'publishInterval': None,
#     'publishTime': None,
#     'maxOrderQty': 10000000,
#     'maxPrice': 1000000.0,
#     'lotSize': 1,
#     'tickSize': 0.5,
#     'multiplier': -100000000,
#     'settlCurrency': 'XBt',
#     'underlyingToPositionMultiplier': None,
#     'underlyingToSettleMultiplier': -100000000,
#     'quoteToSettleMultiplier': None,
#     'isQuanto': False,
#     'isInverse': True,
#     'initMargin': 0.01,
#     'maintMargin': 0.005,
#     'riskLimit': 5000000000,
#     'riskStep': 5000000000,
#     'limit': None,
#     'capped': False,
#     'taxed': True,
#     'deleverage': True,
#     'makerFee': -0.00025,
#     'takerFee': 0.00075,
#     'settlementFee': 0.0005,
#     'insuranceFee': 0.0,
#     'fundingBaseSymbol': '',
#     'fundingQuoteSymbol': '',
#     'fundingPremiumSymbol': '',
#     'fundingTimestamp': None,
#     'fundingInterval': None,
#     'fundingRate': None,
#     'indicativeFundingRate': None,
#     'rebalanceTimestamp': None,
#     'rebalanceInterval': None,
#     'openingTimestamp': datetime.datetime(2019, 6, 19, 2, 0, tzinfo=tzutc()),
#     'closingTimestamp': datetime.datetime(2019, 6, 19, 3, 0, tzinfo=tzutc()),
#     'sessionInterval': datetime.datetime(2000, 1, 1, 1, 0, tzinfo=tzutc()),
#     'prevClosePrice': 9659.56,
#     'limitDownPrice': None,
#     'limitUpPrice': None,
#     'bankruptLimitDownPrice': None,
#     'bankruptLimitUpPrice': None,
#     'prevTotalVolume': 145781226,
#     'totalVolume': 145781249,
#     'volume': 23,
#     'volume24h': 1977620,
#     'prevTotalTurnover': 1854715350129,
#     'totalTurnover': 1854715602876,
#     'turnover': 252747,
#     'turnover24h': 22201371376,
#     'homeNotional24h': 222.0137137600001,
#     'foreignNotional24h': 1977620.0,
#     'prevPrice24h': 9599.5,
#     'vwap': 8907.8924,
#     'highPrice': 10240.0,
#     'lowPrice': 7547.5,
#     'lastPrice': 9100.0,
#     'lastPriceProtected': 9489.46,
#     'lastTickDirection': 'ZeroMinusTick',
#     'lastChangePcnt': -0.052,
#     'bidPrice': 8511.0,
#     'midPrice': 8805.5,
#     'askPrice': 9100.0,
#     'impactBidPrice': 8352.8233,
#     'impactMidPrice': 8749.25,
#     'impactAskPrice': 9145.7838,
#     'hasLiquidity': False,
#     'openInterest': 3756972,
#     'openValue': 39027425136,
#     'fairMethod': 'ImpactMidPrice',
#     'fairBasisRate': 0.19,
#     'fairBasis': 478.16,
#     'fairPrice': 9626.59,
#     'markMethod': 'FairPrice',
#     'markPrice': 9626.59,
#     'indicativeTaxRate': 0.0,
#     'indicativeSettlePrice': 9148.43,
#     'optionUnderlyingPrice': None,
#     'settledPrice': None,
#     'timestamp': datetime.datetime(2019, 6, 19, 2, 12, 50, tzinfo=tzutc())},
#    {'symbol': 'XBTM19',
#     'rootSymbol': 'XBT',
#     'state': 'Open',
#     'typ': 'FFCCSX',
#     'listing': datetime.datetime(2018, 12, 12, 6, 0, tzinfo=tzutc()),
#     'front': datetime.datetime(2019, 4, 26, 12, 0, tzinfo=tzutc()),
#     'expiry': datetime.datetime(2019, 6, 28, 12, 0, tzinfo=tzutc()),
#     'settle': datetime.datetime(2019, 6, 28, 12, 0, tzinfo=tzutc()),
#     'relistInterval': None,
#     'inverseLeg': '',
#     'sellLeg': '',
#     'buyLeg': '',
#     'optionStrikePcnt': None,
#     'optionStrikeRound': None,
#     'optionStrikePrice': None,
#     'optionMultiplier': None,
#     'positionCurrency': 'USD',
#     'underlying': 'XBT',
#     'quoteCurrency': 'USD',
#     'underlyingSymbol': 'XBT=',
#     'reference': 'BMEX',
#     'referenceSymbol': '.BXBT30M',
#     'calcInterval': None,
#     'publishInterval': None,
#     'publishTime': None,
#     'maxOrderQty': 10000000,
#     'maxPrice': 1000000.0,
#     'lotSize': 1,
#     'tickSize': 0.5,
#     'multiplier': -100000000,
#     'settlCurrency': 'XBt',
#     'underlyingToPositionMultiplier': None,
#     'underlyingToSettleMultiplier': -100000000,
#     'quoteToSettleMultiplier': None,
#     'isQuanto': False,
#     'isInverse': True,
#     'initMargin': 0.01,
#     'maintMargin': 0.005,
#     'riskLimit': 5000000000,
#     'riskStep': 5000000000,
#     'limit': None,
#     'capped': False,
#     'taxed': True,
#     'deleverage': True,
#     'makerFee': -0.00025,
#     'takerFee': 0.00075,
#     'settlementFee': 0.0005,
#     'insuranceFee': 0.0,
#     'fundingBaseSymbol': '',
#     'fundingQuoteSymbol': '',
#     'fundingPremiumSymbol': '',
#     'fundingTimestamp': None,
#     'fundingInterval': None,
#     'fundingRate': None,
#     'indicativeFundingRate': None,
#     'rebalanceTimestamp': None,
#     'rebalanceInterval': None,
#     'openingTimestamp': datetime.datetime(2019, 6, 19, 2, 0, tzinfo=tzutc()),
#     'closingTimestamp': datetime.datetime(2019, 6, 19, 3, 0, tzinfo=tzutc()),
#     'sessionInterval': datetime.datetime(2000, 1, 1, 1, 0, tzinfo=tzutc()),
#     'prevClosePrice': 9214.79,
#     'limitDownPrice': None,
#     'limitUpPrice': None,
#     'bankruptLimitDownPrice': None,
#     'bankruptLimitUpPrice': None,
#     'prevTotalVolume': 65026916,
#     'totalVolume': 65026916,
#     'volume': 0,
#     'volume24h': 17276,
#     'prevTotalTurnover': 1152928842493,
#     'totalTurnover': 1152928842493,
#     'turnover': 0,
#     'turnover24h': 187106279,
#     'homeNotional24h': 1.8710627899999999,
#     'foreignNotional24h': 17276.0,
#     'prevPrice24h': 9267.0,
#     'vwap': 9233.6103,
#     'highPrice': 9600.0,
#     'lowPrice': 8257.5,
#     'lastPrice': 9587.5,
#     'lastPriceProtected': 9216.13,
#     'lastTickDirection': 'PlusTick',
#     'lastChangePcnt': 0.0346,
#     'bidPrice': 8918.0,
#     'midPrice': 9258.75,
#     'askPrice': 9599.5,
#     'impactBidPrice': 8353.521,
#     'impactMidPrice': 8976.5,
#     'impactAskPrice': 9599.6928,
#     'hasLiquidity': False,
#     'openInterest': 3657996,
#     'openValue': 39831918444,
#     'fairMethod': 'ImpactMidPrice',
#     'fairBasisRate': 0.15,
#     'fairBasis': 35.37,
#     'fairPrice': 9183.8,
#     'markMethod': 'FairPrice',
#     'markPrice': 9183.8,
#     'indicativeTaxRate': 0.0,
#     'indicativeSettlePrice': 9148.43,
#     'optionUnderlyingPrice': None,
#     'settledPrice': None,
#     'timestamp': datetime.datetime(2019, 6, 19, 2, 12, 50, tzinfo=tzutc())},
#    {'symbol': 'XBTH19',
#     'rootSymbol': 'XBT',
#     'state': 'Settled',
#     'typ': 'FFCCSX',
#     'listing': datetime.datetime(2018, 9, 15, 8, 0, tzinfo=tzutc()),
#     'front': datetime.datetime(2019, 1, 25, 12, 0, tzinfo=tzutc()),
#     'expiry': datetime.datetime(2019, 3, 29, 12, 0, tzinfo=tzutc()),
#     'settle': datetime.datetime(2019, 3, 29, 12, 0, tzinfo=tzutc()),
#     'relistInterval': None,
#     'inverseLeg': '',
#     'sellLeg': '',
#     'buyLeg': '',
#     'optionStrikePcnt': None,
#     'optionStrikeRound': None,
#     'optionStrikePrice': None,
#     'optionMultiplier': None,
#     'positionCurrency': 'USD',
#     'underlying': 'XBT',
#     'quoteCurrency': 'USD',
#     'underlyingSymbol': 'XBT=',
#     'reference': 'BMEX',
#     'referenceSymbol': '.BXBT30M',
#     'calcInterval': None,
#     'publishInterval': None,
#     'publishTime': None,
#     'maxOrderQty': 10000000,
#     'maxPrice': 1000000.0,
#     'lotSize': 1,
#     'tickSize': 0.5,
#     'multiplier': -100000000,
#     'settlCurrency': 'XBt',
#     'underlyingToPositionMultiplier': None,
#     'underlyingToSettleMultiplier': -100000000,
#     'quoteToSettleMultiplier': None,
#     'isQuanto': False,
#     'isInverse': True,
#     'initMargin': 0.01,
#     'maintMargin': 0.005,
#     'riskLimit': 20000000000,
#     'riskStep': 10000000000,
#     'limit': None,
#     'capped': False,
#     'taxed': True,
#     'deleverage': True,
#     'makerFee': -0.00025,
#     'takerFee': 0.00075,
#     'settlementFee': 0.0005,
#     'insuranceFee': 0.0,
#     'fundingBaseSymbol': '',
#     'fundingQuoteSymbol': '',
#     'fundingPremiumSymbol': '',
#     'fundingTimestamp': None,
#     'fundingInterval': None,
#     'fundingRate': None,
#     'indicativeFundingRate': None,
#     'rebalanceTimestamp': None,
#     'rebalanceInterval': None,
#     'openingTimestamp': datetime.datetime(2019, 3, 29, 12, 0, tzinfo=tzutc()),
#     'closingTimestamp': datetime.datetime(2019, 3, 29, 12, 0, tzinfo=tzutc()),
#     'sessionInterval': datetime.datetime(2000, 1, 1, 1, 0, tzinfo=tzutc()),
#     'prevClosePrice': 4094.8,
#     'limitDownPrice': None,
#     'limitUpPrice': None,
#     'bankruptLimitDownPrice': None,
#     'bankruptLimitUpPrice': None,
#     'prevTotalVolume': 415470995,
#     'totalVolume': 415470995,
#     'volume': 0,
#     'volume24h': 0,
#     'prevTotalTurnover': 6739148433604,
#     'totalTurnover': 6739148433604,
#     'turnover': 0,
#     'turnover24h': 0,
#     'homeNotional24h': 0.0,
#     'foreignNotional24h': 0.0,
#     'prevPrice24h': 4094.8,
#     'vwap': None,
#     'highPrice': None,
#     'lowPrice': None,
#     'lastPrice': 4094.8,
#     'lastPriceProtected': 4094.8,
#     'lastTickDirection': 'ZeroMinusTick',
#     'lastChangePcnt': 0.0,
#     'bidPrice': 4081.0,
#     'midPrice': 4115.5,
#     'askPrice': 4150.0,
#     'impactBidPrice': 3991.5379,
#     'impactMidPrice': 4113.0,
#     'impactAskPrice': 4234.5967,
#     'hasLiquidity': False,
#     'openInterest': 0,
#     'openValue': 0,
#     'fairMethod': 'ImpactMidPrice',
#     'fairBasisRate': 0.16,
#     'fairBasis': 0.0,
#     'fairPrice': 4094.8,
#     'markMethod': 'FairPrice',
#     'markPrice': 4094.8,
#     'indicativeTaxRate': 0.0,
#     'indicativeSettlePrice': 4094.8,
#     'optionUnderlyingPrice': None,
#     'settledPrice': 4094.8,
#     'timestamp': datetime.datetime(2019, 3, 29, 12, 0, tzinfo=tzutc())},
#    {'symbol': 'XBTZ18',
#     'rootSymbol': 'XBT',
#     'state': 'Settled',
#     'typ': 'FFCCSX',
#     'listing': datetime.datetime(2018, 7, 1, 18, 0, tzinfo=tzutc()),
#     'front': datetime.datetime(2018, 10, 26, 12, 0, tzinfo=tzutc()),
#     'expiry': datetime.datetime(2018, 12, 28, 12, 0, tzinfo=tzutc()),
#     'settle': datetime.datetime(2018, 12, 28, 12, 0, tzinfo=tzutc()),
#     'relistInterval': None,
#     'inverseLeg': '',
#     'sellLeg': '',
#     'buyLeg': '',
#     'optionStrikePcnt': None,
#     'optionStrikeRound': None,
#     'optionStrikePrice': None,
#     'optionMultiplier': None,
#     'positionCurrency': 'USD',
#     'underlying': 'XBT',
#     'quoteCurrency': 'USD',
#     'underlyingSymbol': 'XBT=',
#     'reference': 'BMEX',
#     'referenceSymbol': '.XBT30M',
#     'calcInterval': None,
#     'publishInterval': None,
#     'publishTime': None,
#     'maxOrderQty': 10000000,
#     'maxPrice': 1000000.0,
#     'lotSize': 1,
#     'tickSize': 0.5,
#     'multiplier': -100000000,
#     'settlCurrency': 'XBt',
#     'underlyingToPositionMultiplier': None,
#     'underlyingToSettleMultiplier': -100000000,
#     'quoteToSettleMultiplier': None,
#     'isQuanto': False,
#     'isInverse': True,
#     'initMargin': 0.01,
#     'maintMargin': 0.005,
#     'riskLimit': 20000000000,
#     'riskStep': 10000000000,
#     'limit': None,
#     'capped': False,
#     'taxed': True,
#     'deleverage': True,
#     'makerFee': -0.00025,
#     'takerFee': 0.00075,
#     'settlementFee': 0.0005,
#     'insuranceFee': 0.0,
#     'fundingBaseSymbol': '',
#     'fundingQuoteSymbol': '',
#     'fundingPremiumSymbol': '',
#     'fundingTimestamp': None,
#     'fundingInterval': None,
#     'fundingRate': None,
#     'indicativeFundingRate': None,
#     'rebalanceTimestamp': None,
#     'rebalanceInterval': None,
#     'openingTimestamp': datetime.datetime(2018, 12, 28, 12, 0, tzinfo=tzutc()),
#     'closingTimestamp': datetime.datetime(2018, 12, 28, 12, 0, tzinfo=tzutc()),
#     'sessionInterval': datetime.datetime(2000, 1, 1, 1, 0, tzinfo=tzutc()),
#     'prevClosePrice': 3628.08,
#     'limitDownPrice': None,
#     'limitUpPrice': None,
#     'bankruptLimitDownPrice': None,
#     'bankruptLimitUpPrice': None,
#     'prevTotalVolume': 1857104550,
#     'totalVolume': 1857104550,
#     'volume': 0,
#     'volume24h': 0,
#     'prevTotalTurnover': 26077250727606,
#     'totalTurnover': 26077250727606,
#     'turnover': 0,
#     'turnover24h': 0,
#     'homeNotional24h': 0.0,
#     'foreignNotional24h': 0.0,
#     'prevPrice24h': 3628.08,
#     'vwap': None,
#     'highPrice': None,
#     'lowPrice': None,
#     'lastPrice': 3628.08,
#     'lastPriceProtected': 3628.08,
#     'lastTickDirection': 'ZeroPlusTick',
#     'lastChangePcnt': 0.0,
#     'bidPrice': 3610.0,
#     'midPrice': 3655.0,
#     'askPrice': 3700.0,
#     'impactBidPrice': 3374.8439,
#     'impactMidPrice': 3697.25,
#     'impactAskPrice': 4019.7773,
#     'hasLiquidity': False,
#     'openInterest': 0,
#     'openValue': 0,
#     'fairMethod': 'ImpactMidPrice',
#     'fairBasisRate': 1.86,
#     'fairBasis': 0.0,
#     'fairPrice': 3628.08,
#     'markMethod': 'FairPrice',
#     'markPrice': 3628.08,
#     'indicativeTaxRate': 0.0,
#     'indicativeSettlePrice': 3628.08,
#     'optionUnderlyingPrice': None,
#     'settledPrice': 3628.08,
#     'timestamp': datetime.datetime(2018, 12, 28, 12, 0, tzinfo=tzutc())},
#    {'symbol': 'XBT7D_D95',
#     'rootSymbol': 'XBT',
#     'state': 'Open',
#     'typ': 'OPECCS',
#     'listing': datetime.datetime(2019, 6, 14, 12, 0, tzinfo=tzutc()),
#     'front': datetime.datetime(2019, 6, 14, 12, 0, tzinfo=tzutc()),
#     'expiry': datetime.datetime(2019, 6, 21, 12, 0, tzinfo=tzutc()),
#     'settle': datetime.datetime(2019, 6, 21, 12, 0, tzinfo=tzutc()),
#     'relistInterval': datetime.datetime(2000, 1, 8, 0, 0, tzinfo=tzutc()),
#     'inverseLeg': '',
#     'sellLeg': '',
#     'buyLeg': '',
#     'optionStrikePcnt': 0.95,
#     'optionStrikeRound': 250.0,
#     'optionStrikePrice': 8000.0,
#     'optionMultiplier': -0.1,
#     'positionCurrency': '',
#     'underlying': 'XBT',
#     'quoteCurrency': 'XBT',
#     'underlyingSymbol': 'XBT=',
#     'reference': 'BMEX',
#     'referenceSymbol': '.BXBT30M',
#     'calcInterval': None,
#     'publishInterval': None,
#     'publishTime': None,
#     'maxOrderQty': 10000000,
#     'maxPrice': 0.1,
#     'lotSize': 1,
#     'tickSize': 1e-05,
#     'multiplier': 100000000,
#     'settlCurrency': 'XBt',
#     'underlyingToPositionMultiplier': 10,
#     'underlyingToSettleMultiplier': None,
#     'quoteToSettleMultiplier': 100000000,
#     'isQuanto': False,
#     'isInverse': False,
#     'initMargin': 1.0,
#     'maintMargin': 0.0,
#     'riskLimit': None,
#     'riskStep': None,
#     'limit': None,
#     'capped': True,
#     'taxed': True,
#     'deleverage': True,
#     'makerFee': 0.0,
#     'takerFee': 0.0,
#     'settlementFee': 0.0,
#     'insuranceFee': 0.0,
#     'fundingBaseSymbol': '',
#     'fundingQuoteSymbol': '',
#     'fundingPremiumSymbol': '',
#     'fundingTimestamp': None,
#     'fundingInterval': None,
#     'fundingRate': None,
#     'indicativeFundingRate': None,
#     'rebalanceTimestamp': None,
#     'rebalanceInterval': None,
#     'openingTimestamp': datetime.datetime(2019, 6, 19, 2, 0, tzinfo=tzutc()),
#     'closingTimestamp': datetime.datetime(2019, 6, 19, 3, 0, tzinfo=tzutc()),
#     'sessionInterval': datetime.datetime(2000, 1, 1, 1, 0, tzinfo=tzutc()),
#     'prevClosePrice': 0.0,
#     'limitDownPrice': 0.0,
#     'limitUpPrice': 0.1,
#     'bankruptLimitDownPrice': None,
#     'bankruptLimitUpPrice': None,
#     'prevTotalVolume': 12073,
#     'totalVolume': 12073,
#     'volume': 0,
#     'volume24h': 0,
#     'prevTotalTurnover': 120730000000,
#     'totalTurnover': 120730000000,
#     'turnover': 0,
#     'turnover24h': 0,
#     'homeNotional24h': 0.0,
#     'foreignNotional24h': 0.0,
#     'prevPrice24h': 0.0,
#     'vwap': None,
#     'highPrice': None,
#     'lowPrice': None,
#     'lastPrice': 0.0,
#     'lastPriceProtected': 0.0,
#     'lastTickDirection': 'ZeroMinusTick',
#     'lastChangePcnt': 0.0,
#     'bidPrice': 0.00393,
#     'midPrice': 0.00431,
#     'askPrice': 0.00469,
#     'impactBidPrice': 0.00374482,
#     'impactMidPrice': 0.004285,
#     'impactAskPrice': 0.00482096,
#     'hasLiquidity': False,
#     'openInterest': 0,
#     'openValue': 0,
#     'fairMethod': '',
#     'fairBasisRate': 0.0,
#     'fairBasis': 0.0,
#     'fairPrice': 0.0,
#     'markMethod': 'LastPrice',
#     'markPrice': 0.0,
#     'indicativeTaxRate': 0.0,
#     'indicativeSettlePrice': 0.0,
#     'optionUnderlyingPrice': 9148.43,
#     'settledPrice': None,
#     'timestamp': datetime.datetime(2019, 6, 19, 2, 12, 50, tzinfo=tzutc())},
#    {'symbol': 'XBT7D_U105',
#     'rootSymbol': 'XBT',
#     'state': 'Open',
#     'typ': 'OCECCS',
#     'listing': datetime.datetime(2019, 6, 14, 12, 0, tzinfo=tzutc()),
#     'front': datetime.datetime(2019, 6, 14, 12, 0, tzinfo=tzutc()),
#     'expiry': datetime.datetime(2019, 6, 21, 12, 0, tzinfo=tzutc()),
#     'settle': datetime.datetime(2019, 6, 21, 12, 0, tzinfo=tzutc()),
#     'relistInterval': datetime.datetime(2000, 1, 8, 0, 0, tzinfo=tzutc()),
#     'inverseLeg': '',
#     'sellLeg': '',
#     'buyLeg': '',
#     'optionStrikePcnt': 1.05,
#     'optionStrikeRound': 250.0,
#     'optionStrikePrice': 8750.0,
#     'optionMultiplier': -0.1,
#     'positionCurrency': '',
#     'underlying': 'XBT',
#     'quoteCurrency': 'XBT',
#     'underlyingSymbol': 'XBT=',
#     'reference': 'BMEX',
#     'referenceSymbol': '.BXBT30M',
#     'calcInterval': None,
#     'publishInterval': None,
#     'publishTime': None,
#     'maxOrderQty': 10000000,
#     'maxPrice': 0.1,
#     'lotSize': 1,
#     'tickSize': 1e-05,
#     'multiplier': 100000000,
#     'settlCurrency': 'XBt',
#     'underlyingToPositionMultiplier': 10,
#     'underlyingToSettleMultiplier': None,
#     'quoteToSettleMultiplier': 100000000,
#     'isQuanto': False,
#     'isInverse': False,
#     'initMargin': 1.0,
#     'maintMargin': 0.0,
#     'riskLimit': None,
#     'riskStep': None,
#     'limit': None,
#     'capped': True,
#     'taxed': True,
#     'deleverage': True,
#     'makerFee': 0.0,
#     'takerFee': 0.0,
#     'settlementFee': 0.0,
#     'insuranceFee': 0.0,
#     'fundingBaseSymbol': '',
#     'fundingQuoteSymbol': '',
#     'fundingPremiumSymbol': '',
#     'fundingTimestamp': None,
#     'fundingInterval': None,
#     'fundingRate': None,
#     'indicativeFundingRate': None,
#     'rebalanceTimestamp': None,
#     'rebalanceInterval': None,
#     'openingTimestamp': datetime.datetime(2019, 6, 19, 2, 0, tzinfo=tzutc()),
#     'closingTimestamp': datetime.datetime(2019, 6, 19, 3, 0, tzinfo=tzutc()),
#     'sessionInterval': datetime.datetime(2000, 1, 1, 1, 0, tzinfo=tzutc()),
#     'prevClosePrice': 0.00049,
#     'limitDownPrice': 0.0,
#     'limitUpPrice': 0.1,
#     'bankruptLimitDownPrice': None,
#     'bankruptLimitUpPrice': None,
#     'prevTotalVolume': 22251,
#     'totalVolume': 22251,
#     'volume': 0,
#     'volume24h': 3,
#     'prevTotalTurnover': 222510000000,
#     'totalTurnover': 222510000000,
#     'turnover': 0,
#     'turnover24h': 30000000,
#     'homeNotional24h': 0.30000000000000004,
#     'foreignNotional24h': 0.0147,
#     'prevPrice24h': 0.00049,
#     'vwap': 0.0049,
#     'highPrice': 0.0049,
#     'lowPrice': 0.0049,
#     'lastPrice': 0.0049,
#     'lastPriceProtected': 0.00464,
#     'lastTickDirection': 'ZeroPlusTick',
#     'lastChangePcnt': 9.0,
#     'bidPrice': 0.001,
#     'midPrice': 0.001,
#     'askPrice': None,
#     'impactBidPrice': None,
#     'impactMidPrice': None,
#     'impactAskPrice': None,
#     'hasLiquidity': False,
#     'openInterest': 3,
#     'openValue': 30000000,
#     'fairMethod': '',
#     'fairBasisRate': 0.0,
#     'fairBasis': 0.0,
#     'fairPrice': 0.00436,
#     'markMethod': 'LastPrice',
#     'markPrice': 0.0049,
#     'indicativeTaxRate': 0.0,
#     'indicativeSettlePrice': 0.00436,
#     'optionUnderlyingPrice': 9148.43,
#     'settledPrice': None,
#     'timestamp': datetime.datetime(2019, 6, 19, 2, 12, 50, tzinfo=tzutc())},
#    {'symbol': 'XBT7D_D90',
#     'rootSymbol': 'XBT',
#     'state': 'Settled',
#     'typ': 'OPECCS',
#     'listing': datetime.datetime(2018, 6, 1, 12, 0, tzinfo=tzutc()),
#     'front': datetime.datetime(2018, 6, 1, 12, 0, tzinfo=tzutc()),
#     'expiry': datetime.datetime(2018, 6, 8, 12, 0, tzinfo=tzutc()),
#     'settle': datetime.datetime(2018, 6, 8, 12, 0, tzinfo=tzutc()),
#     'relistInterval': None,
#     'inverseLeg': '',
#     'sellLeg': '',
#     'buyLeg': '',
#     'optionStrikePcnt': 0.9,
#     'optionStrikeRound': 250.0,
#     'optionStrikePrice': 6750.0,
#     'optionMultiplier': -0.1,
#     'positionCurrency': '',
#     'underlying': 'XBT',
#     'quoteCurrency': 'XBT',
#     'underlyingSymbol': 'XBT=',
#     'reference': 'BMEX',
#     'referenceSymbol': '.BXBT30M',
#     'calcInterval': None,
#     'publishInterval': None,
#     'publishTime': None,
#     'maxOrderQty': 10000000,
#     'maxPrice': 0.1,
#     'lotSize': 1,
#     'tickSize': 1e-05,
#     'multiplier': 100000000,
#     'settlCurrency': 'XBt',
#     'underlyingToPositionMultiplier': 10,
#     'underlyingToSettleMultiplier': None,
#     'quoteToSettleMultiplier': 100000000,
#     'isQuanto': False,
#     'isInverse': False,
#     'initMargin': 1.0,
#     'maintMargin': 0.0,
#     'riskLimit': None,
#     'riskStep': None,
#     'limit': None,
#     'capped': True,
#     'taxed': True,
#     'deleverage': True,
#     'makerFee': 0.0,
#     'takerFee': 0.0,
#     'settlementFee': 0.0,
#     'insuranceFee': 0.0,
#     'fundingBaseSymbol': '',
#     'fundingQuoteSymbol': '',
#     'fundingPremiumSymbol': '',
#     'fundingTimestamp': None,
#     'fundingInterval': None,
#     'fundingRate': None,
#     'indicativeFundingRate': None,
#     'rebalanceTimestamp': None,
#     'rebalanceInterval': None,
#     'openingTimestamp': datetime.datetime(2018, 6, 8, 12, 0, tzinfo=tzutc()),
#     'closingTimestamp': datetime.datetime(2018, 6, 8, 12, 0, tzinfo=tzutc()),
#     'sessionInterval': datetime.datetime(2000, 1, 1, 2, 0, tzinfo=tzutc()),
#     'prevClosePrice': 0.0,
#     'limitDownPrice': 0.0,
#     'limitUpPrice': 0.1,
#     'bankruptLimitDownPrice': None,
#     'bankruptLimitUpPrice': None,
#     'prevTotalVolume': 20500,
#     'totalVolume': 20500,
#     'volume': 0,
#     'volume24h': 0,
#     'prevTotalTurnover': 59488158000,
#     'totalTurnover': 59488158000,
#     'turnover': 0,
#     'turnover24h': 0,
#     'homeNotional24h': 0.0,
#     'foreignNotional24h': 0.0,
#     'prevPrice24h': 0.0,
#     'vwap': None,
#     'highPrice': None,
#     'lowPrice': None,
#     'lastPrice': 0.0,
#     'lastPriceProtected': 0.0,
#     'lastTickDirection': 'ZeroPlusTick',
#     'lastChangePcnt': 0.0,
#     'bidPrice': 1e-05,
#     'midPrice': 1e-05,
#     'askPrice': None,
#     'impactBidPrice': None,
#     'impactMidPrice': None,
#     'impactAskPrice': None,
#     'hasLiquidity': False,
#     'openInterest': 0,
#     'openValue': 0,
#     'fairMethod': '',
#     'fairBasisRate': 0.0,
#     'fairBasis': 0.0,
#     'fairPrice': 0.0,
#     'markMethod': 'LastPrice',
#     'markPrice': 0.0,
#     'indicativeTaxRate': 0.0,
#     'indicativeSettlePrice': 0.0,
#     'optionUnderlyingPrice': 7568.38103,
#     'settledPrice': None,
#     'timestamp': datetime.datetime(2018, 6, 8, 11, 59, tzinfo=tzutc())},
#    {'symbol': 'XBTU18',
#     'rootSymbol': 'XBT',
#     'state': 'Settled',
#     'typ': 'FFCCSX',
#     'listing': datetime.datetime(2018, 3, 31, 6, 0, tzinfo=tzutc()),
#     'front': datetime.datetime(2018, 7, 27, 12, 0, tzinfo=tzutc()),
#     'expiry': datetime.datetime(2018, 9, 28, 12, 0, tzinfo=tzutc()),
#     'settle': datetime.datetime(2018, 9, 28, 12, 0, tzinfo=tzutc()),
#     'relistInterval': None,
#     'inverseLeg': '',
#     'sellLeg': '',
#     'buyLeg': '',
#     'optionStrikePcnt': None,
#     'optionStrikeRound': None,
#     'optionStrikePrice': None,
#     'optionMultiplier': None,
#     'positionCurrency': 'USD',
#     'underlying': 'XBT',
#     'quoteCurrency': 'USD',
#     'underlyingSymbol': 'XBT=',
#     'reference': 'BMEX',
#     'referenceSymbol': '.XBT30M',
#     'calcInterval': None,
#     'publishInterval': None,
#     'publishTime': None,
#     'maxOrderQty': 10000000,
#     'maxPrice': 1000000.0,
#     'lotSize': 1,
#     'tickSize': 0.5,
#     'multiplier': -100000000,
#     'settlCurrency': 'XBt',
#     'underlyingToPositionMultiplier': None,
#     'underlyingToSettleMultiplier': -100000000,
#     'quoteToSettleMultiplier': None,
#     'isQuanto': False,
#     'isInverse': True,
#     'initMargin': 0.01,
#     'maintMargin': 0.005,
#     'riskLimit': 20000000000,
#     'riskStep': 10000000000,
#     'limit': None,
#     'capped': False,
#     'taxed': True,
#     'deleverage': True,
#     'makerFee': -0.00025,
#     'takerFee': 0.00075,
#     'settlementFee': 0.0005,
#     'insuranceFee': 0.0,
#     'fundingBaseSymbol': '',
#     'fundingQuoteSymbol': '',
#     'fundingPremiumSymbol': '',
#     'fundingTimestamp': None,
#     'fundingInterval': None,
#     'fundingRate': None,
#     'indicativeFundingRate': None,
#     'rebalanceTimestamp': None,
#     'rebalanceInterval': None,
#     'openingTimestamp': datetime.datetime(2018, 9, 28, 12, 0, tzinfo=tzutc()),
#     'closingTimestamp': datetime.datetime(2018, 9, 28, 12, 0, tzinfo=tzutc()),
#     'sessionInterval': datetime.datetime(2000, 1, 1, 1, 0, tzinfo=tzutc()),
#     'prevClosePrice': 6646.62,
#     'limitDownPrice': None,
#     'limitUpPrice': None,
#     'bankruptLimitDownPrice': None,
#     'bankruptLimitUpPrice': None,
#     'prevTotalVolume': 1832221013,
#     'totalVolume': 1832221013,
#     'volume': 0,
#     'volume24h': 0,
#     'prevTotalTurnover': 24433937941810,
#     'totalTurnover': 24433937941810,
#     'turnover': 0,
#     'turnover24h': 0,
#     'homeNotional24h': 0.0,
#     'foreignNotional24h': 0.0,
#     'prevPrice24h': 6646.62,
#     'vwap': None,
#     'highPrice': None,
#     'lowPrice': None,
#     'lastPrice': 6646.62,
#     'lastPriceProtected': 6646.62,
#     'lastTickDirection': 'ZeroMinusTick',
#     'lastChangePcnt': 0.0,
#     'bidPrice': 6642.0,
#     'midPrice': 6646.75,
#     'askPrice': 6651.5,
#     'impactBidPrice': 6641.8704,
#     'impactMidPrice': 6646.75,
#     'impactAskPrice': 6651.5897,
#     'hasLiquidity': True,
#     'openInterest': 0,
#     'openValue': 0,
#     'fairMethod': 'ImpactMidPrice',
#     'fairBasisRate': -0.2,
#     'fairBasis': 0.0,
#     'fairPrice': 6646.62,
#     'markMethod': 'FairPrice',
#     'markPrice': 6646.62,
#     'indicativeTaxRate': 0.0,
#     'indicativeSettlePrice': 6646.62,
#     'optionUnderlyingPrice': None,
#     'settledPrice': 6646.62,
#     'timestamp': datetime.datetime(2018, 9, 28, 12, 0, tzinfo=tzutc())},
#    {'symbol': 'XBT7D_U110',
#     'rootSymbol': 'XBT',
#     'state': 'Settled',
#     'typ': 'OCECCS',
#     'listing': datetime.datetime(2018, 6, 1, 12, 0, tzinfo=tzutc()),
#     'front': datetime.datetime(2018, 6, 1, 12, 0, tzinfo=tzutc()),
#     'expiry': datetime.datetime(2018, 6, 8, 12, 0, tzinfo=tzutc()),
#     'settle': datetime.datetime(2018, 6, 8, 12, 0, tzinfo=tzutc()),
#     'relistInterval': None,
#     'inverseLeg': '',
#     'sellLeg': '',
#     'buyLeg': '',
#     'optionStrikePcnt': 1.1,
#     'optionStrikeRound': 250.0,
#     'optionStrikePrice': 8250.0,
#     'optionMultiplier': -0.1,
#     'positionCurrency': '',
#     'underlying': 'XBT',
#     'quoteCurrency': 'XBT',
#     'underlyingSymbol': 'XBT=',
#     'reference': 'BMEX',
#     'referenceSymbol': '.BXBT30M',
#     'calcInterval': None,
#     'publishInterval': None,
#     'publishTime': None,
#     'maxOrderQty': 10000000,
#     'maxPrice': 0.1,
#     'lotSize': 1,
#     'tickSize': 1e-05,
#     'multiplier': 100000000,
#     'settlCurrency': 'XBt',
#     'underlyingToPositionMultiplier': 10,
#     'underlyingToSettleMultiplier': None,
#     'quoteToSettleMultiplier': 100000000,
#     'isQuanto': False,
#     'isInverse': False,
#     'initMargin': 1.0,
#     'maintMargin': 0.0,
#     'riskLimit': None,
#     'riskStep': None,
#     'limit': None,
#     'capped': True,
#     'taxed': True,
#     'deleverage': True,
#     'makerFee': 0.0,
#     'takerFee': 0.0,
#     'settlementFee': 0.0,
#     'insuranceFee': 0.0,
#     'fundingBaseSymbol': '',
#     'fundingQuoteSymbol': '',
#     'fundingPremiumSymbol': '',
#     'fundingTimestamp': None,
#     'fundingInterval': None,
#     'fundingRate': None,
#     'indicativeFundingRate': None,
#     'rebalanceTimestamp': None,
#     'rebalanceInterval': None,
#     'openingTimestamp': datetime.datetime(2018, 6, 8, 12, 0, tzinfo=tzutc()),
#     'closingTimestamp': datetime.datetime(2018, 6, 8, 12, 0, tzinfo=tzutc()),
#     'sessionInterval': datetime.datetime(2000, 1, 1, 2, 0, tzinfo=tzutc()),
#     'prevClosePrice': 0.0,
#     'limitDownPrice': 0.0,
#     'limitUpPrice': 0.1,
#     'bankruptLimitDownPrice': None,
#     'bankruptLimitUpPrice': None,
#     'prevTotalVolume': 80293,
#     'totalVolume': 80293,
#     'volume': 0,
#     'volume24h': 0,
#     'prevTotalTurnover': 197227291000,
#     'totalTurnover': 197227291000,
#     'turnover': 0,
#     'turnover24h': 0,
#     'homeNotional24h': 0.0,
#     'foreignNotional24h': 0.0,
#     'prevPrice24h': 0.0,
#     'vwap': None,
#     'highPrice': None,
#     'lowPrice': None,
#     'lastPrice': 0.0,
#     'lastPriceProtected': 0.0,
#     'lastTickDirection': 'ZeroPlusTick',
#     'lastChangePcnt': 0.0,
#     'bidPrice': 0.09806,
#     'midPrice': 0.09806,
#     'askPrice': None,
#     'impactBidPrice': None,
#     'impactMidPrice': None,
#     'impactAskPrice': None,
#     'hasLiquidity': False,
#     'openInterest': 0,
#     'openValue': 0,
#     'fairMethod': '',
#     'fairBasisRate': 0.0,
#     'fairBasis': 0.0,
#     'fairPrice': 0.0,
#     'markMethod': 'LastPrice',
#     'markPrice': 0.0,
#     'indicativeTaxRate': 0.0,
#     'indicativeSettlePrice': 0.0,
#     'optionUnderlyingPrice': 7568.38103,
#     'settledPrice': None,
#     'timestamp': datetime.datetime(2018, 6, 8, 11, 59, tzinfo=tzutc())},
#    {'symbol': 'XBTM18',
#     'rootSymbol': 'XBT',
#     'state': 'Settled',
#     'typ': 'FFCCSX',
#     'listing': datetime.datetime(2017, 12, 5, 6, 0, tzinfo=tzutc()),
#     'front': datetime.datetime(2018, 4, 27, 12, 0, tzinfo=tzutc()),
#     'expiry': datetime.datetime(2018, 6, 29, 12, 0, tzinfo=tzutc()),
#     'settle': datetime.datetime(2018, 6, 29, 12, 0, tzinfo=tzutc()),
#     'relistInterval': None,
#     'inverseLeg': '',
#     'sellLeg': '',
#     'buyLeg': '',
#     'optionStrikePcnt': None,
#     'optionStrikeRound': None,
#     'optionStrikePrice': None,
#     'optionMultiplier': None,
#     'positionCurrency': 'USD',
#     'underlying': 'XBT',
#     'quoteCurrency': 'USD',
#     'underlyingSymbol': 'XBT=',
#     'reference': 'BMEX',
#     'referenceSymbol': '.BXBT30M',
#     'calcInterval': None,
#     'publishInterval': None,
#     'publishTime': None,
#     'maxOrderQty': 10000000,
#     'maxPrice': 1000000.0,
#     'lotSize': 1,
#     'tickSize': 0.5,
#     'multiplier': -100000000,
#     'settlCurrency': 'XBt',
#     'underlyingToPositionMultiplier': None,
#     'underlyingToSettleMultiplier': -100000000,
#     'quoteToSettleMultiplier': None,
#     'isQuanto': False,
#     'isInverse': True,
#     'initMargin': 0.01,
#     'maintMargin': 0.005,
#     'riskLimit': 20000000000,
#     'riskStep': 10000000000,
#     'limit': None,
#     'capped': False,
#     'taxed': True,
#     'deleverage': True,
#     'makerFee': -0.00025,
#     'takerFee': 0.00075,
#     'settlementFee': 0.0005,
#     'insuranceFee': 0.0,
#     'fundingBaseSymbol': '',
#     'fundingQuoteSymbol': '',
#     'fundingPremiumSymbol': '',
#     'fundingTimestamp': None,
#     'fundingInterval': None,
#     'fundingRate': None,
#     'indicativeFundingRate': None,
#     'rebalanceTimestamp': None,
#     'rebalanceInterval': None,
#     'openingTimestamp': datetime.datetime(2018, 6, 29, 12, 0, tzinfo=tzutc()),
#     'closingTimestamp': datetime.datetime(2018, 6, 29, 12, 0, tzinfo=tzutc()),
#     'sessionInterval': datetime.datetime(2000, 1, 1, 2, 0, tzinfo=tzutc()),
#     'prevClosePrice': 5861.11,
#     'limitDownPrice': None,
#     'limitUpPrice': None,
#     'bankruptLimitDownPrice': None,
#     'bankruptLimitUpPrice': None,
#     'prevTotalVolume': 2430502058,
#     'totalVolume': 2430502058,
#     'volume': 0,
#     'volume24h': 0,
#     'prevTotalTurnover': 22538333950470,
#     'totalTurnover': 22538333950470,
#     'turnover': 0,
#     'turnover24h': 0,
#     'homeNotional24h': 0.0,
#     'foreignNotional24h': 0.0,
#     'prevPrice24h': 5861.11,
#     'vwap': None,
#     'highPrice': None,
#     'lowPrice': None,
#     'lastPrice': 5861.11,
#     'lastPriceProtected': 5861.11,
#     'lastTickDirection': 'ZeroMinusTick',
#     'lastChangePcnt': 0.0,
#     'bidPrice': 5881.5,
#     'midPrice': 5892.75,
#     'askPrice': 5904.0,
#     'impactBidPrice': 5301.3837,
#     'impactMidPrice': 5800.5,
#     'impactAskPrice': 6299.6094,
#     'hasLiquidity': False,
#     'openInterest': 0,
#     'openValue': 0,
#     'fairMethod': 'ImpactMidPrice',
#     'fairBasisRate': 7.18,
#     'fairBasis': 0.0,
#     'fairPrice': 5861.11,
#     'markMethod': 'FairPrice',
#     'markPrice': 5861.11,
#     'indicativeTaxRate': 0.0,
#     'indicativeSettlePrice': 5861.11,
#     'optionUnderlyingPrice': None,
#     'settledPrice': 5861.11,
#     'timestamp': datetime.datetime(2018, 6, 29, 12, 0, tzinfo=tzutc())},
#    {'symbol': 'XBTH18',
#     'rootSymbol': 'XBT',
#     'state': 'Settled',
#     'typ': 'FFCCSX',
#     'listing': datetime.datetime(2017, 12, 5, 6, 0, tzinfo=tzutc()),
#     'front': datetime.datetime(2018, 1, 26, 12, 0, tzinfo=tzutc()),
#     'expiry': datetime.datetime(2018, 3, 30, 12, 0, tzinfo=tzutc()),
#     'settle': datetime.datetime(2018, 3, 30, 12, 0, tzinfo=tzutc()),
#     'relistInterval': None,
#     'inverseLeg': '',
#     'sellLeg': '',
#     'buyLeg': '',
#     'optionStrikePcnt': None,
#     'optionStrikeRound': None,
#     'optionStrikePrice': None,
#     'optionMultiplier': None,
#     'positionCurrency': 'USD',
#     'underlying': 'XBT',
#     'quoteCurrency': 'USD',
#     'underlyingSymbol': 'XBT=',
#     'reference': 'BMEX',
#     'referenceSymbol': '.BXBT30M',
#     'calcInterval': None,
#     'publishInterval': None,
#     'publishTime': None,
#     'maxOrderQty': 10000000,
#     'maxPrice': 1000000.0,
#     'lotSize': 1,
#     'tickSize': 0.5,
#     'multiplier': -100000000,
#     'settlCurrency': 'XBt',
#     'underlyingToPositionMultiplier': None,
#     'underlyingToSettleMultiplier': -100000000,
#     'quoteToSettleMultiplier': None,
#     'isQuanto': False,
#     'isInverse': True,
#     'initMargin': 0.01,
#     'maintMargin': 0.005,
#     'riskLimit': 20000000000,
#     'riskStep': 10000000000,
#     'limit': None,
#     'capped': False,
#     'taxed': True,
#     'deleverage': True,
#     'makerFee': -0.00025,
#     'takerFee': 0.00075,
#     'settlementFee': 0.0005,
#     'insuranceFee': 0.0,
#     'fundingBaseSymbol': '',
#     'fundingQuoteSymbol': '',
#     'fundingPremiumSymbol': '',
#     'fundingTimestamp': None,
#     'fundingInterval': None,
#     'fundingRate': None,
#     'indicativeFundingRate': None,
#     'rebalanceTimestamp': None,
#     'rebalanceInterval': None,
#     'openingTimestamp': datetime.datetime(2018, 3, 30, 12, 0, tzinfo=tzutc()),
#     'closingTimestamp': datetime.datetime(2018, 3, 30, 12, 0, tzinfo=tzutc()),
#     'sessionInterval': datetime.datetime(2000, 1, 1, 2, 0, tzinfo=tzutc()),
#     'prevClosePrice': 6975.4,
#     'limitDownPrice': None,
#     'limitUpPrice': None,
#     'bankruptLimitDownPrice': None,
#     'bankruptLimitUpPrice': None,
#     'prevTotalVolume': 2319850670,
#     'totalVolume': 2319850670,
#     'volume': 0,
#     'volume24h': 0,
#     'prevTotalTurnover': 20376966841414,
#     'totalTurnover': 20376966841414,
#     'turnover': 0,
#     'turnover24h': 0,
#     'homeNotional24h': 0.0,
#     'foreignNotional24h': 0.0,
#     'prevPrice24h': 6975.4,
#     'vwap': None,
#     'highPrice': None,
#     'lowPrice': None,
#     'lastPrice': 6975.4,
#     'lastPriceProtected': 6975.4,
#     'lastTickDirection': 'MinusTick',
#     'lastChangePcnt': 0.0,
#     'bidPrice': 6501.5,
#     'midPrice': 7049.75,
#     'askPrice': 7598.0,
#     'impactBidPrice': 6500.26,
#     'impactMidPrice': 7289.25,
#     'impactAskPrice': 8078.1969,
#     'hasLiquidity': False,
#     'openInterest': 0,
#     'openValue': 0,
#     'fairMethod': 'ImpactMidPrice',
#     'fairBasisRate': -4.4,
#     'fairBasis': 0.0,
#     'fairPrice': 6975.4,
#     'markMethod': 'FairPrice',
#     'markPrice': 6975.4,
#     'indicativeTaxRate': 0.0,
#     'indicativeSettlePrice': 6975.4,
#     'optionUnderlyingPrice': None,
#     'settledPrice': 6975.4,
#     'timestamp': datetime.datetime(2018, 3, 30, 12, 0, tzinfo=tzutc())},
#    {'symbol': 'XBTZ17',
#     'rootSymbol': 'XBT',
#     'state': 'Settled',
#     'typ': 'FFCCSX',
#     'listing': datetime.datetime(2017, 9, 11, 8, 0, tzinfo=tzutc()),
#     'front': datetime.datetime(2017, 11, 24, 12, 0, tzinfo=tzutc()),
#     'expiry': datetime.datetime(2017, 12, 29, 12, 0, tzinfo=tzutc()),
#     'settle': datetime.datetime(2017, 12, 29, 12, 0, tzinfo=tzutc()),
#     'relistInterval': None,
#     'inverseLeg': '',
#     'sellLeg': '',
#     'buyLeg': '',
#     'optionStrikePcnt': None,
#     'optionStrikeRound': None,
#     'optionStrikePrice': None,
#     'optionMultiplier': None,
#     'positionCurrency': 'USD',
#     'underlying': 'XBT',
#     'quoteCurrency': 'USD',
#     'underlyingSymbol': 'XBT=',
#     'reference': 'BMEX',
#     'referenceSymbol': '.BXBT30M',
#     'calcInterval': None,
#     'publishInterval': None,
#     'publishTime': None,
#     'maxOrderQty': 10000000,
#     'maxPrice': 1000000.0,
#     'lotSize': 1,
#     'tickSize': 0.5,
#     'multiplier': -100000000,
#     'settlCurrency': 'XBt',
#     'underlyingToPositionMultiplier': None,
#     'underlyingToSettleMultiplier': -100000000,
#     'quoteToSettleMultiplier': None,
#     'isQuanto': False,
#     'isInverse': True,
#     'initMargin': 0.01,
#     'maintMargin': 0.005,
#     'riskLimit': 5000000000,
#     'riskStep': 5000000000,
#     'limit': None,
#     'capped': False,
#     'taxed': True,
#     'deleverage': True,
#     'makerFee': -0.00025,
#     'takerFee': 0.00075,
#     'settlementFee': 0.0005,
#     'insuranceFee': 0.0,
#     'fundingBaseSymbol': '',
#     'fundingQuoteSymbol': '',
#     'fundingPremiumSymbol': '',
#     'fundingTimestamp': None,
#     'fundingInterval': None,
#     'fundingRate': None,
#     'indicativeFundingRate': None,
#     'rebalanceTimestamp': None,
#     'rebalanceInterval': None,
#     'openingTimestamp': datetime.datetime(2017, 12, 29, 12, 0, tzinfo=tzutc()),
#     'closingTimestamp': datetime.datetime(2017, 12, 29, 12, 0, tzinfo=tzutc()),
#     'sessionInterval': datetime.datetime(2000, 1, 1, 2, 0, tzinfo=tzutc()),
#     'prevClosePrice': 14280.76,
#     'limitDownPrice': None,
#     'limitUpPrice': None,
#     'bankruptLimitDownPrice': None,
#     'bankruptLimitUpPrice': None,
#     'prevTotalVolume': 1350224357,
#     'totalVolume': 1350224357,
#     'volume': 0,
#     'volume24h': 0,
#     'prevTotalTurnover': 18252765109632,
#     'totalTurnover': 18252765109632,
#     'turnover': 0,
#     'turnover24h': 0,
#     'homeNotional24h': 0.0,
#     'foreignNotional24h': 0.0,
#     'prevPrice24h': 14280.76,
#     'vwap': None,
#     'highPrice': None,
#     'lowPrice': None,
#     'lastPrice': 14280.76,
#     'lastPriceProtected': 14280.76,
#     'lastTickDirection': 'PlusTick',
#     'lastChangePcnt': 0.0,
#     'bidPrice': None,
#     'midPrice': None,
#     'askPrice': None,
#     'impactBidPrice': None,
#     'impactMidPrice': None,
#     'impactAskPrice': None,
#     'hasLiquidity': False,
#     'openInterest': 0,
#     'openValue': 0,
#     'fairMethod': 'ImpactMidPrice',
#     'fairBasisRate': 0.2,
#     'fairBasis': 0.0,
#     'fairPrice': 14280.76,
#     'markMethod': 'FairPrice',
#     'markPrice': 14280.76,
#     'indicativeTaxRate': 0.0,
#     'indicativeSettlePrice': 14280.76,
#     'optionUnderlyingPrice': None,
#     'settledPrice': 14280.76,
#     'timestamp': datetime.datetime(2017, 12, 29, 12, 0, tzinfo=tzutc())},
#    {'symbol': 'XBTU17',
#     'rootSymbol': 'XBT',
#     'state': 'Settled',
#     'typ': 'FFCCSX',
#     'listing': datetime.datetime(2017, 6, 15, 6, 0, tzinfo=tzutc()),
#     'front': datetime.datetime(2017, 8, 25, 12, 0, tzinfo=tzutc()),
#     'expiry': datetime.datetime(2017, 9, 29, 12, 0, tzinfo=tzutc()),
#     'settle': datetime.datetime(2017, 9, 29, 12, 0, tzinfo=tzutc()),
#     'relistInterval': None,
#     'inverseLeg': '',
#     'sellLeg': '',
#     'buyLeg': '',
#     'optionStrikePcnt': None,
#     'optionStrikeRound': None,
#     'optionStrikePrice': None,
#     'optionMultiplier': None,
#     'positionCurrency': 'USD',
#     'underlying': 'XBT',
#     'quoteCurrency': 'USD',
#     'underlyingSymbol': 'XBT=',
#     'reference': 'BMEX',
#     'referenceSymbol': '.BXBT30M',
#     'calcInterval': None,
#     'publishInterval': None,
#     'publishTime': None,
#     'maxOrderQty': 10000000,
#     'maxPrice': 1000000.0,
#     'lotSize': 1,
#     'tickSize': 0.1,
#     'multiplier': -100000000,
#     'settlCurrency': 'XBt',
#     'underlyingToPositionMultiplier': None,
#     'underlyingToSettleMultiplier': -100000000,
#     'quoteToSettleMultiplier': None,
#     'isQuanto': False,
#     'isInverse': True,
#     'initMargin': 0.01,
#     'maintMargin': 0.005,
#     'riskLimit': 5000000000,
#     'riskStep': 5000000000,
#     'limit': None,
#     'capped': False,
#     'taxed': True,
#     'deleverage': True,
#     'makerFee': -0.00025,
#     'takerFee': 0.00075,
#     'settlementFee': 0.0005,
#     'insuranceFee': 0.0,
#     'fundingBaseSymbol': '',
#     'fundingQuoteSymbol': '',
#     'fundingPremiumSymbol': '',
#     'fundingTimestamp': None,
#     'fundingInterval': None,
#     'fundingRate': None,
#     'indicativeFundingRate': None,
#     'rebalanceTimestamp': None,
#     'rebalanceInterval': None,
#     'openingTimestamp': datetime.datetime(2017, 9, 29, 12, 0, tzinfo=tzutc()),
#     'closingTimestamp': datetime.datetime(2017, 9, 29, 12, 0, tzinfo=tzutc()),
#     'sessionInterval': datetime.datetime(2000, 1, 1, 2, 0, tzinfo=tzutc()),
#     'prevClosePrice': 4187.21,
#     'limitDownPrice': None,
#     'limitUpPrice': None,
#     'bankruptLimitDownPrice': None,
#     'bankruptLimitUpPrice': None,
#     'prevTotalVolume': 495357311,
#     'totalVolume': 495357311,
#     'volume': 0,
#     'volume24h': 0,
#     'prevTotalTurnover': 14141095865259,
#     'totalTurnover': 14141095865259,
#     'turnover': 0,
#     'turnover24h': 0,
#     'homeNotional24h': 0.0,
#     'foreignNotional24h': 0.0,
#     'prevPrice24h': 4187.21,
#     'vwap': None,
#     'highPrice': None,
#     'lowPrice': None,
#     'lastPrice': 4187.21,
#     'lastPriceProtected': 4187.21,
#     'lastTickDirection': 'MinusTick',
#     'lastChangePcnt': 0.0,
#     'bidPrice': None,
#     'midPrice': None,
#     'askPrice': None,
#     'impactBidPrice': None,
#     'impactMidPrice': None,
#     'impactAskPrice': None,
#     'hasLiquidity': False,
#     'openInterest': 0,
#     'openValue': 0,
#     'fairMethod': 'ImpactMidPrice',
#     'fairBasisRate': 0.16,
#     'fairBasis': 0.0,
#     'fairPrice': 4187.21,
#     'markMethod': 'FairPrice',
#     'markPrice': 4187.21,
#     'indicativeTaxRate': 0.0,
#     'indicativeSettlePrice': 4187.21,
#     'optionUnderlyingPrice': None,
#     'settledPrice': 4187.21,
#     'timestamp': datetime.datetime(2017, 9, 29, 12, 0, tzinfo=tzutc())},
#    {'symbol': 'XBTM17',
#     'rootSymbol': 'XBT',
#     'state': 'Settled',
#     'typ': 'FFCCSX',
#     'listing': datetime.datetime(2017, 3, 13, 14, 0, tzinfo=tzutc()),
#     'front': datetime.datetime(2017, 5, 26, 12, 0, tzinfo=tzutc()),
#     'expiry': datetime.datetime(2017, 6, 30, 12, 0, tzinfo=tzutc()),
#     'settle': datetime.datetime(2017, 6, 30, 12, 0, tzinfo=tzutc()),
#     'relistInterval': None,
#     'inverseLeg': '',
#     'sellLeg': '',
#     'buyLeg': '',
#     'optionStrikePcnt': None,
#     'optionStrikeRound': None,
#     'optionStrikePrice': None,
#     'optionMultiplier': None,
#     'positionCurrency': 'USD',
#     'underlying': 'XBT',
#     'quoteCurrency': 'USD',
#     'underlyingSymbol': 'XBT=',
#     'reference': 'BMEX',
#     'referenceSymbol': '.BXBT30M',
#     'calcInterval': None,
#     'publishInterval': None,
#     'publishTime': None,
#     'maxOrderQty': 10000000,
#     'maxPrice': 1000000.0,
#     'lotSize': 1,
#     'tickSize': 0.1,
#     'multiplier': -100000000,
#     'settlCurrency': 'XBt',
#     'underlyingToPositionMultiplier': None,
#     'underlyingToSettleMultiplier': -100000000,
#     'quoteToSettleMultiplier': None,
#     'isQuanto': False,
#     'isInverse': True,
#     'initMargin': 0.01,
#     'maintMargin': 0.005,
#     'riskLimit': 5000000000,
#     'riskStep': 5000000000,
#     'limit': None,
#     'capped': False,
#     'taxed': True,
#     'deleverage': True,
#     'makerFee': -0.00025,
#     'takerFee': 0.00075,
#     'settlementFee': 0.0005,
#     'insuranceFee': 0.0,
#     'fundingBaseSymbol': '',
#     'fundingQuoteSymbol': '',
#     'fundingPremiumSymbol': '',
#     'fundingTimestamp': None,
#     'fundingInterval': None,
#     'fundingRate': None,
#     'indicativeFundingRate': None,
#     'rebalanceTimestamp': None,
#     'rebalanceInterval': None,
#     'openingTimestamp': datetime.datetime(2017, 6, 30, 12, 0, tzinfo=tzutc()),
#     'closingTimestamp': datetime.datetime(2017, 6, 30, 12, 0, tzinfo=tzutc()),
#     'sessionInterval': datetime.datetime(2000, 1, 1, 2, 0, tzinfo=tzutc()),
#     'prevClosePrice': 2552.46,
#     'limitDownPrice': None,
#     'limitUpPrice': None,
#     'bankruptLimitDownPrice': None,
#     'bankruptLimitUpPrice': None,
#     'prevTotalVolume': 115448597,
#     'totalVolume': 115448597,
#     'volume': 0,
#     'volume24h': 0,
#     'prevTotalTurnover': 7434625439437,
#     'totalTurnover': 7434625439437,
#     'turnover': 0,
#     'turnover24h': 0,
#     'homeNotional24h': 0.0,
#     'foreignNotional24h': 0.0,
#     'prevPrice24h': 2552.46,
#     'vwap': None,
#     'highPrice': None,
#     'lowPrice': None,
#     'lastPrice': 2552.46,
#     'lastPriceProtected': 2552.46,
#     'lastTickDirection': 'MinusTick',
#     'lastChangePcnt': 0.0,
#     'bidPrice': None,
#     'midPrice': None,
#     'askPrice': None,
#     'impactBidPrice': None,
#     'impactMidPrice': None,
#     'impactAskPrice': None,
#     'hasLiquidity': False,
#     'openInterest': 0,
#     'openValue': 0,
#     'fairMethod': 'ImpactMidPrice',
# ...
#    {'symbol': 'XBTZ14_XBTF15',
#     'rootSymbol': 'XBT',
#     'state': 'Settled',
#     'typ': 'FMXXS',
#     'listing': datetime.datetime(2014, 9, 28, 20, 0, tzinfo=tzutc()),
#     'front': datetime.datetime(2014, 11, 28, 12, 0, tzinfo=tzutc()),
#     'expiry': datetime.datetime(2014, 12, 6, 20, 0, tzinfo=tzutc()),
#     'settle': datetime.datetime(2014, 12, 6, 20, 0, tzinfo=tzutc()),
#     'relistInterval': None,
#     'inverseLeg': '',
#     'sellLeg': 'XBTZ14',
#     'buyLeg': 'XBTF15',
#     'optionStrikePcnt': None,
#     'optionStrikeRound': None,
#     'optionStrikePrice': None,
#     'optionMultiplier': None,
#     'positionCurrency': '',
#     'underlying': 'XBT',
#     'quoteCurrency': 'USD',
#     'underlyingSymbol': 'XBT=',
#     'reference': 'BMEX',
#     'referenceSymbol': '.XBT2H',
#     'calcInterval': None,
#     'publishInterval': None,
#     'publishTime': None,
#     'maxOrderQty': 10000000,
#     'maxPrice': 1000000.0,
#     'lotSize': 1,
#     'tickSize': 0.01,
#     'multiplier': 1000,
#     'settlCurrency': 'XBt',
#     'underlyingToPositionMultiplier': None,
#     'underlyingToSettleMultiplier': 100000000,
#     'quoteToSettleMultiplier': None,
#     'isQuanto': True,
#     'isInverse': False,
#     'initMargin': None,
#     'maintMargin': None,
#     'riskLimit': 5000000000,
#     'riskStep': 5000000000,
#     'limit': None,
#     'capped': False,
#     'taxed': False,
#     'deleverage': False,
#     'makerFee': 5e-05,
#     'takerFee': 5e-05,
#     'settlementFee': 5e-05,
#     'insuranceFee': 0.00015,
#     'fundingBaseSymbol': '',
#     'fundingQuoteSymbol': '',
#     'fundingPremiumSymbol': '',
#     'fundingTimestamp': None,
#     'fundingInterval': None,
#     'fundingRate': None,
#     'indicativeFundingRate': None,
#     'rebalanceTimestamp': None,
#     'rebalanceInterval': None,
#     'openingTimestamp': datetime.datetime(2014, 12, 6, 20, 0, tzinfo=tzutc()),
#     'closingTimestamp': datetime.datetime(2014, 12, 6, 20, 0, tzinfo=tzutc()),
#     'sessionInterval': datetime.datetime(2000, 1, 1, 8, 0, tzinfo=tzutc()),
#     'prevClosePrice': 1.59,
#     'limitDownPrice': None,
#     'limitUpPrice': None,
#     'bankruptLimitDownPrice': None,
#     'bankruptLimitUpPrice': None,
#     'prevTotalVolume': 1978807,
#     'totalVolume': 1987573,
#     'volume': 0,
#     'volume24h': 0,
#     'prevTotalTurnover': 0,
#     'totalTurnover': 0,
#     'turnover': 0,
#     'turnover24h': 0,
#     'homeNotional24h': 0.0,
#     'foreignNotional24h': 0.0,
#     'prevPrice24h': 1.58,
#     'vwap': None,
#     'highPrice': None,
#     'lowPrice': None,
#     'lastPrice': 1.58,
#     'lastPriceProtected': 1.58,
#     'lastTickDirection': 'ZeroMinusTick',
#     'lastChangePcnt': 0.0,
#     'bidPrice': None,
#     'midPrice': None,
#     'askPrice': None,
#     'impactBidPrice': None,
#     'impactMidPrice': None,
#     'impactAskPrice': None,
#     'hasLiquidity': False,
#     'openInterest': 0,
#     'openValue': 0,
#     'fairMethod': '',
#     'fairBasisRate': None,
#     'fairBasis': None,
#     'fairPrice': -90.89999999999998,
#     'markMethod': 'LastPrice',
#     'markPrice': 1.58,
#     'indicativeTaxRate': None,
#     'indicativeSettlePrice': None,
#     'optionUnderlyingPrice': None,
#     'settledPrice': None,
#     'timestamp': datetime.datetime(2014, 9, 28, 23, 5, 26, 20000, tzinfo=tzutc())},
#    {'symbol': 'XBTF15',
#     'rootSymbol': 'XBT',
#     'state': 'Settled',
#     'typ': 'FXXXS',
#     'listing': datetime.datetime(2014, 9, 28, 20, 0, tzinfo=tzutc()),
#     'front': datetime.datetime(2014, 12, 26, 12, 0, tzinfo=tzutc()),
#     'expiry': datetime.datetime(2015, 1, 30, 12, 0, tzinfo=tzutc()),
#     'settle': datetime.datetime(2015, 1, 30, 12, 0, tzinfo=tzutc()),
#     'relistInterval': None,
#     'inverseLeg': '',
#     'sellLeg': '',
#     'buyLeg': '',
#     'optionStrikePcnt': None,
#     'optionStrikeRound': None,
#     'optionStrikePrice': None,
#     'optionMultiplier': None,
#     'positionCurrency': '',
#     'underlying': 'XBT',
#     'quoteCurrency': 'USD',
#     'underlyingSymbol': 'XBT=',
#     'reference': 'BMEX',
#     'referenceSymbol': '.XBT2H',
#     'calcInterval': None,
#     'publishInterval': None,
#     'publishTime': None,
#     'maxOrderQty': 10000000,
#     'maxPrice': 1000000.0,
#     'lotSize': 1,
#     'tickSize': 0.01,
#     'multiplier': 1000,
#     'settlCurrency': 'XBt',
#     'underlyingToPositionMultiplier': None,
#     'underlyingToSettleMultiplier': 100000000,
#     'quoteToSettleMultiplier': None,
#     'isQuanto': True,
#     'isInverse': False,
#     'initMargin': 0.3,
#     'maintMargin': 0.2,
#     'riskLimit': 5000000000,
#     'riskStep': 5000000000,
#     'limit': 0.2,
#     'capped': False,
#     'taxed': False,
#     'deleverage': False,
#     'makerFee': 5e-05,
#     'takerFee': 5e-05,
#     'settlementFee': 5e-05,
#     'insuranceFee': 0.00015,
#     'fundingBaseSymbol': '',
#     'fundingQuoteSymbol': '',
#     'fundingPremiumSymbol': '',
#     'fundingTimestamp': None,
#     'fundingInterval': None,
#     'fundingRate': None,
#     'indicativeFundingRate': None,
#     'rebalanceTimestamp': None,
#     'rebalanceInterval': None,
#     'openingTimestamp': datetime.datetime(2015, 1, 30, 12, 0, tzinfo=tzutc()),
#     'closingTimestamp': datetime.datetime(2015, 1, 30, 12, 0, tzinfo=tzutc()),
#     'sessionInterval': datetime.datetime(2000, 1, 1, 8, 0, tzinfo=tzutc()),
#     'prevClosePrice': 242.16,
#     'limitDownPrice': 193.73,
#     'limitUpPrice': 290.59,
#     'bankruptLimitDownPrice': None,
#     'bankruptLimitUpPrice': None,
#     'prevTotalVolume': 3269473,
#     'totalVolume': 3304933,
#     'volume': 0,
#     'volume24h': 0,
#     'prevTotalTurnover': 54354268780,
#     'totalTurnover': 62658188720,
#     'turnover': 8303919940,
#     'turnover24h': 0,
#     'homeNotional24h': 0.0,
#     'foreignNotional24h': 0.0,
#     'prevPrice24h': 232.43,
#     'vwap': None,
#     'highPrice': None,
#     'lowPrice': None,
#     'lastPrice': 232.43,
#     'lastPriceProtected': 232.43,
#     'lastTickDirection': 'MinusTick',
#     'lastChangePcnt': 0.0,
#     'bidPrice': None,
#     'midPrice': None,
#     'askPrice': None,
#     'impactBidPrice': None,
#     'impactMidPrice': None,
#     'impactAskPrice': None,
#     'hasLiquidity': False,
#     'openInterest': 0,
#     'openValue': 0,
#     'fairMethod': '',
#     'fairBasisRate': None,
#     'fairBasis': 0.0,
#     'fairPrice': 232.43,
#     'markMethod': 'LastPrice',
#     'markPrice': 232.43,
#     'indicativeTaxRate': None,
#     'indicativeSettlePrice': 232.43,
#     'optionUnderlyingPrice': None,
#     'settledPrice': 232.43,
#     'timestamp': datetime.datetime(2014, 9, 28, 23, 5, 26, 20000, tzinfo=tzutc())},
#    {'symbol': 'XBTU14_XBTZ14',
#     'rootSymbol': 'XBT',
#     'state': 'Settled',
#     'typ': 'FMXXS',
#     'listing': datetime.datetime(2014, 9, 12, 12, 0, tzinfo=tzutc()),
#     'front': datetime.datetime(2014, 8, 29, 12, 0, tzinfo=tzutc()),
#     'expiry': datetime.datetime(2014, 9, 26, 12, 0, tzinfo=tzutc()),
#     'settle': datetime.datetime(2014, 9, 26, 12, 0, tzinfo=tzutc()),
#     'relistInterval': None,
#     'inverseLeg': '',
#     'sellLeg': 'XBTU14',
#     'buyLeg': 'XBTZ14',
#     'optionStrikePcnt': None,
#     'optionStrikeRound': None,
#     'optionStrikePrice': None,
#     'optionMultiplier': None,
#     'positionCurrency': '',
#     'underlying': 'XBT',
#     'quoteCurrency': 'USD',
#     'underlyingSymbol': 'XBT=',
#     'reference': 'BMEX',
#     'referenceSymbol': '.XBT2H',
#     'calcInterval': None,
#     'publishInterval': None,
#     'publishTime': None,
#     'maxOrderQty': 10000000,
#     'maxPrice': 1000000.0,
#     'lotSize': 1,
#     'tickSize': 0.01,
#     'multiplier': 1000,
#     'settlCurrency': 'XBt',
#     'underlyingToPositionMultiplier': None,
#     'underlyingToSettleMultiplier': 100000000,
#     'quoteToSettleMultiplier': None,
#     'isQuanto': True,
#     'isInverse': False,
#     'initMargin': None,
#     'maintMargin': None,
#     'riskLimit': 5000000000,
#     'riskStep': 5000000000,
#     'limit': None,
#     'capped': False,
#     'taxed': False,
#     'deleverage': False,
#     'makerFee': 5e-05,
#     'takerFee': 5e-05,
#     'settlementFee': 5e-05,
#     'insuranceFee': 0.00015,
#     'fundingBaseSymbol': '',
#     'fundingQuoteSymbol': '',
#     'fundingPremiumSymbol': '',
#     'fundingTimestamp': None,
#     'fundingInterval': None,
#     'fundingRate': None,
#     'indicativeFundingRate': None,
#     'rebalanceTimestamp': None,
#     'rebalanceInterval': None,
#     'openingTimestamp': datetime.datetime(2014, 9, 26, 12, 0, tzinfo=tzutc()),
#     'closingTimestamp': datetime.datetime(2014, 9, 26, 12, 0, tzinfo=tzutc()),
#     'sessionInterval': datetime.datetime(2000, 1, 1, 8, 0, tzinfo=tzutc()),
#     'prevClosePrice': 20.5,
#     'limitDownPrice': None,
#     'limitUpPrice': None,
#     'bankruptLimitDownPrice': None,
#     'bankruptLimitUpPrice': None,
#     'prevTotalVolume': 37662,
#     'totalVolume': 39486,
#     'volume': 0,
#     'volume24h': 0,
#     'prevTotalTurnover': 0,
#     'totalTurnover': 0,
#     'turnover': 0,
#     'turnover24h': 0,
#     'homeNotional24h': 0.0,
#     'foreignNotional24h': 0.0,
#     'prevPrice24h': 20.5,
#     'vwap': None,
#     'highPrice': None,
#     'lowPrice': None,
#     'lastPrice': 20.5,
#     'lastPriceProtected': 20.5,
#     'lastTickDirection': 'ZeroMinusTick',
#     'lastChangePcnt': 0.0,
#     'bidPrice': None,
#     'midPrice': None,
#     'askPrice': None,
#     'impactBidPrice': None,
#     'impactMidPrice': None,
#     'impactAskPrice': None,
#     'hasLiquidity': False,
#     'openInterest': 0,
#     'openValue': 0,
#     'fairMethod': '',
#     'fairBasisRate': None,
#     'fairBasis': None,
#     'fairPrice': -77.11000000000001,
#     'markMethod': 'LastPrice',
#     'markPrice': 20.5,
#     'indicativeTaxRate': None,
#     'indicativeSettlePrice': None,
#     'optionUnderlyingPrice': None,
#     'settledPrice': None,
#     'timestamp': datetime.datetime(2014, 9, 12, 16, 10, 19, 505000, tzinfo=tzutc())},
#    {'symbol': 'XBTZ14',
#     'rootSymbol': 'XBT',
#     'state': 'Settled',
#     'typ': 'FXXXS',
#     'listing': datetime.datetime(2014, 9, 12, 12, 0, tzinfo=tzutc()),
#     'front': datetime.datetime(2014, 11, 28, 12, 0, tzinfo=tzutc()),
#     'expiry': datetime.datetime(2014, 12, 26, 12, 0, tzinfo=tzutc()),
#     'settle': datetime.datetime(2014, 12, 26, 12, 0, tzinfo=tzutc()),
#     'relistInterval': None,
#     'inverseLeg': '',
#     'sellLeg': '',
#     'buyLeg': '',
#     'optionStrikePcnt': None,
#     'optionStrikeRound': None,
#     'optionStrikePrice': None,
#     'optionMultiplier': None,
#     'positionCurrency': '',
#     'underlying': 'XBT',
#     'quoteCurrency': 'USD',
#     'underlyingSymbol': 'XBT=',
#     'reference': 'BMEX',
#     'referenceSymbol': '.XBT2H',
#     'calcInterval': None,
#     'publishInterval': None,
#     'publishTime': None,
#     'maxOrderQty': 10000000,
#     'maxPrice': 1000000.0,
#     'lotSize': 1,
#     'tickSize': 0.01,
#     'multiplier': 1000,
#     'settlCurrency': 'XBt',
#     'underlyingToPositionMultiplier': None,
#     'underlyingToSettleMultiplier': 100000000,
#     'quoteToSettleMultiplier': None,
#     'isQuanto': True,
#     'isInverse': False,
#     'initMargin': 0.3,
#     'maintMargin': 0.2,
#     'riskLimit': 5000000000,
#     'riskStep': 5000000000,
#     'limit': 0.2,
#     'capped': False,
#     'taxed': False,
#     'deleverage': False,
#     'makerFee': 5e-05,
#     'takerFee': 5e-05,
#     'settlementFee': 5e-05,
#     'insuranceFee': 0.00015,
#     'fundingBaseSymbol': '',
#     'fundingQuoteSymbol': '',
#     'fundingPremiumSymbol': '',
#     'fundingTimestamp': None,
#     'fundingInterval': None,
#     'fundingRate': None,
#     'indicativeFundingRate': None,
#     'rebalanceTimestamp': None,
#     'rebalanceInterval': None,
#     'openingTimestamp': datetime.datetime(2014, 12, 26, 12, 0, tzinfo=tzutc()),
#     'closingTimestamp': datetime.datetime(2014, 12, 26, 12, 0, tzinfo=tzutc()),
#     'sessionInterval': datetime.datetime(2000, 1, 1, 8, 0, tzinfo=tzutc()),
#     'prevClosePrice': 324.16,
#     'limitDownPrice': 259.33,
#     'limitUpPrice': 388.99,
#     'bankruptLimitDownPrice': None,
#     'bankruptLimitUpPrice': None,
#     'prevTotalVolume': 6880792,
#     'totalVolume': 6904211,
#     'volume': 0,
#     'volume24h': 0,
#     'prevTotalTurnover': 0,
#     'totalTurnover': 0,
#     'turnover': 0,
#     'turnover24h': 0,
#     'homeNotional24h': 0.0,
#     'foreignNotional24h': 0.0,
#     'prevPrice24h': 323.33,
#     'vwap': None,
#     'highPrice': None,
#     'lowPrice': None,
#     'lastPrice': 323.33,
#     'lastPriceProtected': 323.33,
#     'lastTickDirection': 'MinusTick',
#     'lastChangePcnt': 0.0,
#     'bidPrice': None,
#     'midPrice': None,
#     'askPrice': None,
#     'impactBidPrice': None,
#     'impactMidPrice': None,
#     'impactAskPrice': None,
#     'hasLiquidity': False,
#     'openInterest': 0,
#     'openValue': 0,
#     'fairMethod': '',
#     'fairBasisRate': None,
#     'fairBasis': 0.0,
#     'fairPrice': 323.33,
#     'markMethod': 'LastPrice',
#     'markPrice': 323.33,
#     'indicativeTaxRate': None,
#     'indicativeSettlePrice': 323.33,
#     'optionUnderlyingPrice': None,
#     'settledPrice': 323.33,
#     'timestamp': datetime.datetime(2014, 9, 12, 16, 10, 19, 505000, tzinfo=tzutc())},
#    {'symbol': 'XBTU14',
#     'rootSymbol': 'XBT',
#     'state': 'Settled',
#     'typ': 'FXXXS',
#     'listing': datetime.datetime(2014, 9, 12, 12, 0, tzinfo=tzutc()),
#     'front': datetime.datetime(2014, 8, 29, 12, 0, tzinfo=tzutc()),
#     'expiry': datetime.datetime(2014, 9, 26, 12, 0, tzinfo=tzutc()),
#     'settle': datetime.datetime(2014, 9, 26, 12, 0, tzinfo=tzutc()),
#     'relistInterval': None,
#     'inverseLeg': '',
#     'sellLeg': '',
#     'buyLeg': '',
#     'optionStrikePcnt': None,
#     'optionStrikeRound': None,
#     'optionStrikePrice': None,
#     'optionMultiplier': None,
#     'positionCurrency': '',
#     'underlying': 'XBT',
#     'quoteCurrency': 'USD',
#     'underlyingSymbol': 'XBT=',
#     'reference': 'BMEX',
#     'referenceSymbol': '.XBT2H',
#     'calcInterval': None,
#     'publishInterval': None,
#     'publishTime': None,
#     'maxOrderQty': 10000000,
#     'maxPrice': 1000000.0,
#     'lotSize': 1,
#     'tickSize': 0.01,
#     'multiplier': 1000,
#     'settlCurrency': 'XBt',
#     'underlyingToPositionMultiplier': None,
#     'underlyingToSettleMultiplier': 100000000,
#     'quoteToSettleMultiplier': None,
#     'isQuanto': True,
#     'isInverse': False,
#     'initMargin': 0.3,
#     'maintMargin': 0.2,
#     'riskLimit': 5000000000,
#     'riskStep': 5000000000,
#     'limit': 0.2,
#     'capped': False,
#     'taxed': False,
#     'deleverage': False,
#     'makerFee': 5e-05,
#     'takerFee': 5e-05,
#     'settlementFee': 5e-05,
#     'insuranceFee': 0.00015,
#     'fundingBaseSymbol': '',
#     'fundingQuoteSymbol': '',
#     'fundingPremiumSymbol': '',
#     'fundingTimestamp': None,
#     'fundingInterval': None,
#     'fundingRate': None,
#     'indicativeFundingRate': None,
#     'rebalanceTimestamp': None,
#     'rebalanceInterval': None,
#     'openingTimestamp': datetime.datetime(2014, 9, 26, 12, 0, tzinfo=tzutc()),
#     'closingTimestamp': datetime.datetime(2014, 9, 26, 12, 0, tzinfo=tzutc()),
#     'sessionInterval': datetime.datetime(2000, 1, 1, 8, 0, tzinfo=tzutc()),
#     'prevClosePrice': 406.39,
#     'limitDownPrice': 325.11,
#     'limitUpPrice': 487.67,
#     'bankruptLimitDownPrice': None,
#     'bankruptLimitUpPrice': None,
#     'prevTotalVolume': 62491,
#     'totalVolume': 64021,
#     'volume': 0,
#     'volume24h': 0,
#     'prevTotalTurnover': 0,
#     'totalTurnover': 0,
#     'turnover': 0,
#     'turnover24h': 0,
#     'homeNotional24h': 0.0,
#     'foreignNotional24h': 0.0,
#     'prevPrice24h': 400.44,
#     'vwap': None,
#     'highPrice': None,
#     'lowPrice': None,
#     'lastPrice': 400.44,
#     'lastPriceProtected': 400.44,
#     'lastTickDirection': 'MinusTick',
#     'lastChangePcnt': 0.0,
#     'bidPrice': None,
#     'midPrice': None,
#     'askPrice': None,
#     'impactBidPrice': None,
#     'impactMidPrice': None,
#     'impactAskPrice': None,
#     'hasLiquidity': False,
#     'openInterest': 0,
#     'openValue': 0,
#     'fairMethod': '',
#     'fairBasisRate': None,
#     'fairBasis': 0.0,
#     'fairPrice': 400.44,
#     'markMethod': 'LastPrice',
#     'markPrice': 400.44,
#     'indicativeTaxRate': None,
#     'indicativeSettlePrice': 400.44,
#     'optionUnderlyingPrice': None,
#     'settledPrice': 400.44,
#     'timestamp': datetime.datetime(2014, 9, 12, 16, 10, 19, 504000, tzinfo=tzutc())}],
#   <bravado.requests_client.RequestsResponseAdapter at 0x107455630>)]

# %%
# create data frame
XBT_data_df = pd.DataFrame(XBT_data)

# view data frame
XBT_data_df.head()
# Out:
#                                                    0       1
# 0  [{'symbol': 'XBTZ19', 'rootSymbol': 'XBT', 'st...  200 OK

# %%
# select first cell of first row
XBT_0 = row[0]

# create data frame
XBT_df = pd.DataFrame(XBT_0)

# view data frame
XBT_df
# Out:
#        askPrice bankruptLimitDownPrice bankruptLimitUpPrice    bidPrice  \
# 0    9200.00000                   None                 None  8500.00000
# 1    8107.00000                   None                 None  8075.50000
# 2    9299.50000                   None                 None  8651.00000
# 3    4150.00000                   None                 None  4081.00000
# 4    3700.00000                   None                 None  3610.00000
# 5       0.00469                   None                 None     0.00393
# 6           NaN                   None                 None     0.00490
# 7           NaN                   None                 None     0.00001
# 8    6651.50000                   None                 None  6642.00000
# 9           NaN                   None                 None     0.09806
# 10   5904.00000                   None                 None  5881.50000
# 11   7598.00000                   None                 None  6501.50000
# 12          NaN                   None                 None         NaN
# 13          NaN                   None                 None         NaN
# 14          NaN                   None                 None         NaN
# 15          NaN                   None                 None         NaN
# 16          NaN                   None                 None         NaN
# 17          NaN                   None                 None         NaN
# 18          NaN                   None                 None         NaN
# 19          NaN                   None                 None         NaN
# 20          NaN                   None                 None         NaN
# 21          NaN                   None                 None         NaN
# 22          NaN                   None                 None         NaN
# 23          NaN                   None                 None         NaN
# 24          NaN                   None                 None         NaN
# 25          NaN                   None                 None         NaN
# 26          NaN                   None                 None         NaN
# 27          NaN                   None                 None         NaN
# 28          NaN                   None                 None         NaN
# 29          NaN                   None                 None         NaN
# ..          ...                    ...                  ...         ...
# 83          NaN                   None                 None         NaN
# 84          NaN                   None                 None         NaN
# 85          NaN                   None                 None         NaN
# 86          NaN                   None                 None         NaN
# 87          NaN                   None                 None         NaN
# 88          NaN                   None                 None         NaN
# 89          NaN                   None                 None         NaN
# 90          NaN                   None                 None         NaN
# 91          NaN                   None                 None         NaN
# 92          NaN                   None                 None         NaN
# 93          NaN                   None                 None         NaN
# 94          NaN                   None                 None         NaN
# 95          NaN                   None                 None         NaN
# 96          NaN                   None                 None         NaN
# 97          NaN                   None                 None         NaN
# 98          NaN                   None                 None         NaN
# 99          NaN                   None                 None         NaN
# 100         NaN                   None                 None         NaN
# 101         NaN                   None                 None         NaN
# 102         NaN                   None                 None         NaN
# 103         NaN                   None                 None         NaN
# 104         NaN                   None                 None         NaN
# 105         NaN                   None                 None         NaN
# 106         NaN                   None                 None         NaN
# 107         NaN                   None                 None         NaN
# 108         NaN                   None                 None         NaN
# 109         NaN                   None                 None         NaN
# 110         NaN                   None                 None         NaN
# 111         NaN                   None                 None         NaN
# 112         NaN                   None                 None         NaN
#
#      buyLeg              calcInterval  capped          closingTimestamp  \
# 0                                 NaT   False 2019-06-17 06:00:00+00:00
# 1                                 NaT   False 2019-06-17 06:00:00+00:00
# 2                                 NaT   False 2019-06-17 06:00:00+00:00
# 3                                 NaT   False 2019-03-29 12:00:00+00:00
# 4                                 NaT   False 2018-12-28 12:00:00+00:00
# 5                                 NaT    True 2019-06-17 06:00:00+00:00
# 6                                 NaT    True 2019-06-17 06:00:00+00:00
# 7                                 NaT    True 2018-06-08 12:00:00+00:00
# 8                                 NaT   False 2018-09-28 12:00:00+00:00
# 9                                 NaT    True 2018-06-08 12:00:00+00:00
# 10                                NaT   False 2018-06-29 12:00:00+00:00
# 11                                NaT   False 2018-03-30 12:00:00+00:00
# 12                                NaT   False 2017-12-29 12:00:00+00:00
# 13                                NaT   False 2017-09-29 12:00:00+00:00
# 14                                NaT   False 2017-06-30 12:00:00+00:00
# 15          2000-01-01 00:30:00+00:00   False                       NaT
# 16                                NaT   False                       NaT
# 17          2000-01-01 02:00:00+00:00   False                       NaT
# 18          2000-01-01 02:00:00+00:00   False                       NaT
# 19                                NaT   False 2017-03-31 12:00:00+00:00
# 20                                NaT   False 2016-12-30 12:00:00+00:00
# 21          2000-01-01 08:00:00+00:00   False                       NaT
# 22                                NaT   False                       NaT
# 23          2000-01-01 08:00:00+00:00   False                       NaT
# 24                                NaT   False                       NaT
# 25          2000-01-01 08:00:00+00:00   False                       NaT
# 26                                NaT   False                       NaT
# 27          2000-01-01 08:00:00+00:00   False                       NaT
# 28          2000-01-01 08:00:00+00:00   False                       NaT
# 29                                NaT   False                       NaT
# ..      ...                       ...     ...                       ...
# 83                                NaT   False 2015-07-31 12:00:00+00:00
# 84   XBTM15                       NaT    True 2015-05-29 12:00:00+00:00
# 85   XBTM15                       NaT   False 2015-04-24 12:00:00+00:00
# 86   XBTM15                       NaT   False 2015-02-27 12:00:00+00:00
# 87   XBTM15                       NaT   False 2015-03-27 12:00:00+00:00
# 88                                NaT    True 2015-06-26 12:00:00+00:00
# 89   XBTK15                       NaT   False 2015-04-24 12:00:00+00:00
# 90                                NaT    True 2015-05-29 12:00:00+00:00
# 91   XBTJ15                       NaT   False 2015-03-27 12:00:00+00:00
# 92                                NaT   False 2015-04-24 12:00:00+00:00
# 93   XBTH15                       NaT   False 2015-02-27 12:00:00+00:00
# 94   XBTH15                       NaT   False 2015-01-30 12:00:00+00:00
# 95   XBTH15                       NaT   False 2014-12-26 12:00:00+00:00
# 96   XBTF15                       NaT   False 2015-01-30 12:00:00+00:00
# 97   XBTF15                       NaT   False 2014-12-26 12:00:00+00:00
# 98   XBTF15                       NaT   False 2014-12-26 12:00:00+00:00
# 99   XBTZ14                       NaT   False 2014-12-26 12:00:00+00:00
# 100  XBTZ14                       NaT   False 2014-12-26 12:00:00+00:00
# 101  XBTG15                       NaT   False 2014-12-26 12:00:00+00:00
# 102  XBTG15                       NaT   False 2015-01-30 12:00:00+00:00
# 103                               NaT   False 2015-02-27 12:00:00+00:00
# 104  XBTH15                       NaT   False 2014-11-28 12:00:00+00:00
# 105                               NaT   False 2015-03-27 12:00:00+00:00
# 106  XBTX14                       NaT   False 2014-09-26 12:00:00+00:00
# 107                               NaT   False 2014-11-28 12:00:00+00:00
# 108  XBTF15                       NaT   False 2014-12-06 20:00:00+00:00
# 109                               NaT   False 2015-01-30 12:00:00+00:00
# 110  XBTZ14                       NaT   False 2014-09-26 12:00:00+00:00
# 111                               NaT   False 2014-12-26 12:00:00+00:00
# 112                               NaT   False 2014-09-26 12:00:00+00:00
#
#      deleverage                    expiry  ...      turnover   turnover24h  \
# 0          True 2019-12-27 12:00:00+00:00  ...  0.000000e+00  3.749405e+09
# 1          True 2019-09-27 12:00:00+00:00  ...  3.977020e+07  1.058510e+10
# 2          True 2019-06-28 12:00:00+00:00  ...  5.376500e+04  2.862140e+09
# 3          True 2019-03-29 12:00:00+00:00  ...  0.000000e+00  0.000000e+00
# 4          True 2018-12-28 12:00:00+00:00  ...  0.000000e+00  0.000000e+00
# 5          True 2019-06-21 12:00:00+00:00  ...  0.000000e+00  0.000000e+00
# 6          True 2019-06-21 12:00:00+00:00  ...  0.000000e+00  0.000000e+00
# 7          True 2018-06-08 12:00:00+00:00  ...  0.000000e+00  0.000000e+00
# 8          True 2018-09-28 12:00:00+00:00  ...  0.000000e+00  0.000000e+00
# 9          True 2018-06-08 12:00:00+00:00  ...  0.000000e+00  0.000000e+00
# 10         True 2018-06-29 12:00:00+00:00  ...  0.000000e+00  0.000000e+00
# 11         True 2018-03-30 12:00:00+00:00  ...  0.000000e+00  0.000000e+00
# 12         True 2017-12-29 12:00:00+00:00  ...  0.000000e+00  0.000000e+00
# 13         True 2017-09-29 12:00:00+00:00  ...  0.000000e+00  0.000000e+00
# 14         True 2017-06-30 12:00:00+00:00  ...  0.000000e+00  0.000000e+00
# 15        False                       NaT  ...           NaN           NaN
# 16        False                       NaT  ...           NaN           NaN
# 17        False                       NaT  ...           NaN           NaN
# 18        False                       NaT  ...           NaN           NaN
# 19         True 2017-03-31 12:00:00+00:00  ...  0.000000e+00  0.000000e+00
# 20         True 2016-12-30 12:00:00+00:00  ...  0.000000e+00  0.000000e+00
# 21        False                       NaT  ...           NaN           NaN
# 22        False                       NaT  ...           NaN           NaN
# 23        False                       NaT  ...           NaN           NaN
# 24        False                       NaT  ...           NaN           NaN
# 25        False                       NaT  ...           NaN           NaN
# 26        False                       NaT  ...           NaN           NaN
# 27        False                       NaT  ...           NaN           NaN
# 28        False                       NaT  ...           NaN           NaN
# 29        False                       NaT  ...           NaN           NaN
# ..          ...                       ...  ...           ...           ...
# 83        False 2015-07-31 12:00:00+00:00  ...  0.000000e+00  0.000000e+00
# 84        False 2015-05-29 12:00:00+00:00  ...  1.628210e+10  0.000000e+00
# 85        False 2015-04-24 12:00:00+00:00  ...  0.000000e+00  0.000000e+00
# 86        False 2015-02-27 12:00:00+00:00  ...  7.322793e+08  0.000000e+00
# 87        False 2015-03-27 12:00:00+00:00  ...  0.000000e+00  0.000000e+00
# 88        False 2015-06-26 12:00:00+00:00  ...  3.616724e+10  0.000000e+00
# 89        False 2015-04-24 12:00:00+00:00  ...  0.000000e+00  0.000000e+00
# 90        False 2015-05-29 12:00:00+00:00  ...  2.266819e+10  0.000000e+00
# 91        False 2015-03-27 12:00:00+00:00  ...  0.000000e+00  0.000000e+00
# 92        False 2015-04-24 12:00:00+00:00  ...  2.450508e+07  0.000000e+00
# 93        False 2015-02-27 12:00:00+00:00  ...  6.846329e+08  0.000000e+00
# 94        False 2015-01-30 12:00:00+00:00  ...  1.087448e+09  0.000000e+00
# 95        False 2014-12-26 12:00:00+00:00  ...  0.000000e+00  0.000000e+00
# 96        False 2015-01-30 12:00:00+00:00  ...  0.000000e+00  0.000000e+00
# 97        False 2014-12-26 12:00:00+00:00  ...  0.000000e+00  0.000000e+00
# 98        False 2014-12-26 12:00:00+00:00  ...  0.000000e+00  0.000000e+00
# 99        False 2014-12-26 12:00:00+00:00  ...  0.000000e+00  0.000000e+00
# 100       False 2014-12-26 12:00:00+00:00  ...  0.000000e+00  0.000000e+00
# 101       False 2014-12-26 12:00:00+00:00  ...  0.000000e+00  0.000000e+00
# 102       False 2015-01-30 12:00:00+00:00  ...  1.277187e+09  0.000000e+00
# 103       False 2015-02-27 12:00:00+00:00  ...  1.392077e+09  0.000000e+00
# 104       False 2014-11-28 12:00:00+00:00  ...  0.000000e+00  0.000000e+00
# 105       False 2015-03-27 12:00:00+00:00  ...  2.896835e+09  0.000000e+00
# 106       False 2014-09-26 12:00:00+00:00  ...  0.000000e+00  0.000000e+00
# 107       False 2014-11-28 12:00:00+00:00  ...  0.000000e+00  0.000000e+00
# 108       False 2014-12-06 20:00:00+00:00  ...  0.000000e+00  0.000000e+00
# 109       False 2015-01-30 12:00:00+00:00  ...  8.303920e+09  0.000000e+00
# 110       False 2014-09-26 12:00:00+00:00  ...  0.000000e+00  0.000000e+00
# 111       False 2014-12-26 12:00:00+00:00  ...  0.000000e+00  0.000000e+00
# 112       False 2014-09-26 12:00:00+00:00  ...  0.000000e+00  0.000000e+00
#
#         typ  underlying  underlyingSymbol underlyingToPositionMultiplier  \
# 0    FFCCSX         XBT              XBT=                            NaN
# 1    FFCCSX         XBT              XBT=                            NaN
# 2    FFCCSX         XBT              XBT=                            NaN
# 3    FFCCSX         XBT              XBT=                            NaN
# 4    FFCCSX         XBT              XBT=                            NaN
# 5    OPECCS         XBT              XBT=                           10.0
# 6    OCECCS         XBT              XBT=                           10.0
# 7    OPECCS         XBT              XBT=                           10.0
# 8    FFCCSX         XBT              XBT=                            NaN
# 9    OCECCS         XBT              XBT=                           10.0
# 10   FFCCSX         XBT              XBT=                            NaN
# 11   FFCCSX         XBT              XBT=                            NaN
# 12   FFCCSX         XBT              XBT=                            NaN
# 13   FFCCSX         XBT              XBT=                            NaN
# 14   FFCCSX         XBT              XBT=                            NaN
# 15   MRCXXX         XBT          .BXBT30M                            NaN
# 16   MRCXXX         XBT              XBT=                            NaN
# 17   MRRXXX         XBT       .XBTUSDPI2H                            NaN
# 18   MRRXXX         XBT         .XBTBON2H                            NaN
# 19   FFCCSX         XBT              XBT=                            NaN
# 20   FFCCSX         XBT              XBT=                            NaN
# 21   MRRXXX         XBT       .LSKXBTPI8H                            NaN
# 22   MRRXXX         XBT         .LSKXBTPI                            NaN
# 23   MRRXXX         XBT       .FCTXBTPI8H                            NaN
# 24   MRRXXX         XBT         .FCTXBTPI                            NaN
# 25   MRRXXX         XBT       .LTCXBTPI8H                            NaN
# 26   MRRXXX         XBT         .LTCXBTPI                            NaN
# 27   MRRXXX         XBT         .XBTPON8H                            NaN
# 28   MRRXXX         XBT       .XBTUSDPI8H                            NaN
# 29   MRRXXX         XBT         .XBTUSDPI                            NaN
# ..      ...         ...               ...                            ...
# 83    FXXXS         XBT              XBT=                            NaN
# 84    FMXXS         XBT              XBT=                            NaN
# 85    FMXXS         XBT              XBT=                            NaN
# 86    FMXXS         XBT              XBT=                            NaN
# 87    FMXXS         XBT              XBT=                            NaN
# 88    FXXXS         XBT              XBT=                            NaN
# 89    FMXXS         XBT              XBT=                            NaN
# 90    FXXXS         XBT              XBT=                            NaN
# 91    FMXXS         XBT              XBT=                            NaN
# 92    FXXXS         XBT              XBT=                            NaN
# 93    FMXXS         XBT              XBT=                            NaN
# 94    FMXXS         XBT              XBT=                            NaN
# 95    FMXXS         XBT              XBT=                            NaN
# 96    FMXXS         XBT              XBT=                            NaN
# 97    FMXXS         XBT              XBT=                            NaN
# 98    FMXXS         XBT              XBT=                            NaN
# 99    FMXXS         XBT              XBT=                            NaN
# 100   FMXXS         XBT              XBT=                            NaN
# 101   FMXXS         XBT              XBT=                            NaN
# 102   FMXXS         XBT              XBT=                            NaN
# 103   FXXXS         XBT              XBT=                            NaN
# 104   FMXXS         XBT              XBT=                            NaN
# 105   FXXXS         XBT              XBT=                            NaN
# 106   FMXXS         XBT              XBT=                            NaN
# 107   FXXXS         XBT              XBT=                            NaN
# 108   FMXXS         XBT              XBT=                            NaN
# 109   FXXXS         XBT              XBT=                            NaN
# 110   FMXXS         XBT              XBT=                            NaN
# 111   FXXXS         XBT              XBT=                            NaN
# 112   FXXXS         XBT              XBT=                            NaN
#
#     underlyingToSettleMultiplier  volume volume24h       vwap
# 0                   -100000000.0     0.0  369282.0  9849.3056
# 1                   -100000000.0  3232.0  932026.0  8805.1422
# 2                   -100000000.0     5.0  262734.0  9180.2075
# 3                   -100000000.0     0.0       0.0        NaN
# 4                   -100000000.0     0.0       0.0        NaN
# 5                            NaN     0.0       0.0        NaN
# 6                            NaN     0.0       0.0        NaN
# 7                            NaN     0.0       0.0        NaN
# 8                   -100000000.0     0.0       0.0        NaN
# 9                            NaN     0.0       0.0        NaN
# 10                  -100000000.0     0.0       0.0        NaN
# 11                  -100000000.0     0.0       0.0        NaN
# 12                  -100000000.0     0.0       0.0        NaN
# 13                  -100000000.0     0.0       0.0        NaN
# 14                  -100000000.0     0.0       0.0        NaN
# 15                           NaN     NaN       NaN        NaN
# 16                           NaN     NaN       NaN        NaN
# 17                           NaN     NaN       NaN        NaN
# 18                           NaN     NaN       NaN        NaN
# 19                  -100000000.0     0.0       0.0        NaN
# 20                  -100000000.0     0.0       0.0        NaN
# 21                           NaN     NaN       NaN        NaN
# 22                           NaN     NaN       NaN        NaN
# 23                           NaN     NaN       NaN        NaN
# 24                           NaN     NaN       NaN        NaN
# 25                           NaN     NaN       NaN        NaN
# 26                           NaN     NaN       NaN        NaN
# 27                           NaN     NaN       NaN        NaN
# 28                           NaN     NaN       NaN        NaN
# 29                           NaN     NaN       NaN        NaN
# ..                           ...     ...       ...        ...
# 83                   100000000.0     0.0       0.0        NaN
# 84                   100000000.0     0.0       0.0        NaN
# 85                   100000000.0     0.0       0.0        NaN
# 86                   100000000.0     0.0       0.0        NaN
# 87                   100000000.0     0.0       0.0        NaN
# 88                   100000000.0     0.0       0.0        NaN
# 89                   100000000.0     0.0       0.0        NaN
# 90                   100000000.0     0.0       0.0        NaN
# 91                   100000000.0     0.0       0.0        NaN
# 92                   100000000.0     0.0       0.0        NaN
# 93                   100000000.0     0.0       0.0        NaN
# 94                   100000000.0     0.0       0.0        NaN
# 95                   100000000.0     0.0       0.0        NaN
# 96                   100000000.0     0.0       0.0        NaN
# 97                   100000000.0     0.0       0.0        NaN
# 98                   100000000.0     0.0       0.0        NaN
# 99                   100000000.0     0.0       0.0        NaN
# 100                  100000000.0     0.0       0.0        NaN
# 101                  100000000.0     0.0       0.0        NaN
# 102                  100000000.0     0.0       0.0        NaN
# 103                  100000000.0     0.0       0.0        NaN
# 104                  100000000.0     0.0       0.0        NaN
# 105                  100000000.0     0.0       0.0        NaN
# 106                  100000000.0     0.0       0.0        NaN
# 107                  100000000.0     0.0       0.0        NaN
# 108                  100000000.0     0.0       0.0        NaN
# 109                  100000000.0     0.0       0.0        NaN
# 110                  100000000.0     0.0       0.0        NaN
# 111                  100000000.0     0.0       0.0        NaN
# 112                  100000000.0     0.0       0.0        NaN
#
# [113 rows x 103 columns]

# %%
# list column headers
XBT_df.columns.values
# Out:
# array(['askPrice', 'bankruptLimitDownPrice', 'bankruptLimitUpPrice',
#        'bidPrice', 'buyLeg', 'calcInterval', 'capped', 'closingTimestamp',
#        'deleverage', 'expiry', 'fairBasis', 'fairBasisRate', 'fairMethod',
#        'fairPrice', 'foreignNotional24h', 'front', 'fundingBaseSymbol',
#        'fundingInterval', 'fundingPremiumSymbol', 'fundingQuoteSymbol',
#        'fundingRate', 'fundingTimestamp', 'hasLiquidity', 'highPrice',
#        'homeNotional24h', 'impactAskPrice', 'impactBidPrice',
#        'impactMidPrice', 'indicativeFundingRate', 'indicativeSettlePrice',
#        'indicativeTaxRate', 'initMargin', 'insuranceFee', 'inverseLeg',
#        'isInverse', 'isQuanto', 'lastChangePcnt', 'lastPrice',
#        'lastPriceProtected', 'lastTickDirection', 'limit',
#        'limitDownPrice', 'limitUpPrice', 'listing', 'lotSize', 'lowPrice',
#        'maintMargin', 'makerFee', 'markMethod', 'markPrice',
#        'maxOrderQty', 'maxPrice', 'midPrice', 'multiplier',
#        'openInterest', 'openValue', 'openingTimestamp',
#        'optionMultiplier', 'optionStrikePcnt', 'optionStrikePrice',
#        'optionStrikeRound', 'optionUnderlyingPrice', 'positionCurrency',
#        'prevClosePrice', 'prevPrice24h', 'prevTotalTurnover',
#        'prevTotalVolume', 'publishInterval', 'publishTime',
#        'quoteCurrency', 'quoteToSettleMultiplier', 'rebalanceInterval',
#        'rebalanceTimestamp', 'reference', 'referenceSymbol',
#        'relistInterval', 'riskLimit', 'riskStep', 'rootSymbol', 'sellLeg',
#        'sessionInterval', 'settlCurrency', 'settle', 'settledPrice',
#        'settlementFee', 'state', 'symbol', 'takerFee', 'taxed',
#        'tickSize', 'timestamp', 'totalTurnover', 'totalVolume',
#        'turnover', 'turnover24h', 'typ', 'underlying', 'underlyingSymbol',
#        'underlyingToPositionMultiplier', 'underlyingToSettleMultiplier',
#        'volume', 'volume24h', 'vwap'], dtype=object)

# %%
# Remove unwanted columns
XBT_df_filtered = XBTUSD_df.drop(['askPrice', 'bankruptLimitDownPrice', 'bankruptLimitUpPrice',
       'bidPrice', 'buyLeg', 'calcInterval', 'capped', 'closingTimestamp',
       'deleverage', 'expiry', 'fairBasis', 'fairBasisRate', 'fairMethod',
       'fairPrice', 'foreignNotional24h', 'front', 'hasLiquidity', 'highPrice',
       'homeNotional24h', 'impactAskPrice', 'impactBidPrice',
       'impactMidPrice', 'indicativeFundingRate', 'indicativeSettlePrice',
       'indicativeTaxRate', 'initMargin', 'insuranceFee', 'inverseLeg',
       'isInverse', 'isQuanto', 'lastChangePcnt', 'lastPrice',
       'lastPriceProtected', 'lastTickDirection', 'limit',
       'limitDownPrice', 'limitUpPrice', 'listing', 'lotSize', 'lowPrice',
       'maintMargin', 'makerFee', 'markMethod', 'markPrice',
       'maxOrderQty', 'maxPrice', 'midPrice', 'multiplier',
       'openInterest', 'openValue', 'openingTimestamp',
       'optionMultiplier', 'optionStrikePcnt', 'optionStrikePrice',
       'optionStrikeRound', 'optionUnderlyingPrice', 'positionCurrency',
       'prevClosePrice', 'prevPrice24h', 'prevTotalTurnover',
       'prevTotalVolume', 'publishInterval', 'publishTime',
       'quoteCurrency', 'quoteToSettleMultiplier', 'rebalanceInterval',
       'rebalanceTimestamp', 'reference', 'referenceSymbol',
       'relistInterval', 'riskLimit', 'riskStep', 'rootSymbol', 'sellLeg',
       'sessionInterval', 'settlCurrency', 'settle', 'settledPrice',
       'settlementFee', 'state', 'symbol', 'takerFee', 'taxed',
       'tickSize', 'timestamp', 'totalTurnover', 'totalVolume',
       'turnover', 'turnover24h', 'typ', 'underlying', 'underlyingSymbol',
       'underlyingToPositionMultiplier', 'underlyingToSettleMultiplier',
       'volume', 'volume24h', 'vwap'], axis  = 1)

XBT_df_filtered.head()
# Out:
#   fundingBaseSymbol fundingInterval fundingPremiumSymbol fundingQuoteSymbol  \
# 0                               NaT
# 1                               NaT
# 2                               NaT
# 3                               NaT
# 4                               NaT
#
#    fundingRate fundingTimestamp
# 0          NaN              NaT
# 1          NaN              NaT
# 2          NaN              NaT
# 3          NaN              NaT
# 4          NaN              NaT

# %% [markdown]
# ### Get settlement data:

# %%
# filters
target_symbol = "XBTUSD"


# set up a parameters dictionary
params = {
    "symbol": target_symbol,
    "key": API_KEY,
    "count": 500,
    "reverse": True
}

# base url
base_url = "https://www.bitmex.com/api/v1/settlement"

# run a request using our params dictionary
response = requests.get(base_url, params=params)

# %%
# convert response to json
Settlement_data = response.json()

# %%
# Print the json (pretty printed)
print(json.dumps(Settlement_data, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 611.06,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-10-03T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 610.27,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-10-02T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 611.98,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-10-01T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 603.79,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-09-30T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 603.16,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-09-29T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 602.99,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-09-28T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 601.49,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-09-27T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 603.87,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-09-26T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 600.93,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-09-25T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 601.11,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-09-24T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 596.23,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-09-23T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 595.08,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-09-22T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 594.26,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-09-21T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 606.48,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-09-20T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 606.5,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-09-19T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 606.58,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-09-18T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 604.91,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-09-17T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 607.15,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-09-16T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 606.98,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-09-15T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 607.18,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-09-14T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 605.87,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-09-13T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 603.72,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-09-12T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 621.81,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-09-11T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 622.06,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-09-10T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 619.08,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-09-09T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 626.25,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-09-08T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 608.99,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-09-07T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 606.21,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-09-06T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 600.36,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-09-05T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 604.4,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-09-04T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 573.59,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-09-03T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 571.16,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-09-02T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 570.13,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-09-01T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 571.96,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-08-31T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 576.38,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-08-30T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 573.85,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-08-29T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 571.71,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-08-28T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 573.85,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-08-27T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 575.8,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-08-26T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 574.41,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-08-25T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 579.24,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-08-24T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 579.23,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-08-23T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 579.17,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-08-22T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 580.91,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-08-21T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 579.79,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-08-20T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 572.41,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-08-19T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 572.87,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-08-18T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 574.43,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-08-17T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 567.33,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-08-16T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 570.92,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-08-15T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 573.03,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-08-14T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 588,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-08-13T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 585.89,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-08-12T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 594.4,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-08-11T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 587.08,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-08-10T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 586.61,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-08-09T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 588.71,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-08-08T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 590.38,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-08-07T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 567.05,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-08-06T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 568.09,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-08-05T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 569.78,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-08-04T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 547.01,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-08-03T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 602.79,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-08-02T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 625.21,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-08-01T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 632.45,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-07-31T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 657.06,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-07-30T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 655.02,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-07-29T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 655.62,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-07-28T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 652.13,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-07-27T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 648.1,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-07-26T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 654.33,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-07-25T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 654.87,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-07-24T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 654.59,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-07-23T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 660.52,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-07-22T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 662.28,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-07-21T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 670.23,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-07-20T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 672.94,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-07-19T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 680.5,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-07-18T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 667.4,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-07-17T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 665.84,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-07-16T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 664.05,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-07-15T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 660.27,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-07-14T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 665.87,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-07-13T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 652.59,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-07-12T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 645.69,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-07-11T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 646.05,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-07-10T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 649.9,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-07-09T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 642.11,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-07-08T12:00:00.000Z"
#     },
#     {
#         "bankrupt": 5911176753,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 644.55,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": 21068272625,
#         "taxRate": 0.2805724445574949,
#         "timestamp": "2016-07-07T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 671.4,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-07-06T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 673.45,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-07-05T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 670.33,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-07-04T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 679.9,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-07-03T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 690.01,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-07-02T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 679.31,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-07-01T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 651.62,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-06-30T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 633.85,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-06-29T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 648.84,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-06-28T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 636,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-06-27T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 648.05,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-06-26T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 676.8,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-06-25T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 654.38,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-06-24T12:00:00.000Z"
#     },
#     {
#         "bankrupt": 13489666245,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 590.88,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": 59442867052,
#         "taxRate": 0.22693498671925397,
#         "timestamp": "2016-06-23T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 662.56,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-06-22T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 690.86,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-06-21T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 743.51,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-06-20T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 753.61,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-06-19T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 751.14,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-06-18T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 738.8,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-06-17T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 732.15,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-06-16T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 682,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-06-15T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 688.34,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-06-14T12:00:00.000Z"
#     },
#     {
#         "bankrupt": 4903345267,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 698.55,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": 39296396803,
#         "taxRate": 0.12477849538168509,
#         "timestamp": "2016-06-13T12:00:00.000Z"
#     },
#     {
#         "bankrupt": 10177462868,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 645.99,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": 50944273227,
#         "taxRate": 0.19977638747834836,
#         "timestamp": "2016-06-12T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 583.46,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-06-11T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 574.68,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-06-10T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 580.83,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-06-09T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 581.58,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-06-08T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 585.82,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-06-07T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 583.28,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-06-06T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 576.9,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-06-05T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 572.83,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-06-04T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 554.32,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-06-03T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 536.62,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-06-02T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 534.29,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-06-01T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 544.93,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-05-31T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 543.4,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-05-30T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 476.3,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-05-27T12:00:00.000Z"
#     },
#     {
#         "bankrupt": null,
#         "optionStrikePrice": null,
#         "optionUnderlyingPrice": null,
#         "settledPrice": 442.59,
#         "settlementType": "Rebalance",
#         "symbol": "XBTUSD",
#         "taxBase": null,
#         "taxRate": null,
#         "timestamp": "2016-05-20T12:00:00.000Z"
#     }
# ]

# %%
# create data frame
Settlement_data_df = pd.DataFrame(Settlement_data)

# view data frame
Settlement_data_df
# Out:
#          bankrupt optionStrikePrice optionUnderlyingPrice  settledPrice  \
# 0             NaN              None                  None        611.06
# 1             NaN              None                  None        610.27
# 2             NaN              None                  None        611.98
# 3             NaN              None                  None        603.79
# 4             NaN              None                  None        603.16
# 5             NaN              None                  None        602.99
# 6             NaN              None                  None        601.49
# 7             NaN              None                  None        603.87
# 8             NaN              None                  None        600.93
# 9             NaN              None                  None        601.11
# 10            NaN              None                  None        596.23
# 11            NaN              None                  None        595.08
# 12            NaN              None                  None        594.26
# 13            NaN              None                  None        606.48
# 14            NaN              None                  None        606.50
# 15            NaN              None                  None        606.58
# 16            NaN              None                  None        604.91
# 17            NaN              None                  None        607.15
# 18            NaN              None                  None        606.98
# 19            NaN              None                  None        607.18
# 20            NaN              None                  None        605.87
# 21            NaN              None                  None        603.72
# 22            NaN              None                  None        621.81
# 23            NaN              None                  None        622.06
# 24            NaN              None                  None        619.08
# 25            NaN              None                  None        626.25
# 26            NaN              None                  None        608.99
# 27            NaN              None                  None        606.21
# 28            NaN              None                  None        600.36
# 29            NaN              None                  None        604.40
# ..            ...               ...                   ...           ...
# 99            NaN              None                  None        648.05
# 100           NaN              None                  None        676.80
# 101           NaN              None                  None        654.38
# 102  1.348967e+10              None                  None        590.88
# 103           NaN              None                  None        662.56
# 104           NaN              None                  None        690.86
# 105           NaN              None                  None        743.51
# 106           NaN              None                  None        753.61
# 107           NaN              None                  None        751.14
# 108           NaN              None                  None        738.80
# 109           NaN              None                  None        732.15
# 110           NaN              None                  None        682.00
# 111           NaN              None                  None        688.34
# 112  4.903345e+09              None                  None        698.55
# 113  1.017746e+10              None                  None        645.99
# 114           NaN              None                  None        583.46
# 115           NaN              None                  None        574.68
# 116           NaN              None                  None        580.83
# 117           NaN              None                  None        581.58
# 118           NaN              None                  None        585.82
# 119           NaN              None                  None        583.28
# 120           NaN              None                  None        576.90
# 121           NaN              None                  None        572.83
# 122           NaN              None                  None        554.32
# 123           NaN              None                  None        536.62
# 124           NaN              None                  None        534.29
# 125           NaN              None                  None        544.93
# 126           NaN              None                  None        543.40
# 127           NaN              None                  None        476.30
# 128           NaN              None                  None        442.59
#
#     settlementType  symbol       taxBase   taxRate                 timestamp
# 0        Rebalance  XBTUSD           NaN       NaN  2016-10-03T12:00:00.000Z
# 1        Rebalance  XBTUSD           NaN       NaN  2016-10-02T12:00:00.000Z
# 2        Rebalance  XBTUSD           NaN       NaN  2016-10-01T12:00:00.000Z
# 3        Rebalance  XBTUSD           NaN       NaN  2016-09-30T12:00:00.000Z
# 4        Rebalance  XBTUSD           NaN       NaN  2016-09-29T12:00:00.000Z
# 5        Rebalance  XBTUSD           NaN       NaN  2016-09-28T12:00:00.000Z
# 6        Rebalance  XBTUSD           NaN       NaN  2016-09-27T12:00:00.000Z
# 7        Rebalance  XBTUSD           NaN       NaN  2016-09-26T12:00:00.000Z
# 8        Rebalance  XBTUSD           NaN       NaN  2016-09-25T12:00:00.000Z
# 9        Rebalance  XBTUSD           NaN       NaN  2016-09-24T12:00:00.000Z
# 10       Rebalance  XBTUSD           NaN       NaN  2016-09-23T12:00:00.000Z
# 11       Rebalance  XBTUSD           NaN       NaN  2016-09-22T12:00:00.000Z
# 12       Rebalance  XBTUSD           NaN       NaN  2016-09-21T12:00:00.000Z
# 13       Rebalance  XBTUSD           NaN       NaN  2016-09-20T12:00:00.000Z
# 14       Rebalance  XBTUSD           NaN       NaN  2016-09-19T12:00:00.000Z
# 15       Rebalance  XBTUSD           NaN       NaN  2016-09-18T12:00:00.000Z
# 16       Rebalance  XBTUSD           NaN       NaN  2016-09-17T12:00:00.000Z
# 17       Rebalance  XBTUSD           NaN       NaN  2016-09-16T12:00:00.000Z
# 18       Rebalance  XBTUSD           NaN       NaN  2016-09-15T12:00:00.000Z
# 19       Rebalance  XBTUSD           NaN       NaN  2016-09-14T12:00:00.000Z
# 20       Rebalance  XBTUSD           NaN       NaN  2016-09-13T12:00:00.000Z
# 21       Rebalance  XBTUSD           NaN       NaN  2016-09-12T12:00:00.000Z
# 22       Rebalance  XBTUSD           NaN       NaN  2016-09-11T12:00:00.000Z
# 23       Rebalance  XBTUSD           NaN       NaN  2016-09-10T12:00:00.000Z
# 24       Rebalance  XBTUSD           NaN       NaN  2016-09-09T12:00:00.000Z
# 25       Rebalance  XBTUSD           NaN       NaN  2016-09-08T12:00:00.000Z
# 26       Rebalance  XBTUSD           NaN       NaN  2016-09-07T12:00:00.000Z
# 27       Rebalance  XBTUSD           NaN       NaN  2016-09-06T12:00:00.000Z
# 28       Rebalance  XBTUSD           NaN       NaN  2016-09-05T12:00:00.000Z
# 29       Rebalance  XBTUSD           NaN       NaN  2016-09-04T12:00:00.000Z
# ..             ...     ...           ...       ...                       ...
# 99       Rebalance  XBTUSD           NaN       NaN  2016-06-26T12:00:00.000Z
# 100      Rebalance  XBTUSD           NaN       NaN  2016-06-25T12:00:00.000Z
# 101      Rebalance  XBTUSD           NaN       NaN  2016-06-24T12:00:00.000Z
# 102      Rebalance  XBTUSD  5.944287e+10  0.226935  2016-06-23T12:00:00.000Z
# 103      Rebalance  XBTUSD           NaN       NaN  2016-06-22T12:00:00.000Z
# 104      Rebalance  XBTUSD           NaN       NaN  2016-06-21T12:00:00.000Z
# 105      Rebalance  XBTUSD           NaN       NaN  2016-06-20T12:00:00.000Z
# 106      Rebalance  XBTUSD           NaN       NaN  2016-06-19T12:00:00.000Z
# 107      Rebalance  XBTUSD           NaN       NaN  2016-06-18T12:00:00.000Z
# 108      Rebalance  XBTUSD           NaN       NaN  2016-06-17T12:00:00.000Z
# 109      Rebalance  XBTUSD           NaN       NaN  2016-06-16T12:00:00.000Z
# 110      Rebalance  XBTUSD           NaN       NaN  2016-06-15T12:00:00.000Z
# 111      Rebalance  XBTUSD           NaN       NaN  2016-06-14T12:00:00.000Z
# 112      Rebalance  XBTUSD  3.929640e+10  0.124778  2016-06-13T12:00:00.000Z
# 113      Rebalance  XBTUSD  5.094427e+10  0.199776  2016-06-12T12:00:00.000Z
# 114      Rebalance  XBTUSD           NaN       NaN  2016-06-11T12:00:00.000Z
# 115      Rebalance  XBTUSD           NaN       NaN  2016-06-10T12:00:00.000Z
# 116      Rebalance  XBTUSD           NaN       NaN  2016-06-09T12:00:00.000Z
# 117      Rebalance  XBTUSD           NaN       NaN  2016-06-08T12:00:00.000Z
# 118      Rebalance  XBTUSD           NaN       NaN  2016-06-07T12:00:00.000Z
# 119      Rebalance  XBTUSD           NaN       NaN  2016-06-06T12:00:00.000Z
# 120      Rebalance  XBTUSD           NaN       NaN  2016-06-05T12:00:00.000Z
# 121      Rebalance  XBTUSD           NaN       NaN  2016-06-04T12:00:00.000Z
# 122      Rebalance  XBTUSD           NaN       NaN  2016-06-03T12:00:00.000Z
# 123      Rebalance  XBTUSD           NaN       NaN  2016-06-02T12:00:00.000Z
# 124      Rebalance  XBTUSD           NaN       NaN  2016-06-01T12:00:00.000Z
# 125      Rebalance  XBTUSD           NaN       NaN  2016-05-31T12:00:00.000Z
# 126      Rebalance  XBTUSD           NaN       NaN  2016-05-30T12:00:00.000Z
# 127      Rebalance  XBTUSD           NaN       NaN  2016-05-27T12:00:00.000Z
# 128      Rebalance  XBTUSD           NaN       NaN  2016-05-20T12:00:00.000Z
#
# [129 rows x 9 columns]

# %% [markdown]
# # Working on this:

# %% [markdown]
# Do I need to save as a separate file "bitmex.py"

# %%
#!/usr/bin/env python

from bravado.client import SwaggerClient
from bravado.requests_client import RequestsClient
from BitMEXAPIKeyAuthenticator import APIKeyAuthenticator


def bitmex(test=True, config=None, api_key=None, api_secret=None):

    if config is None:
        # See full config options at http://bravado.readthedocs.io/en/latest/configuration.html
        config = {
            # Don't use models (Python classes) instead of dicts for #/definitions/{models}
            'use_models': False,
            # bravado has some issues with nullable fields
            'validate_responses': False,
            # Returns response in 2-tuple of (body, response); if False, will only return body
            'also_return_response': True,
        }

    if test:
        host = 'https://testnet.bitmex.com'
    else:
        host = 'https://www.bitmex.com'

    spec_uri = host + '/api/explorer/swagger.json'

    api_key = api_key
    api_secret = api_secret

    if api_key and api_secret:
        request_client = RequestsClient()
        request_client.authenticator = APIKeyAuthenticator(host, api_key, api_secret)

        return SwaggerClient.from_url(spec_uri, config=config, http_client=request_client)

    else:
        return SwaggerClient.from_url(spec_uri, config=config)

# %% [markdown]
# Do I need to save as file: BitMEXAPIKeyAuthenticator.py

# %%
import urllib.parse
import time
import hashlib
import hmac
from bravado.requests_client import Authenticator


class APIKeyAuthenticator(Authenticator):
    """?api_key authenticator.
    This authenticator adds BitMEX API key support via header.
    :param host: Host to authenticate for.
    :param api_key: API key.
    :param api_secret: API secret.
    """

    def __init__(self, host, api_key, api_secret):
        super(APIKeyAuthenticator, self).__init__(host)
        self.api_key = api_key
        self.api_secret = api_secret

    # Forces this to apply to all requests.
    def matches(self, url):
        if "swagger.json" in url:
            return False
        return True

    # Add the proper headers via the `expires` scheme.
    def apply(self, r):
        # 5s grace period in case of clock skew
        expires = int(round(time.time()) + 5)
        r.headers['api-expires'] = str(expires)
        r.headers['api-key'] = self.api_key
        prepared = r.prepare()
        body = prepared.body or ''
        url = prepared.path_url
        # print(json.dumps(r.data,  separators=(',',':')))
        r.headers['api-signature'] = self.generate_signature(self.api_secret, r.method, url, expires, body)
        return r

    # Generates an API signature.
    # A signature is HMAC_SHA256(secret, verb + path + nonce + data), hex encoded.
    # Verb must be uppercased, url is relative, nonce must be an increasing 64-bit integer
    # and the data, if present, must be JSON without whitespace between keys.
    #
    # For example, in psuedocode (and in real code below):
    #
    # verb=POST
    # url=/api/v1/order
    # nonce=1416993995705
    # data={"symbol":"XBTZ14","quantity":1,"price":395.01}
    # signature = HEX(HMAC_SHA256(secret, 'POST/api/v1/order1416993995705{"symbol":"XBTZ14","quantity":1,"price":395.01}'))
    def generate_signature(self, secret, verb, url, nonce, data):
        """Generate a request signature compatible with BitMEX."""
        # Parse the url so we can remove the base and extract just the path.
        parsedURL = urllib.parse.urlparse(url)
        path = parsedURL.path
        if parsedURL.query:
            path = path + '?' + parsedURL.query

        message = bytes(verb + path + str(nonce) + data, 'utf-8')
        # print("Computing HMAC: %s" % message)

        signature = hmac.new(bytes(secret, 'utf-8'), message, digestmod=hashlib.sha256).hexdigest()
        return signature

# %% [markdown]
# ## JUNK CODE

# %%
# Get data for various XBT- symbols
XBT_US_Dollar_data = test_client.Instrument.Instrument_get(filter=json.dumps({'symbol': 'XBTUSD'})).result()
XBT_Japanese_Yen_data = test_client.Instrument.Instrument_get(filter=json.dumps({'symbol': 'XBTJPY'})).result()
XBT_7_Day_Futures_data = test_client.Instrument.Instrument_get(filter=json.dumps({'symbol': 'XBT7D'})).result()

XBT_US_Dollar_data

# %% [markdown]
# ### Create a list of dates in datetime format

# %%
# Range of latitudes and longitudes
day_range = range(1, 32)
month_range = range(1, 13)
year_range = range(2014, 2020)

# for year in year_range:
#     print(year)

# for month in month_range:
#     print(month)
    
# for day in day_range:
#     print(day)


# List for holding dates
dates = []

# Add each date to the list of dates
for year in year_range:
    for month in month_range:
        for day in day_range:
            try:
                date = datetime.datetime(year, month, day, 23, 0, tzinfo=tzutc())
                dates.append(date)
            except(ValueError):
                pass

# Print the date count to confirm dates added
len(dates)
# Out:
# 2191
